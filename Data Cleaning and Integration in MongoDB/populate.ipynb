# %% [markdown]
# ### Import Libraries

# %%
import configparser as configparser
import pandas as pd
import pymongo
import json
from decimal import Decimal

# %% [markdown]
# ## Parsing INI File

# %% [markdown]
# ### Funtion: To parse INI file

# %%
def parse_ini(section: str) -> dict:
    """
    This function parses ini file for configuration details
    :param section: section to read from ini
    :return: Dictionary of config details
    """
    config = dict()
    parser = configparser.ConfigParser()
    parser.read("imdb_database.ini")
    if parser.has_section(section):
        config_items = parser.items(section)
        for item in config_items:
            config[item[0]] = item[1]
    return config

# %%
mongo_config = parse_ini("mongodb")
mongo_config
# Out:
# {'host': 'localhost', 'database': 'imdb', 'port': '27017'}

# %% [markdown]
# ## Processing "extra-data.json"

# %% [markdown]
# ### Reading extra-data.json file and splitting and loading every object into list of JSON objects

# %%
with open('extra-data.json', 'r') as file:
    temp = file.read()  
    temp = temp.split("}\n")
    temp = [data.strip() + "}" for data in temp]
    temp = list(filter(("}").__ne__, temp))
    temp = [json.loads(data) for data in temp]

extra_data = temp
extra_data
# Out:
# [{'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'A Good Day to Die Hard'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1606378'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '92000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '304654182'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': "De rouille et d'os"},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt2053425'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '16000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '19500000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Fistful of Dollars'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0058461'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '200000'},
#   'distributorLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mokép'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3500000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Per un pugno di dollari'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0058461'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '200000'},
#   'distributorLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mokép'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3500000'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Fox Searchlight Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '231400000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Juno'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0467406'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'PG-13'},
#   'titleLabel': {'type': 'literal',
#    'value': 'The Hobbit: An Unexpected Journey'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0903624'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '180000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Fórum Hungary'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1021103568'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Elysium'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1535108'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '115000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'TriStar Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '286140700'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Eagle'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1034389'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '25000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Fórum Hungary'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '36054706'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Renaissance Man'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0110971'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '40000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Walt Disney Studios Motion Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '24332324'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'PG-13'},
#   'titleLabel': {'type': 'literal',
#    'value': 'The Lord of the Rings: The Return of the King'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0167260'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '94000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'New Line Cinema'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1119929521'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'PG-13'},
#   'titleLabel': {'type': 'literal',
#    'value': 'The Lord of the Rings: The Return of the King'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0167260'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '94000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1119929521'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': '300'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0416449'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '65000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '456068181'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': '300'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0416449'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '65000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '456068181'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'PG'},
#   'titleLabel': {'type': 'literal',
#    'value': "Dr. Seuss' How the Grinch Stole Christmas"},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0170016'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'UIP-Dunafilm'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '345100000'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '202000000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Fun with Dick and Jane'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0369441'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Silence of the Lambs'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0102926'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '19000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Orion Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '272742922'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Forrest Gump'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0109830'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '55000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Paramount Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '677945399'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Forrest Gump'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0109830'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '55000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'UIP-Dunafilm'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '677945399'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': '20th Century Fox'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '229900000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Heat'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt2404463'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Bullet to the Head'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1308729'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '55000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '21947209'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Wrestler'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1125849'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '6000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Fórum Hungary'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '44700000'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '271400000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Grown Ups'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1375670'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Insidious'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1591095'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1500000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'FilmDistrict'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '97009150'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Cloverfield'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1060277'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '25000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'UIP-Dunafilm'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '171000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Slumdog Millionaire'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1010048'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '15000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Fox Searchlight Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '377910544'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Slumdog Millionaire'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1010048'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '15000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Fórum Hungary'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '377910544'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Gran Torino'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1205489'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '33000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '269958228'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Gran Torino'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1205489'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '33000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '269958228'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal',
#    'value': 'The Lord of the Rings: The Fellowship of the Ring'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0120737'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '93000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'New Line Cinema'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '871530324'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Machete Kills'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt2002718'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '20000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Global Road Entertainment'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '15008161'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Machete'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0985694'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '10500000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': '20th Century Fox'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '44093316'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Machete'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0985694'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '10500000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Budapest Film'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '44093316'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Gladiator'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0172495'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '103000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'DreamWorks'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '460583960'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Gladiator'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0172495'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '103000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'UIP-Dunafilm'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '460583960'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Palermo'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '11600000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal',
#    'value': 'Monsieur Ibrahim et les fleurs du Coran'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0329388'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Duplex'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0266489'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '40000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Miramax'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '19322135'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Fórum Hungary'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '317400000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Proposal'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1041829'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '243200000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'A Few Good Men'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0104257'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Great Dictator'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0032553'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '2000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United Artists'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '5000000'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Paramount Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '356800000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Top Gun'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0092099'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'UIP-Dunafilm'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '217800000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Collateral'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0369339'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Paramount Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '203400000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Vanilla Sky'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0259711'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'R'},
#   'titleLabel': {'type': 'literal', 'value': 'Dancer in the Dark'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0168629'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Fine Line Features'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '45584036'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'True Lies'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0111503'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '115000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '379000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': "A Knight's Tale"},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0183790'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '41000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '117000000'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Universal Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '30925690'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Dune'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0087182'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Universal Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '30925690'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Dune'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0087182'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Silver Linings Playbook'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1045658'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '21000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'The Weinstein Company'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '236412453'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '411300000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Batman'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0096895'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '411300000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Batman'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0096895'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal',
#    'value': "Lemony Snicket's A Series of Unfortunate Events"},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0339291'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '140000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Paramount Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '209073645'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Fórum Hungary'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '709700000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Twilight Saga: New Moon'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1259571'}},
#  {'distributorLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mokép'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '40157856'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Piano'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0107822'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal',
#    'value': 'The Mummy: Tomb of the Dragon Emperor'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0859163'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '145000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'UIP-Dunafilm'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '401128639'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '545400000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal',
#    'value': 'Sherlock Holmes: A Game of Shadows'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1515091'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Rise of the Planet of the Apes'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1318514'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '93000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '481801049'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal',
#    'value': 'Percy Jackson & the Olympians: The Lightning Thief'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0814255'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '95000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': '20th Century Fox'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '226496399'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal',
#    'value': 'Percy Jackson & the Olympians: The Lightning Thief'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0814255'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '95000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '226496399'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Minority Report'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0181689'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '102000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '358000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'First Blood'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0083944'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '15000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '125212904'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '216500000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': "Valentine's Day"},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0817230'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '216500000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': "Valentine's Day"},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0817230'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '242000000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal',
#    'value': 'Journey to the Center of the Earth'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0373051'}},
#  {'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '4431423'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Hong Kong dollar'},
#   'titleLabel': {'type': 'literal', 'value': '精武門'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0068767'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Fórum Hungary'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '53676580'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Lawless'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1212450'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Dirty Dancing'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0092890'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '6000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Vestron Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '213954274'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'New Line Cinema'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '244400000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Rush Hour'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0120812'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'PG-13'},
#   'titleLabel': {'type': 'literal', 'value': 'Kindergarten Cop'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0099938'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Universal Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '202000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'R'},
#   'titleLabel': {'type': 'literal', 'value': 'The Matrix'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0133093'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '63000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '463517383'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'R'},
#   'titleLabel': {'type': 'literal', 'value': 'The Matrix'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0133093'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '63000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '463517383'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Resident Evil: Retribution'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1855325'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '65000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Screen Gems'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '240000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Blue Lagoon'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0080453'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '4500000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Columbia Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '58853106'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'PG-13'},
#   'titleLabel': {'type': 'literal',
#    'value': 'Harry Potter and the Goblet of Fire'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0330373'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '150000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '897099794'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'PG-13'},
#   'titleLabel': {'type': 'literal',
#    'value': 'Harry Potter and the Order of the Phoenix'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0373889'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '150000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '939885929'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'PG'},
#   'titleLabel': {'type': 'literal',
#    'value': 'Harry Potter and the Chamber of Secrets'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0295297'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '879200000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'PG'},
#   'titleLabel': {'type': 'literal',
#    'value': "Harry Potter and the Philosopher's Stone"},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0241527'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '975051288'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'G'},
#   'titleLabel': {'type': 'literal', 'value': '2001: A Space Odyssey'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0062622'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '10500000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Metro-Goldwyn-Mayer'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '190700000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'G'},
#   'titleLabel': {'type': 'literal', 'value': '2001: A Space Odyssey'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0062622'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '10500000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Turner Entertainment'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '190700000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'G'},
#   'titleLabel': {'type': 'literal', 'value': '2001: A Space Odyssey'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0062622'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '10500000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Home Video'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '190700000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Pulp Fiction'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0110912'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '8000000'},
#   'distributorLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mokép'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '214000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'R'},
#   'titleLabel': {'type': 'literal', 'value': 'Aliens'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0090605'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '18500000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': '20th Century Fox'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '131000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'R'},
#   'titleLabel': {'type': 'literal', 'value': 'Aliens'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0090605'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '18500000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '131000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'R'},
#   'titleLabel': {'type': 'literal', 'value': 'Aliens'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0090605'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '18500000'},
#   'distributorLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mokép'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '131000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'PG'},
#   'titleLabel': {'type': 'literal', 'value': 'Home Alone'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0099785'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '18000000'},
#   'distributorLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mokép'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '476684675'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'PG-13'},
#   'titleLabel': {'type': 'literal', 'value': 'Independence Day'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0116629'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '817400891'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'PG-13'},
#   'titleLabel': {'type': 'literal', 'value': 'The Bourne Identity'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0258463'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'UIP-Dunafilm'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '214000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Dr. Strangelove'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0057012'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1800000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Columbia Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '9440000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Stargate'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0111282'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '55000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '196567262'}},
#  {'distributorLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mokép'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '240000000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Die Hard 2'},
# ...
#    'value': '20th Century Fox'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '242700000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Marley & Me'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0822832'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '242700000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Marley & Me'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0822832'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': '20th Century Fox'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '105300000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The X-Files'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0120902'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Marine'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0419946'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '22000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': '20th Century Fox'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '25800000'}},
#  {'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '9500000'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '25555809'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': '9 рота'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0417397'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Manhattan Murder Mystery'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0107507'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '13500000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'TriStar Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '11300000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'J. Edgar'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1616195'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '35000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '84600000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Four Rooms'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0113101'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '4000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Miramax'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '4257354'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Dimension Films'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '15116634'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal',
#    'value': 'Halloween: The Curse of Michael Myers'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0113253'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Soldier'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0120157'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '75000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '15000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Pink Flamingos'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0069089'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '10000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'New Line Cinema'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '6000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': '"Crocodile" Dundee II'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0092493'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '9000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Paramount Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '239606210'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Magnolia Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '2783139'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'To the Wonder'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1595656'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Analyze This'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0122933'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '80000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '176880000'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'First National'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '1200000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Patent Leather Kid'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0018253'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': "Bienvenue chez les Ch'tis"},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1064932'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '11000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Pathé Distribution'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '245000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Windtalkers'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0245562'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '115000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Metro-Goldwyn-Mayer'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '77628265'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '165615285'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Sleepers'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0117665'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'UIP-Dunafilm'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '375700000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'G.I. Joe: Retaliation'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1583421'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'R'},
#   'titleLabel': {'type': 'literal', 'value': 'Point Break'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0102685'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '24000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': '20th Century Fox'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '83000000'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Vikings'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0052365'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3500000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United Artists'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '6000000'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Walt Disney Studios Motion Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '309457509'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Runaway Bride'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0163187'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Max Payne'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0467197'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '35000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'InterCom'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '85416905'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Footloose'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1068242'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '24000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Paramount Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '62701289'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'Katy Perry: Part of Me'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt2215719'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '13000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Universal Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '32726956'}},
#  {'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Titanus'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '6000000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Shootist'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0075213'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Swarm'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0078350'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '21000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Warner Bros.'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '7600000'}},
#  {'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '4500000'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '123820'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Romantics'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1403988'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'MPAA_film_ratingLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'PG-13'},
#   'titleLabel': {'type': 'literal', 'value': 'Thor: The Dark World'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt1981115'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '170000000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'Walt Disney Studios Motion Pictures'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '644571402'}},
#  {'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '800000'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '800000'},
#   'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'The Barbarians'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0092615'}},
#  {'box_office_currencyLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': 'United States dollar'},
#   'titleLabel': {'type': 'literal', 'value': 'La Mouche noire'},
#   'IMDb_ID': {'type': 'literal', 'value': 'tt0051622'},
#   'cost': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '495000'},
#   'distributorLabel': {'xml:lang': 'en',
#    'type': 'literal',
#    'value': '20th Century Fox'},
#   'box_office': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal',
#    'type': 'literal',
#    'value': '3000000'}},
#  ...]

# %%
len(extra_data)
# Out:
# 230825

# %% [markdown]
# ### Counting documents with "IMDb_ID" field

# %%
count = 0
for data in extra_data:
    data1 = data
    if 'IMDb_ID' in data:
        id = data['IMDb_ID']['value']
        count += 1
count
# Out:
# 181968

# %% [markdown]
# ### Creating UpdateOne Requests for MongoDB

# %%
requests = []
for data in extra_data:
    data1 = data
    if 'IMDb_ID' in data:
        id = data['IMDb_ID']['value']
        filter = {'_id': int(id[2:])}
        update = dict()
        currency = "United States dollar"
        if 'box_office_currencyLabel' in data:
            currency = data['box_office_currencyLabel']['value']
        if 'box_office' in data:
            try:
                update['box_office'] = {'value': int(data['box_office']['value']), 'currency': currency}
            except ValueError:
                try:
                    value = float(data['box_office']['value'])
                    update['box_office'] = {'value': int(value), 'currency': currency}
                except ValueError:
                    pass 
        if 'cost' in data:
            try:
                update['cost'] = {'value': int(data['cost']['value']), 'currency': currency}
            except ValueError:
                try:
                    value = float(data['cost']['value'])
                    update['cost'] = {'value': int(value), 'currency': currency}
                except ValueError:
                    pass
        if 'distributorLabel' in data:
            update['distributor'] = data['distributorLabel']['value']
        if 'MPAA_film_ratingLabel' in data:
            update['rating_label'] = data['MPAA_film_ratingLabel']['value']
        if bool(update):
            requests += [pymongo.UpdateOne(filter=filter, update={'$set': update})]

requests
# Out:
# [UpdateOne({'_id': 1606378}, {'$set': {'box_office': {'value': 304654182, 'currency': 'United States dollar'}, 'cost': {'value': 92000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 2053425}, {'$set': {'box_office': {'value': 19500000, 'currency': 'United States dollar'}, 'cost': {'value': 16000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 58461}, {'$set': {'box_office': {'value': 3500000, 'currency': 'United States dollar'}, 'cost': {'value': 200000, 'currency': 'United States dollar'}, 'distributor': 'Mokép'}}, False, None, None, None),
#  UpdateOne({'_id': 58461}, {'$set': {'box_office': {'value': 3500000, 'currency': 'United States dollar'}, 'cost': {'value': 200000, 'currency': 'United States dollar'}, 'distributor': 'Mokép'}}, False, None, None, None),
#  UpdateOne({'_id': 467406}, {'$set': {'box_office': {'value': 231400000, 'currency': 'United States dollar'}, 'distributor': 'Fox Searchlight Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 903624}, {'$set': {'box_office': {'value': 1021103568, 'currency': 'United States dollar'}, 'cost': {'value': 180000000, 'currency': 'United States dollar'}, 'distributor': 'Fórum Hungary', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 1535108}, {'$set': {'box_office': {'value': 286140700, 'currency': 'United States dollar'}, 'cost': {'value': 115000000, 'currency': 'United States dollar'}, 'distributor': 'TriStar Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 1034389}, {'$set': {'box_office': {'value': 36054706, 'currency': 'United States dollar'}, 'cost': {'value': 25000000, 'currency': 'United States dollar'}, 'distributor': 'Fórum Hungary'}}, False, None, None, None),
#  UpdateOne({'_id': 110971}, {'$set': {'box_office': {'value': 24332324, 'currency': 'United States dollar'}, 'cost': {'value': 40000000, 'currency': 'United States dollar'}, 'distributor': 'Walt Disney Studios Motion Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 167260}, {'$set': {'box_office': {'value': 1119929521, 'currency': 'United States dollar'}, 'cost': {'value': 94000000, 'currency': 'United States dollar'}, 'distributor': 'New Line Cinema', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 167260}, {'$set': {'box_office': {'value': 1119929521, 'currency': 'United States dollar'}, 'cost': {'value': 94000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 416449}, {'$set': {'box_office': {'value': 456068181, 'currency': 'United States dollar'}, 'cost': {'value': 65000000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 416449}, {'$set': {'box_office': {'value': 456068181, 'currency': 'United States dollar'}, 'cost': {'value': 65000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 170016}, {'$set': {'box_office': {'value': 345100000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm', 'rating_label': 'PG'}}, False, None, None, None),
#  UpdateOne({'_id': 369441}, {'$set': {'box_office': {'value': 202000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 102926}, {'$set': {'box_office': {'value': 272742922, 'currency': 'United States dollar'}, 'cost': {'value': 19000000, 'currency': 'United States dollar'}, 'distributor': 'Orion Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 109830}, {'$set': {'box_office': {'value': 677945399, 'currency': 'United States dollar'}, 'cost': {'value': 55000000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 109830}, {'$set': {'box_office': {'value': 677945399, 'currency': 'United States dollar'}, 'cost': {'value': 55000000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 2404463}, {'$set': {'box_office': {'value': 229900000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 1308729}, {'$set': {'box_office': {'value': 21947209, 'currency': 'United States dollar'}, 'cost': {'value': 55000000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 1125849}, {'$set': {'box_office': {'value': 44700000, 'currency': 'United States dollar'}, 'cost': {'value': 6000000, 'currency': 'United States dollar'}, 'distributor': 'Fórum Hungary'}}, False, None, None, None),
#  UpdateOne({'_id': 1375670}, {'$set': {'box_office': {'value': 271400000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 1591095}, {'$set': {'box_office': {'value': 97009150, 'currency': 'United States dollar'}, 'cost': {'value': 1500000, 'currency': 'United States dollar'}, 'distributor': 'FilmDistrict'}}, False, None, None, None),
#  UpdateOne({'_id': 1060277}, {'$set': {'box_office': {'value': 171000000, 'currency': 'United States dollar'}, 'cost': {'value': 25000000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 1010048}, {'$set': {'box_office': {'value': 377910544, 'currency': 'United States dollar'}, 'cost': {'value': 15000000, 'currency': 'United States dollar'}, 'distributor': 'Fox Searchlight Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 1010048}, {'$set': {'box_office': {'value': 377910544, 'currency': 'United States dollar'}, 'cost': {'value': 15000000, 'currency': 'United States dollar'}, 'distributor': 'Fórum Hungary'}}, False, None, None, None),
#  UpdateOne({'_id': 1205489}, {'$set': {'box_office': {'value': 269958228, 'currency': 'United States dollar'}, 'cost': {'value': 33000000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 1205489}, {'$set': {'box_office': {'value': 269958228, 'currency': 'United States dollar'}, 'cost': {'value': 33000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 120737}, {'$set': {'box_office': {'value': 871530324, 'currency': 'United States dollar'}, 'cost': {'value': 93000000, 'currency': 'United States dollar'}, 'distributor': 'New Line Cinema'}}, False, None, None, None),
#  UpdateOne({'_id': 2002718}, {'$set': {'box_office': {'value': 15008161, 'currency': 'United States dollar'}, 'cost': {'value': 20000000, 'currency': 'United States dollar'}, 'distributor': 'Global Road Entertainment'}}, False, None, None, None),
#  UpdateOne({'_id': 985694}, {'$set': {'box_office': {'value': 44093316, 'currency': 'United States dollar'}, 'cost': {'value': 10500000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 985694}, {'$set': {'box_office': {'value': 44093316, 'currency': 'United States dollar'}, 'cost': {'value': 10500000, 'currency': 'United States dollar'}, 'distributor': 'Budapest Film'}}, False, None, None, None),
#  UpdateOne({'_id': 172495}, {'$set': {'box_office': {'value': 460583960, 'currency': 'United States dollar'}, 'cost': {'value': 103000000, 'currency': 'United States dollar'}, 'distributor': 'DreamWorks'}}, False, None, None, None),
#  UpdateOne({'_id': 172495}, {'$set': {'box_office': {'value': 460583960, 'currency': 'United States dollar'}, 'cost': {'value': 103000000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 329388}, {'$set': {'box_office': {'value': 11600000, 'currency': 'United States dollar'}, 'distributor': 'Palermo'}}, False, None, None, None),
#  UpdateOne({'_id': 266489}, {'$set': {'box_office': {'value': 19322135, 'currency': 'United States dollar'}, 'cost': {'value': 40000000, 'currency': 'United States dollar'}, 'distributor': 'Miramax'}}, False, None, None, None),
#  UpdateOne({'_id': 1041829}, {'$set': {'box_office': {'value': 317400000, 'currency': 'United States dollar'}, 'distributor': 'Fórum Hungary'}}, False, None, None, None),
#  UpdateOne({'_id': 104257}, {'$set': {'box_office': {'value': 243200000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 32553}, {'$set': {'box_office': {'value': 5000000, 'currency': 'United States dollar'}, 'cost': {'value': 2000000, 'currency': 'United States dollar'}, 'distributor': 'United Artists'}}, False, None, None, None),
#  UpdateOne({'_id': 92099}, {'$set': {'box_office': {'value': 356800000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 369339}, {'$set': {'box_office': {'value': 217800000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 259711}, {'$set': {'box_office': {'value': 203400000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 168629}, {'$set': {'box_office': {'value': 45584036, 'currency': 'United States dollar'}, 'distributor': 'Fine Line Features', 'rating_label': 'R'}}, False, None, None, None),
#  UpdateOne({'_id': 111503}, {'$set': {'box_office': {'value': 379000000, 'currency': 'United States dollar'}, 'cost': {'value': 115000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 183790}, {'$set': {'box_office': {'value': 117000000, 'currency': 'United States dollar'}, 'cost': {'value': 41000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 87182}, {'$set': {'box_office': {'value': 30925690, 'currency': 'United States dollar'}, 'distributor': 'Universal Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 87182}, {'$set': {'box_office': {'value': 30925690, 'currency': 'United States dollar'}, 'distributor': 'Universal Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 1045658}, {'$set': {'box_office': {'value': 236412453, 'currency': 'United States dollar'}, 'cost': {'value': 21000000, 'currency': 'United States dollar'}, 'distributor': 'The Weinstein Company'}}, False, None, None, None),
#  UpdateOne({'_id': 96895}, {'$set': {'box_office': {'value': 411300000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 96895}, {'$set': {'box_office': {'value': 411300000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 339291}, {'$set': {'box_office': {'value': 209073645, 'currency': 'United States dollar'}, 'cost': {'value': 140000000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 1259571}, {'$set': {'box_office': {'value': 709700000, 'currency': 'United States dollar'}, 'distributor': 'Fórum Hungary'}}, False, None, None, None),
#  UpdateOne({'_id': 107822}, {'$set': {'box_office': {'value': 40157856, 'currency': 'United States dollar'}, 'distributor': 'Mokép'}}, False, None, None, None),
#  UpdateOne({'_id': 859163}, {'$set': {'box_office': {'value': 401128639, 'currency': 'United States dollar'}, 'cost': {'value': 145000000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 1515091}, {'$set': {'box_office': {'value': 545400000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 1318514}, {'$set': {'box_office': {'value': 481801049, 'currency': 'United States dollar'}, 'cost': {'value': 93000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 814255}, {'$set': {'box_office': {'value': 226496399, 'currency': 'United States dollar'}, 'cost': {'value': 95000000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 814255}, {'$set': {'box_office': {'value': 226496399, 'currency': 'United States dollar'}, 'cost': {'value': 95000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 181689}, {'$set': {'box_office': {'value': 358000000, 'currency': 'United States dollar'}, 'cost': {'value': 102000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 83944}, {'$set': {'box_office': {'value': 125212904, 'currency': 'United States dollar'}, 'cost': {'value': 15000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 817230}, {'$set': {'box_office': {'value': 216500000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 817230}, {'$set': {'box_office': {'value': 216500000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 373051}, {'$set': {'box_office': {'value': 242000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 68767}, {'$set': {'box_office': {'value': 4431423, 'currency': 'Hong Kong dollar'}}}, False, None, None, None),
#  UpdateOne({'_id': 1212450}, {'$set': {'box_office': {'value': 53676580, 'currency': 'United States dollar'}, 'distributor': 'Fórum Hungary'}}, False, None, None, None),
#  UpdateOne({'_id': 92890}, {'$set': {'box_office': {'value': 213954274, 'currency': 'United States dollar'}, 'cost': {'value': 6000000, 'currency': 'United States dollar'}, 'distributor': 'Vestron Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 120812}, {'$set': {'box_office': {'value': 244400000, 'currency': 'United States dollar'}, 'distributor': 'New Line Cinema'}}, False, None, None, None),
#  UpdateOne({'_id': 99938}, {'$set': {'box_office': {'value': 202000000, 'currency': 'United States dollar'}, 'distributor': 'Universal Pictures', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 133093}, {'$set': {'box_office': {'value': 463517383, 'currency': 'United States dollar'}, 'cost': {'value': 63000000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.', 'rating_label': 'R'}}, False, None, None, None),
#  UpdateOne({'_id': 133093}, {'$set': {'box_office': {'value': 463517383, 'currency': 'United States dollar'}, 'cost': {'value': 63000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom', 'rating_label': 'R'}}, False, None, None, None),
#  UpdateOne({'_id': 1855325}, {'$set': {'box_office': {'value': 240000000, 'currency': 'United States dollar'}, 'cost': {'value': 65000000, 'currency': 'United States dollar'}, 'distributor': 'Screen Gems'}}, False, None, None, None),
#  UpdateOne({'_id': 80453}, {'$set': {'box_office': {'value': 58853106, 'currency': 'United States dollar'}, 'cost': {'value': 4500000, 'currency': 'United States dollar'}, 'distributor': 'Columbia Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 330373}, {'$set': {'box_office': {'value': 897099794, 'currency': 'United States dollar'}, 'cost': {'value': 150000000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 373889}, {'$set': {'box_office': {'value': 939885929, 'currency': 'United States dollar'}, 'cost': {'value': 150000000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 295297}, {'$set': {'box_office': {'value': 879200000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.', 'rating_label': 'PG'}}, False, None, None, None),
#  UpdateOne({'_id': 241527}, {'$set': {'box_office': {'value': 975051288, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.', 'rating_label': 'PG'}}, False, None, None, None),
#  UpdateOne({'_id': 62622}, {'$set': {'box_office': {'value': 190700000, 'currency': 'United States dollar'}, 'cost': {'value': 10500000, 'currency': 'United States dollar'}, 'distributor': 'Metro-Goldwyn-Mayer', 'rating_label': 'G'}}, False, None, None, None),
#  UpdateOne({'_id': 62622}, {'$set': {'box_office': {'value': 190700000, 'currency': 'United States dollar'}, 'cost': {'value': 10500000, 'currency': 'United States dollar'}, 'distributor': 'Turner Entertainment', 'rating_label': 'G'}}, False, None, None, None),
#  UpdateOne({'_id': 62622}, {'$set': {'box_office': {'value': 190700000, 'currency': 'United States dollar'}, 'cost': {'value': 10500000, 'currency': 'United States dollar'}, 'distributor': 'Warner Home Video', 'rating_label': 'G'}}, False, None, None, None),
#  UpdateOne({'_id': 110912}, {'$set': {'box_office': {'value': 214000000, 'currency': 'United States dollar'}, 'cost': {'value': 8000000, 'currency': 'United States dollar'}, 'distributor': 'Mokép'}}, False, None, None, None),
#  UpdateOne({'_id': 90605}, {'$set': {'box_office': {'value': 131000000, 'currency': 'United States dollar'}, 'cost': {'value': 18500000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox', 'rating_label': 'R'}}, False, None, None, None),
#  UpdateOne({'_id': 90605}, {'$set': {'box_office': {'value': 131000000, 'currency': 'United States dollar'}, 'cost': {'value': 18500000, 'currency': 'United States dollar'}, 'distributor': 'InterCom', 'rating_label': 'R'}}, False, None, None, None),
#  UpdateOne({'_id': 90605}, {'$set': {'box_office': {'value': 131000000, 'currency': 'United States dollar'}, 'cost': {'value': 18500000, 'currency': 'United States dollar'}, 'distributor': 'Mokép', 'rating_label': 'R'}}, False, None, None, None),
#  UpdateOne({'_id': 99785}, {'$set': {'box_office': {'value': 476684675, 'currency': 'United States dollar'}, 'cost': {'value': 18000000, 'currency': 'United States dollar'}, 'distributor': 'Mokép', 'rating_label': 'PG'}}, False, None, None, None),
#  UpdateOne({'_id': 116629}, {'$set': {'box_office': {'value': 817400891, 'currency': 'United States dollar'}, 'distributor': 'InterCom', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 258463}, {'$set': {'box_office': {'value': 214000000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 57012}, {'$set': {'box_office': {'value': 9440000, 'currency': 'United States dollar'}, 'cost': {'value': 1800000, 'currency': 'United States dollar'}, 'distributor': 'Columbia Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 111282}, {'$set': {'box_office': {'value': 196567262, 'currency': 'United States dollar'}, 'cost': {'value': 55000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 99423}, {'$set': {'box_office': {'value': 240000000, 'currency': 'United States dollar'}, 'distributor': 'Mokép'}}, False, None, None, None),
#  UpdateOne({'_id': 120903}, {'$set': {'box_office': {'value': 296300000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 120903}, {'$set': {'box_office': {'value': 296300000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 97165}, {'$set': {'box_office': {'value': 235900000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 112384}, {'$set': {'box_office': {'value': 355237933, 'currency': 'United States dollar'}, 'cost': {'value': 62000000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 119116}, {'$set': {'box_office': {'value': 263900000, 'currency': 'United States dollar'}, 'distributor': 'Gaumont Film Company'}}, False, None, None, None),
#  UpdateOne({'_id': 119116}, {'$set': {'box_office': {'value': 263900000, 'currency': 'United States dollar'}, 'distributor': 'Gaumont Film Company'}}, False, None, None, None),
#  UpdateOne({'_id': 112864}, {'$set': {'box_office': {'value': 366100000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 108160}, {'$set': {'box_office': {'value': 227900000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 440963}, {'$set': {'box_office': {'value': 442800000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 335266}, {'$set': {'box_office': {'value': 119000000, 'currency': 'United States dollar'}, 'cost': {'value': 4000000, 'currency': 'United States dollar'}, 'distributor': 'Focus Features'}}, False, None, None, None),
#  UpdateOne({'_id': 335266}, {'$set': {'box_office': {'value': 119000000, 'currency': 'United States dollar'}, 'cost': {'value': 4000000, 'currency': 'United States dollar'}, 'distributor': 'Pathé Distribution'}}, False, None, None, None),
#  UpdateOne({'_id': 59800}, {'$set': {'box_office': {'value': 205000000, 'currency': 'United States dollar'}, 'cost': {'value': 9000000, 'currency': 'United States dollar'}, 'distributor': 'United Artists'}}, False, None, None, None),
#  UpdateOne({'_id': 111257}, {'$set': {'box_office': {'value': 350400000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 54331}, {'$set': {'box_office': {'value': 22800000, 'currency': 'Hong Kong dollar'}, 'cost': {'value': 12000000, 'currency': 'Hong Kong dollar'}, 'distributor': 'Universal Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 94226}, {'$set': {'box_office': {'value': 76270454, 'currency': 'United States dollar'}, 'cost': {'value': 25000000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 134847}, {'$set': {'box_office': {'value': 53187659, 'currency': 'United States dollar'}, 'cost': {'value': 23000000, 'currency': 'United States dollar'}, 'distributor': 'Focus Features'}}, False, None, None, None),
#  UpdateOne({'_id': 278504}, {'$set': {'box_office': {'value': 113714830, 'currency': 'United States dollar'}, 'cost': {'value': 46000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 119396}, {'$set': {'box_office': {'value': 72000000, 'currency': 'United States dollar'}, 'cost': {'value': 12000000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 1067583}, {'$set': {'box_office': {'value': 117086251, 'currency': 'United States dollar'}, 'cost': {'value': 38000000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 361596}, {'$set': {'box_office': {'value': 222400000, 'currency': 'United States dollar'}, 'cost': {'value': 6000000, 'currency': 'United States dollar'}, 'distributor': 'IFC Films'}}, False, None, None, None),
#  UpdateOne({'_id': 361596}, {'$set': {'box_office': {'value': 222400000, 'currency': 'United States dollar'}, 'cost': {'value': 6000000, 'currency': 'United States dollar'}, 'distributor': 'Dog Eat Dog Films'}}, False, None, None, None),
#  UpdateOne({'_id': 361596}, {'$set': {'box_office': {'value': 222400000, 'currency': 'United States dollar'}, 'cost': {'value': 6000000, 'currency': 'United States dollar'}, 'distributor': 'Lionsgate Films'}}, False, None, None, None),
#  UpdateOne({'_id': 361596}, {'$set': {'box_office': {'value': 222400000, 'currency': 'United States dollar'}, 'cost': {'value': 6000000, 'currency': 'United States dollar'}, 'distributor': 'Mokép'}}, False, None, None, None),
#  UpdateOne({'_id': 100802}, {'$set': {'box_office': {'value': 261300000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 427327}, {'$set': {'box_office': {'value': 202500000, 'currency': 'United States dollar'}, 'distributor': 'New Line Cinema'}}, False, None, None, None),
#  UpdateOne({'_id': 116282}, {'$set': {'box_office': {'value': 60600000, 'currency': 'United States dollar'}, 'cost': {'value': 7000000, 'currency': 'United States dollar'}, 'distributor': 'Gramercy Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 478311}, {'$set': {'box_office': {'value': 219100000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 322259}, {'$set': {'box_office': {'value': 236400000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 113497}, {'$set': {'box_office': {'value': 262800000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 458352}, {'$set': {'box_office': {'value': 326551094, 'currency': 'United States dollar'}, 'cost': {'value': 35000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 332280}, {'$set': {'box_office': {'value': 15533000, 'currency': '1'}, 'cost': {'value': 30000000, 'currency': '1'}, 'distributor': 'New Line Cinema'}}, False, None, None, None),
#  UpdateOne({'_id': 955308}, {'$set': {'box_office': {'value': 321669741, 'currency': 'United States dollar'}, 'cost': {'value': 200000000, 'currency': 'United States dollar'}, 'distributor': 'Universal Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 955308}, {'$set': {'box_office': {'value': 321669741, 'currency': 'United States dollar'}, 'cost': {'value': 200000000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 1270798}, {'$set': {'box_office': {'value': 353624124, 'currency': 'United States dollar'}, 'cost': {'value': 160000000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 119094}, {'$set': {'box_office': {'value': 245700000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 120667}, {'$set': {'box_office': {'value': 330600000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 120667}, {'$set': {'box_office': {'value': 330600000, 'currency': 'United States dollar'}, 'distributor': 'Twentieth Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 1622547}, {'$set': {'box_office': {'value': 40547440, 'currency': 'United States dollar'}, 'cost': {'value': 28000000, 'currency': 'United States dollar'}, 'distributor': 'Columbia Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 78252}, {'$set': {'box_office': {'value': 2708748, 'currency': 'Hong Kong dollar'}}}, False, None, None, None),
#  UpdateOne({'_id': 176269}, {'$set': {'box_office': {'value': 10667893, 'currency': 'United States dollar'}, 'cost': {'value': 45000000, 'currency': 'United States dollar'}, 'distributor': 'TriStar Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 1646987}, {'$set': {'box_office': {'value': 305300000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 88850}, {'$set': {'box_office': {'value': 45833132, 'currency': 'United States dollar'}, 'cost': {'value': 20000000, 'currency': 'United States dollar'}, 'distributor': 'Universal Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 160127}, {'$set': {'box_office': {'value': 264100000, 'currency': 'United States dollar'}, 'distributor': 'Columbia Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 305357}, {'$set': {'box_office': {'value': 259200000, 'currency': 'United States dollar'}, 'cost': {'value': 120000000, 'currency': 'United States dollar'}, 'distributor': 'Columbia Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 1187043}, {'$set': {'box_office': {'value': 3920000000, 'currency': 'Indian rupee'}, 'cost': {'value': 350000000, 'currency': 'Indian rupee'}, 'distributor': 'Reliance Entertainment'}}, False, None, None, None),
#  UpdateOne({'_id': 948470}, {'$set': {'box_office': {'value': 757930663, 'currency': 'United States dollar'}, 'cost': {'value': 230000000, 'currency': 'United States dollar'}, 'distributor': 'Columbia Pictures', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 948470}, {'$set': {'box_office': {'value': 757930663, 'currency': 'United States dollar'}, 'cost': {'value': 230000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 1201607}, {'$set': {'box_office': {'value': 1341511219, 'currency': 'United States dollar'}, 'distributor': 'InterCom', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 1399103}, {'$set': {'box_office': {'value': 1123794079, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 1399103}, {'$set': {'box_office': {'value': 1123794079, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 75686}, {'$set': {'box_office': {'value': 38300000, 'currency': 'United States dollar'}, 'cost': {'value': 4000000, 'currency': 'United States dollar'}, 'distributor': 'United Artists'}}, False, None, None, None),
#  UpdateOne({'_id': 876563}, {'$set': {'box_office': {'value': 202400000, 'currency': 'United States dollar'}, 'distributor': 'Tōhō'}}, False, None, None, None),
#  UpdateOne({'_id': 21749}, {'$set': {'box_office': {'value': 5000000, 'currency': 'United States dollar'}, 'cost': {'value': 1500000, 'currency': 'United States dollar'}, 'distributor': 'United Artists'}}, False, None, None, None),
#  UpdateOne({'_id': 396269}, {'$set': {'box_office': {'value': 285200000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 449010}, {'$set': {'box_office': {'value': 249500000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 162346}, {'$set': {'box_office': {'value': 8764007, 'currency': 'United States dollar'}, 'cost': {'value': 7000000, 'currency': 'United States dollar'}, 'distributor': 'Metro-Goldwyn-Mayer'}}, False, None, None, None),
#  UpdateOne({'_id': 181865}, {'$set': {'box_office': {'value': 207500000, 'currency': 'United States dollar'}, 'distributor': 'Focus Features'}}, False, None, None, None),
#  UpdateOne({'_id': 1600195}, {'$set': {'box_office': {'value': 28087155, 'currency': 'United States dollar'}, 'cost': {'value': 40000000, 'currency': 'United States dollar'}, 'distributor': 'Lionsgate Films'}}, False, None, None, None),
#  UpdateOne({'_id': 103772}, {'$set': {'box_office': {'value': 352900000, 'currency': 'United States dollar'}, 'cost': {'value': 49000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom', 'rating_label': 'R'}}, False, None, None, None),
#  UpdateOne({'_id': 103772}, {'$set': {'box_office': {'value': 352900000, 'currency': 'United States dollar'}, 'cost': {'value': 49000000, 'currency': 'United States dollar'}, 'distributor': 'Q57831015', 'rating_label': 'R'}}, False, None, None, None),
#  UpdateOne({'_id': 80855}, {'$set': {'box_office': {'value': 3484331, 'currency': 'United States dollar'}, 'cost': {'value': 44000000, 'currency': 'United States dollar'}, 'distributor': 'United Artists'}}, False, None, None, None),
#  UpdateOne({'_id': 363226}, {'$set': {'box_office': {'value': 32300000, 'currency': 'United States dollar'}, 'distributor': 'Mikado Film'}}, False, None, None, None),
#  UpdateOne({'_id': 410764}, {'$set': {'box_office': {'value': 566611, 'currency': 'United States dollar'}, 'cost': {'value': 12000000, 'currency': 'United States dollar'}, 'distributor': 'Q3881046'}}, False, None, None, None),
#  UpdateOne({'_id': 381061}, {'$set': {'box_office': {'value': 599000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 454876}, {'$set': {'box_office': {'value': 609000000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 120804}, {'$set': {'box_office': {'value': 102441078, 'currency': 'United States dollar'}, 'cost': {'value': 33000000, 'currency': 'United States dollar'}, 'distributor': 'Screen Gems'}}, False, None, None, None),
#  UpdateOne({'_id': 59578}, {'$set': {'box_office': {'value': 15000000, 'currency': 'United States dollar'}, 'cost': {'value': 600000, 'currency': 'United States dollar'}, 'distributor': 'Mokép'}}, False, None, None, None),
#  UpdateOne({'_id': 59578}, {'$set': {'box_office': {'value': 15000000, 'currency': 'United States dollar'}, 'cost': {'value': 600000, 'currency': 'United States dollar'}, 'distributor': 'Mokép'}}, False, None, None, None),
#  UpdateOne({'_id': 361748}, {'$set': {'box_office': {'value': 321455689, 'currency': 'United States dollar'}, 'cost': {'value': 70000000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 217505}, {'$set': {'box_office': {'value': 193772504, 'currency': 'United States dollar'}, 'cost': {'value': 97000000, 'currency': 'United States dollar'}, 'distributor': 'Miramax'}}, False, None, None, None),
#  UpdateOne({'_id': 1022603}, {'$set': {'box_office': {'value': 60700000, 'currency': 'United States dollar'}, 'cost': {'value': 7500000, 'currency': 'United States dollar'}, 'distributor': 'Fox Searchlight Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 370263}, {'$set': {'box_office': {'value': 172544654, 'currency': 'United States dollar'}, 'cost': {'value': 60000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 232500}, {'$set': {'box_office': {'value': 207283925, 'currency': '1'}, 'cost': {'value': 38000000, 'currency': '1'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 1001508}, {'$set': {'box_office': {'value': 178000000, 'currency': 'United States dollar'}, 'cost': {'value': 40000000, 'currency': 'United States dollar'}, 'distributor': 'New Line Cinema'}}, False, None, None, None),
#  UpdateOne({'_id': 1001508}, {'$set': {'box_office': {'value': 178000000, 'currency': 'United States dollar'}, 'cost': {'value': 40000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 106977}, {'$set': {'box_office': {'value': 368900000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 207201}, {'$set': {'box_office': {'value': 374111707, 'currency': 'United States dollar'}, 'cost': {'value': 70000000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 120912}, {'$set': {'box_office': {'value': 441818803, 'currency': 'United States dollar'}, 'distributor': 'Columbia Pictures', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 372183}, {'$set': {'box_office': {'value': 288500000, 'currency': 'United States dollar'}, 'distributor': 'Universal Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 372183}, {'$set': {'box_office': {'value': 288500000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 1034314}, {'$set': {'box_office': {'value': 8135031, 'currency': 'United States dollar'}, 'cost': {'value': 7500000, 'currency': 'United States dollar'}, 'distributor': 'Moviemax'}}, False, None, None, None),
#  UpdateOne({'_id': 985699}, {'$set': {'box_office': {'value': 200276784, 'currency': 'United States dollar'}, 'cost': {'value': 80000000, 'currency': 'United States dollar'}, 'distributor': 'Metro-Goldwyn-Mayer'}}, False, None, None, None),
#  UpdateOne({'_id': 985699}, {'$set': {'box_office': {'value': 200276784, 'currency': 'United States dollar'}, 'cost': {'value': 80000000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 985699}, {'$set': {'box_office': {'value': 200276784, 'currency': 'United States dollar'}, 'cost': {'value': 80000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 1504320}, {'$set': {'box_office': {'value': 414200000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 1099212}, {'$set': {'box_office': {'value': 393600000, 'currency': 'United States dollar'}, 'distributor': 'Summit Entertainment'}}, False, None, None, None),
#  UpdateOne({'_id': 360717}, {'$set': {'box_office': {'value': 550517357, 'currency': 'United States dollar'}, 'cost': {'value': 207000000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 382625}, {'$set': {'box_office': {'value': 758200000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 388795}, {'$set': {'box_office': {'value': 178000000, 'currency': 'United States dollar'}, 'cost': {'value': 14000000, 'currency': 'United States dollar'}, 'distributor': 'Focus Features'}}, False, None, None, None),
#  UpdateOne({'_id': 318627}, {'$set': {'box_office': {'value': 129300000, 'currency': 'United States dollar'}, 'distributor': 'Screen Gems'}}, False, None, None, None),
#  UpdateOne({'_id': 926084}, {'$set': {'box_office': {'value': 960431568, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 926084}, {'$set': {'box_office': {'value': 960431568, 'currency': 'United States dollar'}, 'distributor': 'InterCom', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 417741}, {'$set': {'box_office': {'value': 934546568, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.', 'rating_label': 'PG'}}, False, None, None, None),
#  UpdateOne({'_id': 417741}, {'$set': {'box_office': {'value': 934546568, 'currency': 'United States dollar'}, 'distributor': 'InterCom', 'rating_label': 'PG'}}, False, None, None, None),
#  UpdateOne({'_id': 88247}, {'$set': {'box_office': {'value': 78371200, 'currency': 'United States dollar'}, 'cost': {'value': 6400000, 'currency': 'United States dollar'}, 'distributor': 'Orion Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 346491}, {'$set': {'box_office': {'value': 167298192, 'currency': 'United States dollar'}, 'cost': {'value': 155000000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 74285}, {'$set': {'box_office': {'value': 33800000, 'currency': 'United States dollar'}, 'cost': {'value': 1800000, 'currency': 'United States dollar'}, 'distributor': 'United Artists'}}, False, None, None, None),
#  UpdateOne({'_id': 112573}, {'$set': {'box_office': {'value': 213200000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 112573}, {'$set': {'box_office': {'value': 213200000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 54215}, {'$set': {'box_office': {'value': 40000000, 'currency': 'United States dollar'}, 'cost': {'value': 800000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 389557}, {'$set': {'box_office': {'value': 26768563, 'currency': 'United States dollar'}, 'cost': {'value': 21000000, 'currency': 'United States dollar'}}}, False, None, None, None),
#  UpdateOne({'_id': 468569}, {'$set': {'box_office': {'value': 1004558444, 'currency': 'United States dollar'}, 'cost': {'value': 185000000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 468569}, {'$set': {'box_office': {'value': 1004558444, 'currency': 'United States dollar'}, 'cost': {'value': 185000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 443649}, {'$set': {'box_office': {'value': 269800000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 268978}, {'$set': {'box_office': {'value': 313500000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 396171}, {'$set': {'box_office': {'value': 135000000, 'currency': 'United States dollar'}, 'cost': {'value': 60000000, 'currency': 'United States dollar'}, 'distributor': 'DreamWorks'}}, False, None, None, None),
#  UpdateOne({'_id': 167261}, {'$set': {'box_office': {'value': 926047111, 'currency': 'United States dollar'}, 'cost': {'value': 94000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 266697}, {'$set': {'box_office': {'value': 180949045, 'currency': 'United States dollar'}, 'cost': {'value': 30000000, 'currency': 'United States dollar'}, 'distributor': 'Miramax'}}, False, None, None, None),
#  UpdateOne({'_id': 280707}, {'$set': {'box_office': {'value': 87700000, 'currency': 'United States dollar'}, 'cost': {'value': 19800000, 'currency': 'United States dollar'}, 'distributor': 'Focus Features'}}, False, None, None, None),
#  UpdateOne({'_id': 237993}, {'$set': {'box_office': {'value': 126, 'currency': 'United States dollar'}}}, False, None, None, None),
#  UpdateOne({'_id': 1527186}, {'$set': {'box_office': {'value': 15946321, 'currency': 'United States dollar'}, 'cost': {'value': 7400000, 'currency': 'United States dollar'}, 'distributor': 'BiM Distribuzione'}}, False, None, None, None),
#  UpdateOne({'_id': 120815}, {'$set': {'box_office': {'value': 481840909, 'currency': 'United States dollar'}, 'cost': {'value': 70000000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 372784}, {'$set': {'box_office': {'value': 374218673, 'currency': 'United States dollar'}, 'cost': {'value': 150000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 107290}, {'$set': {'box_office': {'value': 1029528120, 'currency': 'United States dollar'}, 'cost': {'value': 63000000, 'currency': 'United States dollar'}, 'distributor': 'Universal Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 147800}, {'$set': {'box_office': {'value': 893344, 'currency': 'euro'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 466399}, {'$set': {'box_office': {'value': 3000000, 'currency': 'Australian dollar'}, 'distributor': 'Palace Films and Cinemas'}}, False, None, None, None),
#  UpdateOne({'_id': 182789}, {'$set': {'box_office': {'value': 87400000, 'currency': 'United States dollar'}, 'cost': {'value': 100000000, 'currency': 'United States dollar'}, 'distributor': 'Walt Disney Studios Motion Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 103064}, {'$set': {'box_office': {'value': 520881154, 'currency': 'United States dollar'}, 'cost': {'value': 102000000, 'currency': 'United States dollar'}, 'distributor': 'TriStar Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 103064}, {'$set': {'box_office': {'value': 520881154, 'currency': 'United States dollar'}, 'cost': {'value': 102000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 418279}, {'$set': {'box_office': {'value': 709700000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 418279}, {'$set': {'box_office': {'value': 709700000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 1408101}, {'$set': {'box_office': {'value': 467381584, 'currency': 'United States dollar'}, 'cost': {'value': 190000000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 1408101}, {'$set': {'box_office': {'value': 467381584, 'currency': 'United States dollar'}, 'cost': {'value': 190000000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 1655442}, {'$set': {'box_office': {'value': 133432856, 'currency': 'United States dollar'}, 'cost': {'value': 15000000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 1655442}, {'$set': {'box_office': {'value': 133432856, 'currency': 'United States dollar'}, 'cost': {'value': 15000000, 'currency': 'United States dollar'}, 'distributor': 'Fórum Hungary'}}, False, None, None, None),
#  UpdateOne({'_id': 1655442}, {'$set': {'box_office': {'value': 133432856, 'currency': 'United States dollar'}, 'cost': {'value': 15000000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros. France'}}, False, None, None, None),
#  UpdateOne({'_id': 111161}, {'$set': {'box_office': {'value': 59800000, 'currency': 'United States dollar'}, 'cost': {'value': 25000000, 'currency': 'United States dollar'}, 'distributor': 'Columbia Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 407887}, {'$set': {'box_office': {'value': 291500000, 'currency': 'United States dollar'}, 'distributor': 'InterCom', 'rating_label': 'R'}}, False, None, None, None),
#  UpdateOne({'_id': 82971}, {'$set': {'box_office': {'value': 389900000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 82971}, {'$set': {'box_office': {'value': 389900000, 'currency': 'United States dollar'}, 'distributor': 'Mokép'}}, False, None, None, None),
#  UpdateOne({'_id': 1542344}, {'$set': {'box_office': {'value': 60000000, 'currency': 'United States dollar'}, 'cost': {'value': 18000000, 'currency': 'United States dollar'}, 'distributor': 'Fox Searchlight Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 488478}, {'$set': {'box_office': {'value': 7537453, 'currency': 'United States dollar'}, 'cost': {'value': 2500000, 'currency': 'United States dollar'}, 'distributor': '01 Distribution'}}, False, None, None, None),
#  UpdateOne({'_id': 114746}, {'$set': {'box_office': {'value': 168839459, 'currency': 'United States dollar'}, 'cost': {'value': 29500000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 377800}, {'$set': {'box_office': {'value': 4600000, 'currency': 'United States dollar'}, 'cost': {'value': 11000000, 'currency': 'United States dollar'}, 'distributor': 'Sony Pictures Classics'}}, False, None, None, None),
#  UpdateOne({'_id': 220506}, {'$set': {'box_office': {'value': 37664855, 'currency': 'United States dollar'}, 'distributor': 'Miramax'}}, False, None, None, None),
#  UpdateOne({'_id': 220506}, {'$set': {'box_office': {'value': 37664855, 'currency': 'United States dollar'}, 'distributor': 'Dimension Films'}}, False, None, None, None),
#  UpdateOne({'_id': 455590}, {'$set': {'box_office': {'value': 48363516, 'currency': 'United States dollar'}, 'cost': {'value': 6000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom', 'rating_label': 'R'}}, False, None, None, None),
# ...
#  UpdateOne({'_id': 98258}, {'$set': {'box_office': {'value': 21500000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 1540133}, {'$set': {'box_office': {'value': 17600000, 'currency': 'United States dollar'}, 'cost': {'value': 6000000, 'currency': 'United States dollar'}, 'distributor': 'Eagle Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 459759}, {'$set': {'box_office': {'value': 12859418, 'currency': 'United States dollar'}, 'cost': {'value': 6000000, 'currency': 'United States dollar'}}}, False, None, None, None),
#  UpdateOne({'_id': 77531}, {'$set': {'box_office': {'value': 20400000, 'currency': 'United States dollar'}, 'cost': {'value': 11000000, 'currency': 'United States dollar'}, 'distributor': 'United Artists'}}, False, None, None, None),
#  UpdateOne({'_id': 822847}, {'$set': {'box_office': {'value': 78309131, 'currency': 'United States dollar'}, 'cost': {'value': 60000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 250797}, {'$set': {'box_office': {'value': 119137784, 'currency': 'United States dollar'}, 'cost': {'value': 50000000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 97474}, {'$set': {'box_office': {'value': 11642254, 'currency': 'United States dollar'}}}, False, None, None, None),
#  UpdateOne({'_id': 844286}, {'$set': {'box_office': {'value': 5500000, 'currency': 'United States dollar'}, 'cost': {'value': 20000000, 'currency': 'United States dollar'}, 'distributor': 'Summit Entertainment'}}, False, None, None, None),
#  UpdateOne({'_id': 844286}, {'$set': {'box_office': {'value': 5500000, 'currency': 'United States dollar'}, 'cost': {'value': 20000000, 'currency': 'United States dollar'}, 'distributor': 'Budapest Film'}}, False, None, None, None),
#  UpdateOne({'_id': 103241}, {'$set': {'box_office': {'value': 63707829, 'currency': 'United States dollar'}, 'cost': {'value': 35000000, 'currency': 'United States dollar'}, 'distributor': 'Walt Disney Studios Motion Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 110200}, {'$set': {'box_office': {'value': 16060576, 'currency': 'Hong Kong dollar'}, 'distributor': 'Orange Sky Golden Harvest'}}, False, None, None, None),
#  UpdateOne({'_id': 90956}, {'$set': {'box_office': {'value': 21606063, 'currency': 'Hong Kong dollar'}, 'distributor': 'Orange Sky Golden Harvest'}}, False, None, None, None),
#  UpdateOne({'_id': 403358}, {'$set': {'box_office': {'value': 33899078, 'currency': 'United States dollar'}, 'cost': {'value': 1800000, 'currency': 'United States dollar'}}}, False, None, None, None),
#  UpdateOne({'_id': 112642}, {'$set': {'box_office': {'value': 287900000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 164912}, {'$set': {'box_office': {'value': 300100000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 1253864}, {'$set': {'box_office': {'value': 226900000, 'currency': 'United States dollar'}, 'distributor': 'Relativity Media'}}, False, None, None, None),
#  UpdateOne({'_id': 239395}, {'$set': {'box_office': {'value': 200700000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 298814}, {'$set': {'box_office': {'value': 60000000, 'currency': 'United States dollar'}, 'cost': {'value': 73498611, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 362120}, {'$set': {'box_office': {'value': 178710620, 'currency': 'United States dollar'}, 'distributor': 'Fórum Hungary'}}, False, None, None, None),
#  UpdateOne({'_id': 90293}, {'$set': {'box_office': {'value': 1918117, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 118694}, {'$set': {'box_office': {'value': 2734044, 'currency': 'United States dollar'}, 'distributor': 'Universal Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 1778304}, {'$set': {'box_office': {'value': 207000000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 1397280}, {'$set': {'box_office': {'value': 376100000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 1397280}, {'$set': {'box_office': {'value': 376100000, 'currency': 'United States dollar'}, 'distributor': 'EuropaCorp'}}, False, None, None, None),
#  UpdateOne({'_id': 419887}, {'$set': {'box_office': {'value': 73200000, 'currency': 'United States dollar'}, 'cost': {'value': 20000000, 'currency': 'United States dollar'}, 'distributor': 'DreamWorks'}}, False, None, None, None),
#  UpdateOne({'_id': 93894}, {'$set': {'box_office': {'value': 38122105, 'currency': 'United States dollar'}, 'cost': {'value': 27000000, 'currency': 'United States dollar'}, 'distributor': 'TriStar Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 116705}, {'$set': {'box_office': {'value': 129832389, 'currency': 'United States dollar'}, 'cost': {'value': 75000000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 20960}, {'$set': {'box_office': {'value': 8000000, 'currency': 'United States dollar'}, 'cost': {'value': 3950000, 'currency': 'United States dollar'}, 'distributor': 'United Artists'}}, False, None, None, None),
#  UpdateOne({'_id': 1352824}, {'$set': {'box_office': {'value': 11702642, 'currency': 'United States dollar'}, 'distributor': 'Sony Pictures Classics'}}, False, None, None, None),
#  UpdateOne({'_id': 1024715}, {'$set': {'box_office': {'value': 3980000, 'currency': 'United States dollar'}, 'cost': {'value': 3000000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 432637}, {'$set': {'box_office': {'value': 18000000, 'currency': 'United States dollar'}, 'cost': {'value': 10000000, 'currency': 'United States dollar'}, 'distributor': 'Yash Raj Films'}}, False, None, None, None),
#  UpdateOne({'_id': 1631867}, {'$set': {'box_office': {'value': 370500000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 1204340}, {'$set': {'box_office': {'value': 244500, 'currency': 'pound sterling'}, 'cost': {'value': 750000, 'currency': 'pound sterling'}, 'distributor': 'StudioCanal UK'}}, False, None, None, None),
#  UpdateOne({'_id': 1465487}, {'$set': {'box_office': {'value': 41000000, 'currency': 'United States dollar'}, 'cost': {'value': 8700000, 'currency': 'United States dollar'}, 'distributor': 'Lucky Red Distribuzione'}}, False, None, None, None),
#  UpdateOne({'_id': 1465487}, {'$set': {'box_office': {'value': 41000000, 'currency': 'United States dollar'}, 'cost': {'value': 8700000, 'currency': 'United States dollar'}, 'distributor': 'Budapest Film'}}, False, None, None, None),
#  UpdateOne({'_id': 181316}, {'$set': {'box_office': {'value': 117758500, 'currency': 'United States dollar'}, 'cost': {'value': 65000000, 'currency': 'United States dollar'}, 'distributor': 'Columbia Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 167132}, {'$set': {'box_office': {'value': 5000000, 'currency': 'United States dollar'}}}, False, None, None, None),
#  UpdateOne({'_id': 1587707}, {'$set': {'box_office': {'value': 5300000, 'currency': 'United States dollar'}, 'distributor': 'Revolver Entertainment'}}, False, None, None, None),
#  UpdateOne({'_id': 481369}, {'$set': {'box_office': {'value': 77566815, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 481369}, {'$set': {'box_office': {'value': 77566815, 'currency': 'United States dollar'}, 'distributor': 'New Line Home Entertainment'}}, False, None, None, None),
#  UpdateOne({'_id': 816462}, {'$set': {'box_office': {'value': 48795021, 'currency': 'United States dollar'}, 'cost': {'value': 80000000, 'currency': 'United States dollar'}, 'distributor': 'Lions Gate Entertainment'}}, False, None, None, None),
#  UpdateOne({'_id': 311113}, {'$set': {'box_office': {'value': 212000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 433362}, {'$set': {'box_office': {'value': 50011441, 'currency': 'United States dollar'}, 'cost': {'value': 20000000, 'currency': 'United States dollar'}, 'distributor': 'Lions Gate Entertainment'}}, False, None, None, None),
#  UpdateOne({'_id': 433362}, {'$set': {'box_office': {'value': 50011441, 'currency': 'United States dollar'}, 'cost': {'value': 20000000, 'currency': 'United States dollar'}, 'distributor': 'Budapest Film'}}, False, None, None, None),
#  UpdateOne({'_id': 1263670}, {'$set': {'box_office': {'value': 47400000, 'currency': 'United States dollar'}, 'cost': {'value': 7000000, 'currency': 'United States dollar'}, 'distributor': 'Fox Searchlight Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 822832}, {'$set': {'box_office': {'value': 242700000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 822832}, {'$set': {'box_office': {'value': 242700000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 120902}, {'$set': {'box_office': {'value': 105300000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 419946}, {'$set': {'box_office': {'value': 25800000, 'currency': 'United States dollar'}, 'cost': {'value': 22000000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  UpdateOne({'_id': 417397}, {'$set': {'box_office': {'value': 25555809, 'currency': 'United States dollar'}, 'cost': {'value': 9500000, 'currency': 'United States dollar'}}}, False, None, None, None),
#  UpdateOne({'_id': 107507}, {'$set': {'box_office': {'value': 11300000, 'currency': 'United States dollar'}, 'cost': {'value': 13500000, 'currency': 'United States dollar'}, 'distributor': 'TriStar Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 1616195}, {'$set': {'box_office': {'value': 84600000, 'currency': 'United States dollar'}, 'cost': {'value': 35000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 113101}, {'$set': {'box_office': {'value': 4257354, 'currency': 'United States dollar'}, 'cost': {'value': 4000000, 'currency': 'United States dollar'}, 'distributor': 'Miramax'}}, False, None, None, None),
#  UpdateOne({'_id': 113253}, {'$set': {'box_office': {'value': 15116634, 'currency': 'United States dollar'}, 'distributor': 'Dimension Films'}}, False, None, None, None),
#  UpdateOne({'_id': 120157}, {'$set': {'box_office': {'value': 15000000, 'currency': 'United States dollar'}, 'cost': {'value': 75000000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 69089}, {'$set': {'box_office': {'value': 6000000, 'currency': 'United States dollar'}, 'cost': {'value': 10000, 'currency': 'United States dollar'}, 'distributor': 'New Line Cinema'}}, False, None, None, None),
#  UpdateOne({'_id': 92493}, {'$set': {'box_office': {'value': 239606210, 'currency': 'United States dollar'}, 'cost': {'value': 9000000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 1595656}, {'$set': {'box_office': {'value': 2783139, 'currency': 'United States dollar'}, 'distributor': 'Magnolia Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 122933}, {'$set': {'box_office': {'value': 176880000, 'currency': 'United States dollar'}, 'cost': {'value': 80000000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 18253}, {'$set': {'box_office': {'value': 1200000, 'currency': 'United States dollar'}, 'distributor': 'First National'}}, False, None, None, None),
#  UpdateOne({'_id': 1064932}, {'$set': {'box_office': {'value': 245000000, 'currency': 'United States dollar'}, 'cost': {'value': 11000000, 'currency': 'United States dollar'}, 'distributor': 'Pathé Distribution'}}, False, None, None, None),
#  UpdateOne({'_id': 245562}, {'$set': {'box_office': {'value': 77628265, 'currency': 'United States dollar'}, 'cost': {'value': 115000000, 'currency': 'United States dollar'}, 'distributor': 'Metro-Goldwyn-Mayer'}}, False, None, None, None),
#  UpdateOne({'_id': 117665}, {'$set': {'box_office': {'value': 165615285, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 1583421}, {'$set': {'box_office': {'value': 375700000, 'currency': 'United States dollar'}, 'distributor': 'UIP-Dunafilm'}}, False, None, None, None),
#  UpdateOne({'_id': 102685}, {'$set': {'box_office': {'value': 83000000, 'currency': 'United States dollar'}, 'cost': {'value': 24000000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox', 'rating_label': 'R'}}, False, None, None, None),
#  UpdateOne({'_id': 52365}, {'$set': {'box_office': {'value': 6000000, 'currency': 'United States dollar'}, 'cost': {'value': 3500000, 'currency': 'United States dollar'}, 'distributor': 'United Artists'}}, False, None, None, None),
#  UpdateOne({'_id': 163187}, {'$set': {'box_office': {'value': 309457509, 'currency': 'United States dollar'}, 'distributor': 'Walt Disney Studios Motion Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 467197}, {'$set': {'box_office': {'value': 85416905, 'currency': 'United States dollar'}, 'cost': {'value': 35000000, 'currency': 'United States dollar'}, 'distributor': 'InterCom'}}, False, None, None, None),
#  UpdateOne({'_id': 1068242}, {'$set': {'box_office': {'value': 62701289, 'currency': 'United States dollar'}, 'cost': {'value': 24000000, 'currency': 'United States dollar'}, 'distributor': 'Paramount Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 2215719}, {'$set': {'box_office': {'value': 32726956, 'currency': 'United States dollar'}, 'cost': {'value': 13000000, 'currency': 'United States dollar'}, 'distributor': 'Universal Pictures'}}, False, None, None, None),
#  UpdateOne({'_id': 75213}, {'$set': {'box_office': {'value': 6000000, 'currency': 'United States dollar'}, 'distributor': 'Titanus'}}, False, None, None, None),
#  UpdateOne({'_id': 78350}, {'$set': {'box_office': {'value': 7600000, 'currency': 'United States dollar'}, 'cost': {'value': 21000000, 'currency': 'United States dollar'}, 'distributor': 'Warner Bros.'}}, False, None, None, None),
#  UpdateOne({'_id': 1403988}, {'$set': {'box_office': {'value': 123820, 'currency': 'United States dollar'}, 'cost': {'value': 4500000, 'currency': 'United States dollar'}}}, False, None, None, None),
#  UpdateOne({'_id': 1981115}, {'$set': {'box_office': {'value': 644571402, 'currency': 'United States dollar'}, 'cost': {'value': 170000000, 'currency': 'United States dollar'}, 'distributor': 'Walt Disney Studios Motion Pictures', 'rating_label': 'PG-13'}}, False, None, None, None),
#  UpdateOne({'_id': 92615}, {'$set': {'box_office': {'value': 800000, 'currency': 'United States dollar'}, 'cost': {'value': 800000, 'currency': 'United States dollar'}}}, False, None, None, None),
#  UpdateOne({'_id': 51622}, {'$set': {'box_office': {'value': 3000000, 'currency': 'United States dollar'}, 'cost': {'value': 495000, 'currency': 'United States dollar'}, 'distributor': '20th Century Fox'}}, False, None, None, None),
#  ...]

# %%
len(requests)
# Out:
# 49039

# %% [markdown]
# ## Updating JSON data to IMDB MongoDB

# %% [markdown]
# ### Connecting to IMDB MongoDB

# %%
connection_string = "mongodb://" + mongo_config['host'] + ":" + mongo_config['port']
mongo_client = pymongo.MongoClient(connection_string)
imdb = mongo_client[mongo_config['database']]
imdb
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'imdb')

# %%
movie_collection = imdb['Movies']

# %% [markdown]
# ### Bulk writing Update operations to IMDB

# %%
output = movie_collection.bulk_write(requests)

# %%
output.bulk_api_result
# Out:
# {'writeErrors': [],
#  'writeConcernErrors': [],
#  'nInserted': 0,
#  'nUpserted': 0,
#  'nMatched': 48879,
#  'nModified': 48437,
#  'nRemoved': 0,
#  'upserted': []}
