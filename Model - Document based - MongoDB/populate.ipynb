# %% [markdown]
# ### Import Libraries

# %%
import psycopg2
import psycopg2.extras
import configparser as configparser
import pandas as pd
import pymongo
import json
from decimal import Decimal

# %% [markdown]
# ## Parsing INI File

# %% [markdown]
# ### Funtion: To parse INI file

# %%
def parse_ini(section: str) -> dict:
    """
    This function parses ini file for configuration details
    :param section: section to read from ini
    :return: Dictionary of config details
    """
    config = dict()
    parser = configparser.ConfigParser()
    parser.read("imdb_database.ini")
    if parser.has_section(section):
        config_items = parser.items(section)
        for item in config_items:
            config[item[0]] = item[1]
    return config

# %%
sql_config = parse_ini("postgresql")
sql_config
# Out:
# {'host': 'localhost',
#  'database': 'imdb',
#  'user': 'postgres',
#  'password': '1997',
#  'port': '5432'}

# %%
mongo_config = parse_ini("mongodb")
mongo_config
# Out:
# {'host': 'localhost', 'database': 'imdb', 'port': '27017'}

# %% [markdown]
# ## Fetching data from IMDB SQL DB

# %% [markdown]
# ### Function: To connect to IMDB database and run select query to fetch from IMDB SQL Database

# %%
def run_sql(query: str):
    with psycopg2.connect(**sql_config) as conn:
        try:
            dataframe = pd.read_sql_query(query, conn)
            print("The query results loaded to Dataframe")
        except (Exception, psycopg2.DatabaseError) as error:
            print("SQL Exception:" + str(error))
            return None
    return dataframe

# %%
def fetch_sql(query: str):
    with psycopg2.connect(**sql_config) as conn:
        conn.autocommit = True
        cursor = conn.cursor()
        try:
            cursor.execute(query)
            results = cursor.fetchall()
            return results
        except (Exception, psycopg2.DatabaseError) as error:
            print("SQL Exception:" + str(error))
        finally:
            cursor.close()

# %% [markdown]
# ### Fetching members table as JSON dictionary from IMDB SQL DB

# %%
query = '''SELECT id AS _id, name, birthyear, deathyear
	FROM member'''
members = fetch_sql(query)
members
# Out:
# [(1, 'Fred Astaire', 1899, 1987),
#  (2, 'Lauren Bacall', 1924, 2014),
#  (3, 'Brigitte Bardot', 1934, None),
#  (4, 'John Belushi', 1949, 1982),
#  (5, 'Ingmar Bergman', 1918, 2007),
#  (6, 'Ingrid Bergman', 1915, 1982),
#  (7, 'Humphrey Bogart', 1899, 1957),
#  (8, 'Marlon Brando', 1924, 2004),
#  (9, 'Richard Burton', 1925, 1984),
#  (10, 'James Cagney', 1899, 1986),
#  (11, 'Gary Cooper', 1901, 1961),
#  (12, 'Bette Davis', 1908, 1989),
#  (13, 'Doris Day', 1922, 2019),
#  (14, 'Olivia de Havilland', 1916, 2020),
#  (15, 'James Dean', 1931, 1955),
#  (16, 'Georges Delerue', 1925, 1992),
#  (17, 'Marlene Dietrich', 1901, 1992),
#  (18, 'Kirk Douglas', 1916, 2020),
#  (19, 'Federico Fellini', 1920, 1993),
#  (20, 'Henry Fonda', 1905, 1982),
#  (21, 'Joan Fontaine', 1917, 2013),
#  (22, 'Clark Gable', 1901, 1960),
#  (23, 'Judy Garland', 1922, 1969),
#  (24, 'John Gielgud', 1904, 2000),
#  (25, 'Jerry Goldsmith', 1929, 2004),
#  (26, 'Cary Grant', 1904, 1986),
#  (27, 'Alec Guinness', 1914, 2000),
#  (28, 'Rita Hayworth', 1918, 1987),
#  (29, 'Margaux Hemingway', 1954, 1996),
#  (30, 'Audrey Hepburn', 1929, 1993),
#  (31, 'Katharine Hepburn', 1907, 2003),
#  (32, 'Charlton Heston', 1923, 2008),
#  (33, 'Alfred Hitchcock', 1899, 1980),
#  (34, 'William Holden', 1918, 1981),
#  (35, 'James Horner', 1953, 2015),
#  (36, 'Buster Keaton', 1895, 1966),
#  (37, 'Gene Kelly', 1912, 1996),
#  (38, 'Grace Kelly', 1929, 1982),
#  (39, 'Deborah Kerr', 1921, 2007),
#  (40, 'Stanley Kubrick', 1928, 1999),
#  (41, 'Akira Kurosawa', 1910, 1998),
#  (42, 'Alan Ladd', 1913, 1964),
#  (43, 'Veronica Lake', 1922, 1973),
#  (44, 'Burt Lancaster', 1913, 1994),
#  (45, 'Bruce Lee', 1940, 1973),
#  (46, 'Vivien Leigh', 1913, 1967),
#  (47, 'Sophia Loren', 1934, None),
#  (48, 'Peter Lorre', 1904, 1964),
#  (49, 'Henry Mancini', 1924, 1994),
#  (50, 'Groucho Marx', 1890, 1977),
#  (51, 'James Mason', 1909, 1984),
#  (52, 'Marcello Mastroianni', 1924, 1996),
#  (53, 'Robert Mitchum', 1917, 1997),
#  (54, 'Marilyn Monroe', 1926, 1962),
#  (55, 'Alfred Newman', 1900, 1970),
#  (56, 'Paul Newman', 1925, 2008),
#  (57, 'David Niven', 1910, 1983),
#  (58, "Maureen O'Hara", 1920, 2015),
#  (59, 'Laurence Olivier', 1907, 1989),
#  (60, 'Gregory Peck', 1916, 2003),
#  (61, 'Tyrone Power', 1914, 1958),
#  (62, 'Elvis Presley', 1935, 1977),
#  (63, 'Anthony Quinn', 1915, 2001),
#  (64, 'Edward G. Robinson', 1893, 1973),
#  (65, 'Nino Rota', 1911, 1979),
#  (66, 'Jane Russell', 1921, 2011),
#  (67, 'Miklós Rózsa', 1907, 1995),
#  (68, 'Randolph Scott', 1898, 1987),
#  (69, 'Frank Sinatra', 1915, 1998),
#  (70, 'Max Steiner', 1888, 1971),
#  (71, 'James Stewart', 1908, 1997),
#  (72, 'Elizabeth Taylor', 1932, 2011),
#  (73, 'Shirley Temple', 1928, 2014),
#  (74, 'Gene Tierney', 1920, 1991),
#  (75, 'Spencer Tracy', 1900, 1967),
#  (76, 'François Truffaut', 1932, 1984),
#  (77, 'Franz Waxman', 1906, 1967),
#  (78, 'John Wayne', 1907, 1979),
#  (79, 'Raquel Welch', 1940, None),
#  (80, 'Orson Welles', 1915, 1985),
#  (81, 'Natalie Wood', 1938, 1981),
#  (82, 'Victor Young', 1900, 1956),
#  (83, 'Alan Miller', None, None),
#  (84, 'Gong Li', 1965, None),
#  (85, 'Henner Hofmann', 1950, None),
#  (86, 'Louis de Funès', 1914, 1983),
#  (87, 'Elena Koreneva', 1953, None),
#  (88, 'Aleksey Korenev', 1927, 1995),
#  (89, 'Richard Paul', 1940, 1998),
#  (90, 'Armin Mueller-Stahl', 1930, None),
#  (91, 'Gérard Pirès', 1942, None),
#  (92, 'John Cleese', 1939, None),
#  (93, 'Brad Pitt', 1963, None),
#  (94, 'J. Reifel', None, None),
#  (95, 'Woody Allen', 1935, None),
#  (96, 'Gillian Anderson', 1968, None),
#  (97, 'Pamela Anderson', 1967, None),
#  (98, 'Jennifer Aniston', 1969, None),
#  (99, 'Patricia Arquette', 1968, None),
#  (100, 'Rowan Atkinson', 1955, None),
#  (101, 'Dan Aykroyd', 1952, None),
#  (102, 'Kevin Bacon', 1958, None),
#  (103, 'Fairuza Balk', 1974, None),
#  (104, 'Antonio Banderas', 1960, None),
#  (105, 'Adrienne Barbeau', 1945, None),
#  (106, 'Drew Barrymore', 1975, None),
#  (107, 'Kim Basinger', 1953, None),
#  (108, 'Luc Besson', 1959, None),
#  (109, 'Yasmine Bleeth', 1968, None),
#  (110, 'Kenneth Branagh', 1960, None),
#  (111, 'Matthew Broderick', 1962, None),
#  (112, 'Pierce Brosnan', 1953, None),
#  (113, 'Sandra Bullock', 1964, None),
#  (114, 'Steve Buscemi', 1957, None),
#  (115, 'Nicolas Cage', 1964, None),
#  (116, 'James Cameron', 1954, None),
#  (117, 'Neve Campbell', 1973, None),
#  (118, 'John Carpenter', 1948, None),
#  (119, 'Tia Carrere', 1967, None),
#  (120, 'Jim Carrey', 1962, None),
#  (121, 'Phoebe Cates', 1963, None),
#  (122, 'Charles Chaplin', 1889, 1977),
#  (123, 'George Clooney', 1961, None),
#  (124, 'Jennifer Connelly', 1970, None),
#  (125, 'Sean Connery', 1930, 2020),
#  (126, 'Kevin Costner', 1955, None),
#  (127, 'Wes Craven', 1939, 2015),
#  (128, 'Russell Crowe', 1964, None),
#  (129, 'Tom Cruise', 1962, None),
#  (130, 'Jamie Lee Curtis', 1958, None),
#  (131, 'John Cusack', 1966, None),
#  (132, 'Claire Danes', 1979, None),
#  (133, 'Geena Davis', 1956, None),
#  (134, 'Robert De Niro', 1943, None),
#  (135, 'John Denver', 1943, 1997),
#  (136, 'Johnny Depp', 1963, None),
#  (137, 'Bo Derek', 1956, None),
#  (138, 'Leonardo DiCaprio', 1974, None),
#  (139, 'Cameron Diaz', 1972, None),
#  (140, 'Michael Douglas', 1944, None),
#  (141, 'David Duchovny', 1960, None),
#  (142, 'Clint Eastwood', 1930, None),
#  (143, 'Erika Eleniak', 1969, None),
#  (144, 'Cary Elwes', 1962, None),
#  (145, 'Sherilyn Fenn', 1965, None),
#  (146, 'Ralph Fiennes', 1962, None),
#  (147, 'Colin Firth', 1960, None),
#  (148, 'Harrison Ford', 1942, None),
#  (149, 'Jodie Foster', 1962, None),
#  (150, 'Michael J. Fox', 1961, None),
#  (151, 'Morgan Freeman', 1937, None),
#  (152, 'Richard Gere', 1949, None),
#  (153, 'Gina Gershon', 1962, None),
#  (154, 'Mel Gibson', 1956, None),
#  (155, 'Whoopi Goldberg', 1955, None),
#  (156, 'Jeff Goldblum', 1952, None),
#  (157, 'Linda Hamilton', 1956, None),
#  (158, 'Tom Hanks', 1956, None),
#  (159, 'Teri Hatcher', 1964, None),
#  (160, 'Ethan Hawke', 1970, None),
#  (161, 'Salma Hayek', 1966, None),
#  (162, 'Anne Heche', 1969, 2022),
#  (163, 'Dustin Hoffman', 1937, None),
#  (164, 'Anthony Hopkins', 1937, None),
#  (165, 'Ron Howard', 1954, None),
#  (166, 'Helen Hunt', 1963, None),
#  (167, 'Elizabeth Hurley', 1965, None),
#  (168, 'Samuel L. Jackson', 1948, None),
#  (169, 'Tommy Lee Jones', 1946, None),
#  (170, 'Milla Jovovich', 1975, None),
#  (171, 'Ashley Judd', 1968, None),
#  (172, 'Harvey Keitel', 1939, None),
#  (173, 'Nicole Kidman', 1967, None),
#  (174, 'Val Kilmer', 1959, None),
#  (175, 'Stephen King', 1947, None),
#  (176, 'Nastassja Kinski', 1961, None),
#  (177, 'Kevin Kline', 1947, None),
#  (178, 'Diane Lane', 1965, None),
#  (179, 'Jude Law', 1972, None),
#  (180, 'David Lean', 1908, 1991),
#  (181, 'Heather Locklear', 1961, None),
#  (182, 'Jennifer Lopez', 1969, None),
#  (183, 'Traci Lords', 1968, None),
#  (184, 'George Lucas', 1944, None),
#  (185, 'Dolph Lundgren', 1957, None),
#  (186, 'David Lynch', 1946, None),
#  (187, 'Madonna', 1958, None),
#  (188, 'Steve Martin', 1945, None),
#  (189, 'Jenny McCarthy-Wahlberg', 1972, None),
#  (190, 'Matthew McConaughey', 1969, None),
#  (191, 'Ewan McGregor', 1971, None),
#  (192, 'Alyssa Milano', 1972, None),
#  (193, 'Demi Moore', 1962, None),
#  (194, 'Julianne Moore', 1960, None),
#  (195, 'Bill Murray', 1950, None),
#  (196, 'Mike Myers', 1963, None),
#  (197, 'Jack Nicholson', 1937, None),
#  (198, 'Gary Oldman', 1958, None),
#  (199, 'Al Pacino', 1940, None),
#  (200, 'Bill Paxton', 1955, 2017),
#  (201, 'Michelle Pfeiffer', 1958, None),
#  (202, 'Ryan Phillippe', 1974, None),
#  (203, 'River Phoenix', 1970, 1993),
#  (204, 'Natalie Portman', 1981, None),
#  (205, 'Parker Posey', 1968, None),
#  (206, 'Keanu Reeves', 1964, None),
#  (207, 'Christina Ricci', 1980, None),
#  (208, 'Molly Ringwald', 1968, None),
#  (209, 'Tim Robbins', 1958, None),
#  (210, 'Julia Roberts', 1967, None),
#  (211, 'Mimi Rogers', 1956, None),
#  (212, 'Meg Ryan', 1961, None),
#  (213, 'Winona Ryder', 1971, None),
#  (214, 'Mia Sara', 1967, None),
#  (215, 'Susan Sarandon', 1946, None),
#  (216, 'Arnold Schwarzenegger', 1947, None),
#  (217, 'Martin Scorsese', 1942, None),
#  (218, 'Kristin Scott Thomas', 1960, None),
#  (219, 'Steven Seagal', 1952, None),
#  (220, 'Joan Severance', 1958, None),
#  (221, 'Charlie Sheen', 1965, None),
#  (222, 'Brooke Shields', 1965, None),
#  (223, 'Elisabeth Shue', 1963, None),
#  (224, 'Alicia Silverstone', 1976, None),
#  (225, 'Christian Slater', 1969, None),
#  (226, 'Will Smith', 1968, None),
#  (227, 'Mira Sorvino', 1967, None),
#  (228, 'Kevin Spacey', 1959, None),
#  (229, 'Steven Spielberg', 1946, None),
#  (230, 'Sylvester Stallone', 1946, None),
#  (231, 'Oliver Stone', 1946, None),
#  (232, 'Sharon Stone', 1958, None),
#  (233, 'Quentin Tarantino', 1963, None),
#  (234, 'Charlize Theron', 1975, None),
#  (235, 'Uma Thurman', 1970, None),
#  (236, 'Jennifer Tilly', 1958, None),
#  (237, 'John Travolta', 1954, None),
#  (238, 'Shannon Tweed', 1957, None),
#  (239, 'Liv Tyler', 1977, None),
#  (240, 'Skeet Ulrich', 1970, None),
#  (241, 'Jean-Claude Van Damme', 1960, None),
#  (242, 'Mark Wahlberg', 1971, None),
#  (243, 'Denzel Washington', 1954, None),
#  (244, 'Sigourney Weaver', 1949, None),
#  (245, 'Robin Williams', 1951, 2014),
#  (246, 'Bruce Willis', 1955, None),
#  (247, 'John Woo', 1946, None),
#  (248, 'Edward D. Wood Jr.', 1924, 1978),
#  (249, 'James Woods', 1947, None),
#  (250, 'Renée Zellweger', 1969, None),
#  (251, 'Timothy Dowling', 1973, None),
#  (252, 'Robert Ellis', 1892, 1974),
#  (253, 'Robert Ellis', 1888, 1935),
#  (254, 'Isabelle Adjani', 1955, None),
#  (255, 'Ben Affleck', 1972, None),
#  (256, 'Jenny Agutter', 1952, None),
#  (257, 'Alan Alda', 1936, None),
#  (258, 'Stephanie Zimbalist', 1956, None),
#  (259, 'Ginger Lynn', 1962, None),
#  (260, 'Joan Allen', 1956, None),
#  (261, 'Karen Allen', 1951, None),
#  (262, 'Nancy Allen', 1950, None),
#  (263, 'Kirstie Alley', 1951, 2022),
#  (264, 'Pedro Almodóvar', 1949, None),
#  (265, 'Robert Altman', 1925, 2006),
#  (266, 'Ursula Andress', 1936, None),
#  (267, 'Julie Andrews', 1935, None),
#  (268, 'Ann-Margret', 1941, None),
#  (269, 'Jean-Jacques Annaud', 1943, None),
#  (270, 'Gabrielle Anwar', 1970, None),
#  (271, 'Anne Archer', 1947, None),
#  (272, 'Fanny Ardant', 1949, None),
#  (273, 'Alan Arkin', 1934, None),
#  (274, 'David Arquette', 1971, None),
#  (275, 'Rosanna Arquette', 1959, None),
#  (276, 'Sean Astin', 1971, None),
#  (277, 'Richard Attenborough', 1923, 2014),
#  (278, 'Pernilla August', 1958, None),
#  (279, 'Hank Azaria', 1964, None),
#  (280, 'Catherine Bach', 1954, None),
#  (281, 'Scott Baio', 1960, None),
#  (282, 'Scott Bairstow', 1970, None),
#  (283, 'Brenda Bakke', 1963, None),
#  (284, 'Adam Baldwin', 1962, None),
#  (285, 'Alec Baldwin', 1958, None),
#  (286, 'Stephen Baldwin', 1966, None),
#  (287, 'William Baldwin', 1963, None),
#  (288, 'Christian Bale', 1974, None),
#  (289, 'Ellen Barkin', 1954, None),
#  (290, 'John Barry', 1933, 2011),
#  (291, 'Angela Bassett', 1958, None),
#  (292, 'Michelle Bauer', 1958, None),
#  (293, 'Sean Bean', 1959, None),
#  (294, 'Amanda Bearse', 1958, None),
#  (295, 'Kate Beckinsale', 1973, None),
#  (296, 'Robert Beltran', 1953, None),
#  (297, 'Tom Berenger', 1949, None),
#  (298, 'Candice Bergen', 1946, None),
#  (299, 'Michael Biehn', 1956, None),
#  (300, 'Juliette Binoche', 1964, None),
#  (301, 'Thora Birch', 1982, None),
#  (302, 'Jacqueline Bisset', 1944, None),
#  (303, 'Honor Blackman', 1925, 2020),
#  (304, 'Linda Blair', 1959, None),
#  (305, 'Mel Blanc', 1908, 1989),
#  (306, 'Brian Blessed', 1936, None),
#  (307, 'Helena Bonham Carter', 1966, None),
#  (308, 'Ernest Borgnine', 1917, 2012),
#  (309, 'David Bowie', 1947, 2016),
#  (310, 'Bruce Boxleitner', 1950, None),
#  (311, 'Annie Rosar', 1888, 1963),
#  (312, 'Amy Brenneman', 1964, None),
#  (313, 'Jeff Bridges', 1949, None),
#  (314, 'Charles Bronson', 1921, 2003),
#  (315, 'Louise Brooks', 1906, 1985),
#  (316, 'Mel Brooks', 1926, None),
#  (317, 'Clancy Brown', 1959, None),
#  (318, 'Tim Burton', 1958, None),
#  (319, 'Yancy Butler', 1970, None),
#  (320, 'Luis Buñuel', 1900, 1983),
#  (321, 'Gabriel Byrne', 1950, None),
#  (322, 'Emmanuelle Béart', 1963, None),
#  (323, 'Michael Caine', 1933, None),
#  (324, 'Barbara Carrera', 1945, None),
#  (325, 'David Caruso', 1956, None),
#  (326, 'Kim Cattrall', 1956, None),
#  (327, 'Lacey Chabert', 1982, None),
#  (328, 'Richard Chamberlain', 1934, None),
#  (329, 'Jackie Chan', 1954, None),
#  (330, 'Stockard Channing', 1944, None),
#  (331, 'Chevy Chase', 1943, None),
#  (332, 'Don Cheadle', 1964, None),
#  (333, 'Cher', 1946, None),
#  (334, 'Chow Yun-Fat', 1955, None),
#  (335, 'Glenn Close', 1947, None),
#  (336, 'James Coburn', 1928, 2002),
#  (337, 'Rachael Leigh Cook', 1979, None),
#  (338, 'Francis Ford Coppola', 1939, None),
#  (339, 'Roger Corman', 1926, None),
#  (340, 'Cindy Crawford', 1966, None),
#  (341, 'Michael Crichton', 1942, 2008),
#  (342, 'James Cromwell', 1940, None),
#  (343, 'David Cronenberg', 1943, None),
#  (344, 'Denise Crosby', None, None),
#  (345, 'Billy Crystal', 1948, None),
#  (346, 'Macaulay Culkin', 1980, None),
#  (347, 'Tim Curry', 1946, None),
#  (348, 'Tony Curtis', 1925, 2010),
#  (349, 'Joan Cusack', 1962, None),
#  (350, "Beverly D'Angelo", 1951, None),
#  (351, "Donna D'Errico", 1968, None),
#  (352, "Vincent D'Onofrio", 1959, None),
#  (353, 'Willem Dafoe', 1955, None),
#  (354, 'Matt Damon', 1970, None),
#  (355, 'Anthony Daniels', 1946, None),
#  (356, 'Sybil Danning', None, None),
#  (357, 'Lolita Davidovich', 1961, None),
#  (358, 'Daniel Day-Lewis', 1957, None),
#  (359, 'Olivier De Funès', 1949, None),
#  (360, 'Rebecca De Mornay', 1959, None),
#  (361, 'Brian De Palma', 1940, None),
#  (362, 'Danny DeVito', 1944, None),
#  (363, 'Loren Dean', 1969, None),
#  (364, 'Sandra Dee', 1942, 2005),
#  (365, 'Julie Delpy', 1969, None),
#  (366, 'Catherine Deneuve', 1943, None),
#  (367, 'Gérard Depardieu', 1948, None),
#  (368, 'Laura Dern', 1967, None),
#  (369, 'Matt Dillon', 1964, None),
#  (370, 'Walt Disney', 1901, 1966),
#  (371, 'Ami Dolenz', 1969, None),
#  (372, 'Amanda Donohoe', 1962, None),
#  (373, 'Michael Dorn', 1952, None),
#  (374, 'Brad Dourif', 1950, None),
#  (375, 'Robert Downey Jr.', 1965, None),
#  (376, 'Fran Drescher', 1957, None),
#  (377, 'Richard Dreyfuss', 1947, None),
#  (378, 'Minnie Driver', 1970, None),
#  (379, 'Kirsten Dunst', 1982, None),
#  (380, 'Robert Duvall', 1931, None),
#  (381, 'Anthony Edwards', 1962, None),
#  (382, 'Atom Egoyan', 1960, None),
#  (383, 'Jennifer Ehle', 1969, None),
#  (384, 'Danny Elfman', 1953, None),
#  (385, 'Sam Elliott', 1944, None),
#  (386, 'Roland Emmerich', 1955, None),
#  (387, 'Robert Englund', 1947, None),
#  (388, 'R. Lee Ermey', 1944, 2018),
#  (389, 'Emilio Estevez', 1962, None),
#  (390, 'Joe Eszterhas', 1944, None),
#  (391, 'Rupert Everett', 1959, None),
#  (392, 'Morgan Fairchild', 1950, None),
#  (393, 'Peter Falk', 1927, 2011),
#  (394, 'Chris Farley', 1964, 1997),
#  (395, 'Terry Farrell', 1963, None),
#  (396, 'Farrah Fawcett', 1947, 2009),
#  (397, 'Corey Feldman', 1971, None),
#  (398, 'Sally Field', 1946, None),
#  (399, 'David Fincher', 1962, None),
#  (400, 'Linda Fiorentino', 1958, None),
#  (401, 'Laurence Fishburne', 1961, None),
#  (402, 'Carrie Fisher', 1956, 2016),
#  (403, 'Bridget Fonda', 1964, None),
#  (404, 'Jane Fonda', 1937, None),
#  (405, 'Michelle Forbes', 1965, None),
#  (406, 'John Ford', 1894, 1973),
#  (407, 'Vivica A. Fox', 1964, None),
#  (408, 'Jonathan Frakes', 1952, None),
#  (409, 'Brendan Fraser', 1968, None),
#  (410, 'Stephen Fry', 1957, None),
#  (411, 'Edward Furlong', 1977, None),
#  (412, 'Andy Garcia', 1956, None),
#  (413, 'Janeane Garofalo', 1964, None),
#  (414, 'Teri Garr', 1947, None),
#  (415, 'Jami Gertz', 1965, None),
#  (416, 'Terry Gilliam', 1940, None),
#  (417, 'Crispin Glover', 1964, None),
#  (418, 'Danny Glover', 1946, None),
#  (419, 'Jean-Luc Godard', 1930, 2022),
#  (420, 'Valeria Golino', 1965, None),
#  (421, 'Cuba Gooding Jr.', 1968, None),
#  (422, 'John Goodman', 1952, None),
#  (423, 'Serena Grandi', 1958, None),
#  (424, 'Hugh Grant', 1960, None),
#  (425, 'Peter Greenaway', 1942, None),
#  (426, 'Jennifer Grey', 1960, None),
#  (427, 'Pam Grier', 1949, None),
#  (428, 'D.W. Griffith', 1875, 1948),
#  (429, 'Melanie Griffith', 1957, None),
#  (430, 'Steve Guttenberg', 1958, None),
#  (431, 'Taylor Hackford', 1944, None),
#  (432, 'Gene Hackman', 1930, None),
#  (433, 'Corey Haim', 1971, 2010),
#  (434, 'Mark Hamill', 1951, None),
#  (435, 'Daryl Hannah', 1960, None),
#  (436, 'Curtis Hanson', 1945, 2016),
#  (437, 'Woody Harrelson', 1961, None),
#  (438, 'Ed Harris', 1950, None),
#  (439, 'Neil Patrick Harris', 1973, None),
#  (440, 'Nina Hartley', 1959, None),
#  (441, 'Noah Hathaway', 1971, None),
#  (442, 'Rutger Hauer', 1944, 2019),
#  (443, 'Goldie Hawn', 1945, None),
#  (444, 'Glenne Headly', 1955, 2017),
#  (445, 'Dan Hedaya', 1940, None),
#  (446, 'Mariel Hemingway', 1961, None),
#  (447, 'Marilu Henner', 1952, None),
#  (448, 'Lance Henriksen', 1940, None),
#  (449, 'Natasha Henstridge', 1974, None),
#  (450, 'Philip Seymour Hoffman', 1967, 2014),
#  (451, 'Gaby Hoffmann', 1982, None),
#  (452, 'Lauren Holly', 1963, None),
#  (453, 'Ian Holm', 1931, 2020),
#  (454, 'Dennis Hopper', 1936, 2010),
#  (455, 'John Hughes', 1950, 2009),
#  (456, 'Holly Hunter', 1958, None),
#  (457, 'John Hurt', 1940, 2017),
#  (458, 'William Hurt', 1950, 2022),
#  (459, 'Timothy Hutton', 1960, None),
#  (460, 'Jeremy Irons', 1948, None),
#  (461, 'Michael Ironside', 1950, None),
#  (462, 'Kate Jackson', 1948, None),
#  (463, 'Famke Janssen', 1964, None),
#  (464, 'Jim Jarmusch', 1953, None),
#  (465, 'Ron Jeremy', 1953, None),
#  (466, 'Jean-Pierre Jeunet', 1953, None),
#  (467, 'Don Johnson', 1949, None),
#  (468, 'Lynn-Holly Johnson', 1958, None),
#  (469, 'James Earl Jones', 1931, None),
#  (470, 'Jeffrey Jones', 1946, None),
#  (471, 'Raul Julia', 1940, 1994),
#  (472, 'Boris Karloff', 1887, 1969),
#  (473, 'Diane Keaton', 1946, None),
#  (474, 'Michael Keaton', 1951, None),
#  (475, 'Patsy Kensit', 1968, None),
#  (476, 'Sally Kirkland', 1941, None),
#  (477, 'Mia Kirshner', 1975, None),
#  (478, 'Tawny Kitaen', 1961, 2021),
#  (479, 'Walter Koenig', 1936, None),
#  (480, 'Elias Koteas', 1961, None),
#  (481, 'Alice Krige', 1954, None),
#  (482, 'Sylvia Kristel', 1952, 2012),
#  (483, 'Christopher Lambert', 1957, None),
#  (484, 'John Landis', 1950, None),
#  (485, 'Fritz Lang', 1890, 1976),
#  (486, 'Heather Langenkamp', 1964, None),
#  (487, 'Ang Lee', 1954, None),
#  (488, 'Brandon Lee', 1965, 1993),
#  (489, 'Christopher Lee', 1922, 2015),
#  (490, 'Spike Lee', 1957, None),
#  (491, 'John Leguizamo', 1960, None),
#  (492, 'Jennifer Jason Leigh', 1962, None),
#  (493, 'Jack Lemmon', 1925, 2001),
#  (494, 'Robert Sean Leonard', 1969, None),
#  (495, 'Téa Leoni', 1966, None),
#  (496, 'Juliette Lewis', 1973, None),
#  (497, 'Jennifer Lien', 1974, None),
#  (498, 'Matthew Lillard', 1970, None),
#  (499, 'Bai Ling', None, None),
#  (500, 'Richard Linklater', 1960, None),
#  (501, 'Ray Liotta', 1954, 2022),
#  (502, 'Christopher Lloyd', 1938, None),
#  (503, 'Emily Lloyd', 1970, None),
#  (504, 'Amy Locane', 1971, None),
#  (505, 'Nia Long', 1970, None),
#  (506, 'Julia Louis-Dreyfus', 1961, None),
#  (507, 'Rob Lowe', 1964, None),
#  (508, 'Carey Lowell', 1961, None),
#  (509, 'Bela Lugosi', 1882, 1956),
#  (510, 'Andie MacDowell', 1958, None),
#  (511, 'Shirley MacLaine', 1934, None),
#  (512, 'Elle Macpherson', 1964, None),
#  (513, 'William H. Macy', 1950, None),
#  (514, 'Michael Madsen', 1957, None),
#  (515, 'Virginia Madsen', 1961, None),
#  (516, 'Lee Majors', 1939, None),
#  (517, 'Terrence Malick', 1943, None),
#  (518, 'John Malkovich', 1953, None),
#  (519, 'David Mamet', 1947, None),
#  (520, 'Michael Mann', 1943, None),
#  (521, 'Sophie Marceau', 1966, None),
#  (522, 'Vanessa Marcil', 1968, None),
#  (523, 'Julianna Margulies', 1966, None),
#  (524, 'Mary Stuart Masterson', 1966, None),
#  (525, 'Heather Matarazzo', 1982, None),
#  (526, 'Samantha Mathis', 1970, None),
#  (527, 'Walter Matthau', 1920, 2000),
#  (528, 'Mathilda May', 1965, None),
#  (529, 'Debi Mazar', 1964, None),
#  (530, 'Andrew McCarthy', 1962, None),
#  (531, 'Frances McDormand', 1957, None),
#  (532, 'Malcolm McDowell', 1943, None),
#  (533, 'Gates McFadden', 1949, None),
#  (534, 'Kelly McGillis', 1957, None),
#  (535, 'Rose McGowan', 1973, None),
#  (536, 'Robert Duncan McNeill', 1964, None),
#  (537, 'Steve McQueen', 1930, 1980),
#  (538, 'Colm Meaney', 1953, None),
#  (539, 'Dina Meyer', 1968, None),
#  (540, 'Russ Meyer', 1922, 2004),
#  (541, 'Bette Midler', 1945, None),
#  (542, 'Penelope Ann Miller', 1964, None),
#  (543, 'Sal Mineo', 1939, 1976),
#  (544, 'Carmen Miranda', 1909, 1955),
#  (545, 'Helen Mirren', 1945, None),
#  (546, 'Matthew Modine', 1959, None),
#  (547, 'Alfred Molina', 1953, None),
#  (548, 'Elizabeth Montgomery', 1933, 1995),
#  (549, 'Roger Moore', 1927, 2017),
#  (550, 'Kate Mulgrew', 1955, None),
#  (551, 'Dermot Mulroney', 1963, None),
#  (552, 'Eddie Murphy', 1961, None),
#  (553, 'Liam Neeson', 1952, None),
#  (554, 'Sam Neill', 1947, None),
#  (555, 'Judd Nelson', 1959, None),
#  (556, 'Olivia Newton-John', 1948, 2022),
#  (557, 'Brigitte Nielsen', 1963, None),
#  (558, 'Leslie Nielsen', 1926, 2010),
#  (559, 'Leonard Nimoy', 1931, 2015),
#  (560, 'Nick Nolte', 1941, None),
#  (561, 'Peter North', 1957, None),
#  (562, 'Jeremy Northam', 1961, None),
#  (563, "Chris O'Donnell", 1970, None),
#  (564, "Peter O'Toole", 1932, 2013),
#  (565, 'Lena Olin', 1955, None),
#  (566, 'Julia Ormond', 1965, None),
#  (567, 'George Orwell', 1903, 1950),
#  (568, 'Frank Oz', 1944, None),
#  (569, 'Gwyneth Paltrow', 1972, None),
#  (570, 'Alan Parker', 1944, 2020),
#  (571, 'Mary-Louise Parker', 1964, None),
#  (572, 'Sarah Jessica Parker', 1965, None),
#  (573, 'Dolly Parton', 1946, None),
#  (574, 'Jason Patric', 1966, None),
#  (575, 'Alexandra Paul', 1963, None),
#  (576, 'Sean Penn', 1960, None),
#  (577, 'George Peppard', 1928, 1994),
#  (578, 'Anthony Perkins', 1932, 1992),
#  (579, 'Ron Perlman', 1950, None),
#  (580, 'Luke Perry', 1966, 2019),
#  (581, 'Joseph L. Mankiewicz', 1909, 1993),
#  (582, 'Joe Pesci', 1943, None),
#  (583, 'Wolfgang Petersen', 1941, 2022),
#  (584, 'Amanda Peterson', 1971, 2015),
#  (585, 'Robert Picardo', 1953, None),
#  (586, 'Jada Pinkett Smith', 1971, None),
#  (587, 'Donald Pleasence', 1919, 1995),
#  (588, 'Martha Plimpton', 1970, None),
#  (589, 'Eve Plumb', 1958, None),
#  (590, 'Edgar Allan Poe', 1809, 1849),
#  (591, 'Roman Polanski', 1933, None),
#  (592, 'Pete Postlethwaite', 1946, 2011),
#  (593, 'Kelly Preston', 1962, 2020),
#  (594, 'Jason Priestley', 1969, None),
#  (595, 'Victoria Principal', 1950, None),
#  (596, 'Jonathan Pryce', 1947, None),
#  (597, 'Bill Pullman', 1953, None),
#  (598, 'Dennis Quaid', 1954, None),
#  (599, 'Kathleen Quinlan', 1954, None),
#  (600, 'Sam Raimi', 1959, None),
#  (601, 'Harold Ramis', 1944, 2014),
#  (602, 'Robert Redford', 1936, None),
#  (603, 'Vanessa Redgrave', 1937, None),
#  (604, 'John C. Reilly', 1965, None),
#  (605, 'Brad Renfro', 1982, 2008),
#  (606, 'Jean Reno', 1948, None),
#  (607, 'Paul Reubens', 1952, None),
#  (608, 'Burt Reynolds', 1936, 2018),
#  (609, 'Ving Rhames', 1959, None),
#  (610, 'Giovanni Ribisi', 1974, None),
#  (611, 'Ariana Richards', 1979, None),
#  (612, 'Denise Richards', 1971, None),
#  (613, 'Joely Richardson', 1965, None),
#  (614, 'Alan Rickman', 1946, 2016),
#  (615, 'John Ritter', 1948, 2003),
#  (616, 'Eric Roberts', 1956, None),
#  (617, 'Tanya Roberts', 1949, 2021),
#  (618, 'Isabella Rossellini', 1952, None),
#  (619, 'Tim Roth', 1961, None),
#  (620, 'Mickey Rourke', 1952, None),
#  (621, 'Kurt Russell', 1951, None),
#  (622, 'Theresa Russell', 1957, None),
#  (623, 'Rene Russo', 1954, None),
#  (624, 'Laura San Giacomo', 1961, None),
#  (625, 'Fred Savage', 1976, None),
#  (626, 'John Sayles', 1950, None),
#  (627, 'Greta Scacchi', 1960, None),
#  (628, 'Johnathon Schaech', 1969, None),
#  (629, 'Claudia Schiffer', 1970, None),
#  (630, 'Liev Schreiber', 1967, None),
#  (631, 'Ridley Scott', 1937, None),
#  (632, 'Jerry Seinfeld', 1954, None),
#  (633, 'Tom Selleck', 1945, None),
#  (634, 'Peter Sellers', 1925, 1980),
#  (635, 'Yahoo Serious', 1953, None),
#  (636, 'William Shakespeare', 1564, 1616),
#  (637, 'Tupac Shakur', 1971, 1996),
#  (638, 'William Shatner', 1931, None),
#  (639, 'Ally Sheedy', 1962, None),
#  (640, 'Martin Sheen', 1940, None),
#  (641, 'Gary Sinise', 1955, None),
#  (642, 'Marina Sirtis', 1955, None),
#  (643, 'Tom Skerritt', 1933, None),
#  (644, 'Helen Slater', 1963, None),
#  (645, 'Anna Nicole Smith', 1967, 2007),
#  (646, 'Jaclyn Smith', 1945, None),
#  (647, 'Alan Smithee', None, None),
#  (648, 'Wesley Snipes', 1962, None),
#  (649, 'Paul Sorvino', 1939, 2022),
#  (650, 'Talisa Soto', 1967, None),
#  (651, 'Sissy Spacek', 1949, None),
#  (652, 'James Spader', 1960, None),
#  (653, 'Brent Spiner', 1949, None),
#  (654, 'Terence Stamp', 1938, None),
#  (655, 'Eric Stoltz', 1961, None),
#  (656, 'Madeleine Stowe', 1958, None),
#  (657, 'David Strathairn', 1949, None),
#  (658, 'Meryl Streep', 1949, None),
#  (659, 'Barbra Streisand', 1942, None),
#  (660, 'Tami Stronach', 1972, None),
#  (661, 'Donald Sutherland', 1935, None),
#  (662, 'Kiefer Sutherland', 1966, None),
#  (663, 'Dominique Swain', 1980, None),
#  (664, 'Patrick Swayze', 1952, 2009),
#  (665, 'D.B. Sweeney', None, None),
#  (666, 'Lili Taylor', 1967, None),
#  (667, 'David Thewlis', 1963, None),
#  (668, 'Emma Thompson', 1959, None),
#  (669, 'Fred Thompson', 1942, 2015),
#  (670, 'Lea Thompson', 1961, None),
#  (671, 'Billy Bob Thornton', 1955, None),
#  (672, 'Meg Tilly', 1960, None),
#  (673, 'Marisa Tomei', 1964, None),
#  (674, 'Tamlyn Tomita', 1966, None),
#  (675, 'Jeanne Tripplehorn', 1963, None),
#  (676, 'Chris Tucker', 1971, None),
#  (677, 'Robin Tunney', 1972, None),
#  (678, 'Kathleen Turner', 1954, None),
#  (679, 'Deborah Kara Unger', 1966, None),
#  (680, 'Casper Van Dien', 1968, None),
#  (681, 'Vince Vaughn', 1970, None),
#  (682, 'Paul Verhoeven', 1938, None),
#  (683, 'Gore Vidal', 1925, 2012),
#  (684, 'Nana Visitor', 1957, None),
#  (685, 'Jon Voight', 1938, None),
#  (686, 'Christopher Walken', 1943, None),
#  (687, 'J.T. Walsh', 1943, 1998),
#  (688, 'Sela Ward', 1956, None),
#  (689, 'Julie Warner', 1965, None),
#  (690, 'Lesley Ann Warren', 1946, None),
#  (691, 'John Waters', 1946, None),
#  (692, 'Teri Weigel', 1962, None),
#  (693, 'Peter Weller', 1947, None),
#  (694, 'Wim Wenders', 1945, None),
#  (695, 'Joanne Whalley', 1961, None),
#  (696, 'Wil Wheaton', 1972, None),
#  (697, 'Billy Wilder', 1906, 2002),
#  (698, 'Gene Wilder', 1933, 2016),
#  (699, 'Michael Wincott', 1958, None),
#  (700, 'Debra Winger', 1955, None),
#  (701, 'Kate Winslet', 1975, None),
#  (702, 'Reese Witherspoon', 1976, None),
#  (703, 'BD Wong', 1960, None),
#  (704, 'Elijah Wood', 1981, None),
#  (705, 'Robin Wright', 1966, None),
#  (706, 'Michelle Yeoh', 1962, None),
#  (707, 'Sean Young', 1959, None),
#  (708, 'Billy Zane', 1966, None),
#  (709, 'Robert Zemeckis', 1952, None),
#  (710, 'David Raksin', 1912, 2004),
#  (711, 'Rick Baker', 1950, None),
#  (712, 'Steve Cohen', None, None),
#  (713, 'Joel Oliansky', 1935, 2002),
#  (714, 'Willie Aames', 1960, None),
#  (715, 'Caroline Aaron', 1952, None),
#  (716, 'Paula Abdul', 1962, None),
#  (717, 'Kareem Abdul-Jabbar', 1947, None),
#  (718, 'Ian Abercrombie', 1934, 2012),
#  (719, 'F. Murray Abraham', 1939, None),
#  (720, 'Jim Abrahams', 1944, None),
#  (721, 'Victoria Abril', 1959, None),
#  (722, 'Joss Ackland', 1928, None),
#  (723, 'Deborah Adair', 1952, None),
#  (724, 'Brooke Adams', 1949, None),
#  (725, 'Joey Lauren Adams', 1968, None),
#  (726, 'Maud Adams', 1945, None),
#  (727, 'Percy Adlon', 1935, None),
#  (728, 'Mario Adorf', 1930, None),
#  (729, 'Casey Affleck', 1975, None),
#  (730, 'John Agar', 1921, 2002),
#  (731, 'Brian Aherne', 1902, 1986),
#  (732, 'Danny Aiello', 1933, 2019),
#  (733, 'Anouk Aimée', 1932, None),
#  (734, 'Eddie Albert', 1906, 2005),
#  (735, 'Brian Aldiss', 1925, 2017),
#  (736, 'Robert Aldrich', 1918, 1983),
#  (737, 'Jane Alexander', 1939, None),
#  (738, 'Muhammad Ali', 1942, 2016),
#  (739, 'Debbie Allen', 1950, None),
#  (740, 'Irwin Allen', 1916, 1991),
#  (741, 'Tim Allen', 1953, None),
#  (742, 'June Allyson', 1917, 2006),
#  (743, 'Néstor Almendros', 1930, 1992),
#  (744, 'Maria Conchita Alonso', 1957, None),
#  (745, 'Carol Alt', 1960, None),
#  (746, 'Trini Alvarado', 1967, None),
#  (747, 'Don Ameche', 1908, 1993),
#  (748, 'Leon Ames', 1902, 1993),
#  (749, 'Mädchen Amick', 1970, None),
#  (750, 'Jon Amiel', 1948, None),
#  (751, 'Suzy Amis', 1962, None),
#  (752, 'Judith Anderson', 1897, 1992),
#  (753, 'Juliet Anderson', 1938, 2010),
#  (754, 'Kevin Anderson', 1960, None),
#  (755, 'Lindsay Anderson', 1923, 1994),
#  (756, 'Loni Anderson', 1945, None),
#  (757, 'Melissa Sue Anderson', 1962, None),
#  (758, 'Melody Anderson', 1955, None),
#  (759, 'Paul Thomas Anderson', 1970, None),
#  (760, 'Richard Dean Anderson', 1950, None),
#  (761, 'Bibi Andersson', 1935, 2019),
#  (762, 'Anthony Andrews', 1948, None),
#  (763, 'Dana Andrews', 1909, 1992),
#  (764, 'André René Roussimoff', 1946, 1993),
#  (765, 'Pier Angeli', 1932, 1971),
#  (766, 'Theodoros Angelopoulos', 1935, 2012),
#  (767, 'Jean-Hugues Anglade', 1955, None),
#  (768, 'Francesca Annis', 1945, None),
#  (769, 'Susan Anspach', 1942, 2018),
#  (770, 'David Anspaugh', 1946, None),
#  (771, 'Lysette Anthony', 1963, None),
#  (772, 'Susan Anton', 1950, None),
#  (773, 'Laura Antonelli', 1941, 2015),
#  (774, 'Michelangelo Antonioni', 1912, 2007),
#  (775, 'Christina Applegate', 1971, None),
#  (776, 'Michael Apted', 1941, 2021),
#  (777, 'Gregg Araki', 1959, None),
#  (778, 'Alfonso Arau', 1932, None),
#  (779, "Roscoe 'Fatty' Arbuckle", 1887, 1933),
#  (780, 'Denys Arcand', 1941, None),
#  (781, 'Eve Arden', 1908, 1990),
#  (782, 'Asia Argento', 1975, None),
#  (783, 'Dario Argento', 1940, None),
#  (784, 'Pedro Armendáriz', 1912, 1963),
#  (785, 'Alison Armitage', 1965, None),
#  (786, 'George Armitage', 1942, None),
#  (787, 'Bess Armstrong', 1953, None),
#  (788, 'Gillian Armstrong', 1950, None),
#  (789, 'Desi Arnaz', 1917, 1986),
#  (790, 'James Arness', 1923, 2011),
#  (791, 'Jack Arnold', 1912, 1992),
#  (792, 'Tom Arnold', 1959, None),
#  (793, 'Alexis Arquette', 1969, 2016),
#  (794, 'Lewis Arquette', 1935, 2001),
#  (795, 'Jean Arthur', 1900, 1991),
#  (796, 'Dana Ashbrook', 1967, None),
#  (797, 'Hal Ashby', 1929, 1988),
#  (798, 'Linden Ashby', 1960, None),
#  (799, 'Edward Asner', 1929, 2021),
#  (800, 'Armand Assante', 1949, None),
#  (801, 'Olivier Assayas', 1955, None),
#  (802, 'Mary Astor', 1906, 1987),
#  (803, 'Christopher Atkins', 1961, None),
#  (804, 'Stéphane Audran', 1932, 2018),
#  (805, 'Claudine Auger', 1941, 2019),
#  (806, 'Bille August', 1948, None),
#  (807, 'Jane Austen', 1775, 1817),
#  (808, 'Paul Auster', 1947, None),
#  (809, 'Daniel Auteuil', 1950, None),
#  (810, 'Gene Autry', 1907, 1998),
#  (811, 'Frankie Avalon', 1940, None),
#  (812, 'Roger Avary', 1965, None),
#  (813, 'Tex Avery', 1908, 1980),
#  (814, 'John G. Avildsen', 1935, 2017),
#  (815, 'Mili Avital', 1972, None),
#  (816, 'Jon Avnet', 1949, None),
#  (817, 'Lew Ayres', 1908, 1996),
#  (818, 'Shabana Azmi', 1950, None),
#  (819, 'Barbara Bach', 1946, None),
#  (820, 'Burt Bacharach', 1928, None),
#  (821, 'Amitabh Bachchan', 1942, None),
#  (822, 'Jim Backus', 1913, 1989),
#  (823, 'Angelo Badalamenti', 1937, 2022),
#  (824, 'John Badham', 1939, None),
#  (825, 'Mary Badham', 1952, None),
#  (826, 'Jane Badler', 1953, None),
#  (827, 'Maxine Bahns', 1971, None),
#  (828, 'Barbara Bain', 1931, None),
#  (829, 'Stuart Baird', 1947, None),
#  (830, 'Oksana Baiul', 1977, None),
#  (832, 'Diane Baker', 1938, None),
#  (833, 'Joe Don Baker', 1936, None),
#  (834, 'Kathy Baker', 1950, None),
#  (835, 'Ralph Bakshi', 1938, None),
#  (836, 'Scott Bakula', 1954, None),
#  (837, 'Bob Balaban', 1945, None),
#  (838, 'Daniel Baldwin', 1960, None),
#  (839, 'Ina Balin', 1937, 1990),
#  (840, 'Lucille Ball', 1911, 1989),
#  (841, 'Michael Ballhaus', 1935, 2017),
#  (842, 'Martin Balsam', 1919, 1996),
#  (843, 'Anne Bancroft', 1931, 2005),
#  (844, 'Tamasaburô Bandô', 1950, None),
#  (845, 'Tallulah Bankhead', 1902, 1968),
#  (846, 'Ian Bannen', 1928, 1999),
#  (847, 'Theda Bara', 1885, 1955),
#  (848, 'Olivia Barash', None, None),
#  (849, 'Javier Bardem', 1969, None),
#  (850, 'Clive Barker', 1952, None),
#  (851, 'Lex Barker', 1919, 1973),
#  (852, 'Jean-Marc Barr', 1960, None),
#  (853, 'Bruno Barreto', 1955, None),
#  (854, 'Majel Barrett', 1932, 2008),
#  (855, 'Raymond J. Barry', 1939, None),
#  (856, 'Ethel Barrymore', 1879, 1959),
#  (857, 'John Drew Barrymore', 1932, 2004),
#  (858, 'John Barrymore', 1882, 1942),
#  (859, 'Lionel Barrymore', 1878, 1954),
#  (860, 'Paul Bartel', 1938, 2000),
#  (861, 'Freddie Bartholomew', 1924, 1992),
#  (862, 'Robin Bartlett', 1951, None),
#  (863, 'Billy Barty', 1924, 2000),
#  (864, 'Mikhail Baryshnikov', 1948, None),
#  (865, 'Richard Basehart', 1914, 1984),
#  (866, 'Saul Bass', 1920, 1996),
#  (867, 'Jason Bateman', 1969, None),
#  (868, 'Justine Bateman', 1966, None),
#  (869, 'Alan Bates', 1934, 2003),
#  (870, 'Kathy Bates', 1948, None),
#  (871, 'Randall Batinkoff', 1968, None),
#  (872, 'Patrick Bauchau', 1938, None),
#  (873, 'Belinda Bauer', 1950, None),
#  (874, 'Steven Bauer', 1956, None),
#  (875, 'L. Frank Baum', 1856, 1919),
#  (876, 'Noah Baumbach', 1969, None),
#  (877, 'Lamberto Bava', 1944, None),
#  (878, 'Mario Bava', 1914, 1980),
#  (879, 'Anne Baxter', 1923, 1985),
#  (880, 'Meredith Baxter', 1947, None),
#  (881, 'Michael Bay', 1965, None),
#  (882, 'Nathalie Baye', 1948, None),
#  (883, 'Stephanie Beacham', 1947, None),
#  (884, 'Jennifer Beals', 1963, None),
#  (885, 'Ned Beatty', 1937, 2021),
#  (886, 'Warren Beatty', 1937, None),
#  (887, 'Harold Becker', 1928, None),
#  (888, 'Meret Becker', 1969, None),
#  (889, 'Bonnie Bedelia', 1948, None),
#  (890, 'Noah Beery Jr.', 1913, 1994),
#  (891, 'Wallace Beery', 1885, 1949),
#  (892, 'Jason Beghe', 1960, None),
#  (893, 'Ed Begley Jr.', 1949, None),
#  (894, 'Jean-Jacques Beineix', 1946, 2022),
#  (895, 'Barbara Bel Geddes', 1922, 2005),
#  (896, 'Harry Belafonte', 1927, None),
#  (897, 'Ralph Bellamy', 1904, 1991),
#  (898, 'Kathleen Beller', 1956, None),
#  (899, 'Monica Bellucci', 1964, None),
#  (900, 'Pamela Bellwood', 1944, None),
#  (901, 'Jean-Paul Belmondo', 1933, 2021),
#  (902, 'Jim Belushi', 1954, None),
#  (903, 'Brian Benben', 1956, None),
#  (904, 'William Bendix', 1906, 1964),
#  (905, 'Roberto Benigni', 1952, None),
#  (906, 'Annette Bening', 1958, None),
#  (907, 'Richard Benjamin', 1938, None),
#  (908, 'David Bennent', 1966, None),
#  (909, 'Constance Bennett', 1904, 1965),
#  (910, 'Joan Bennett', 1910, 1990),
#  (911, 'Nigel Bennett', 1949, None),
#  (912, 'Jack Benny', 1894, 1974),
#  (913, 'Robby Benson', 1956, None),
#  (914, 'Robert Benton', 1932, None),
#  (915, 'Bruce Beresford', 1940, None),
#  (916, 'Peter Berg', 1964, None),
#  (917, 'Polly Bergen', 1930, 2014),
#  (918, 'Helmut Berger', 1944, None),
#  (919, 'Senta Berger', 1941, None),
#  (920, 'Patrick Bergin', 1951, None),
#  (921, 'Andrew Bergman', 1945, None),
#  (922, 'Sandahl Bergman', 1951, None),
#  (923, 'Busby Berkeley', 1895, 1976),
#  (924, 'Elizabeth Berkley', 1972, None),
#  (925, 'Steven Berkoff', 1937, None),
#  (926, 'Milton Berle', 1908, 2002),
#  (927, 'Irving Berlin', 1888, 1989),
#  (928, 'Sandra Bernhard', 1955, None),
#  (929, 'Corbin Bernsen', 1954, None),
#  (930, 'Elmer Bernstein', 1922, 2004),
#  (931, 'Elizabeth Berridge', 1962, None),
#  (932, 'Halle Berry', 1966, None),
#  (933, 'Valerie Bertinelli', 1960, None),
#  (934, 'Bernardo Bertolucci', 1941, 2018),
#  (935, 'Bibi Besch', 1942, 1996),
#  (936, 'Martine Beswick', 1941, None),
#  (937, 'Richard Beymer', 1939, None),
#  (938, 'Daniela Bianchi', 1942, None),
#  (939, 'Adrian Biddle', 1952, 2005),
#  (940, 'Bigas Luna', 1946, 2013),
#  (941, 'Kathryn Bigelow', 1951, None),
#  (942, 'Theodore Bikel', 1924, 2015),
#  (943, 'Traci Bingham', 1968, None),
#  (944, 'Antonia Bird', 1951, 2013),
#  (945, 'Jane Birkin', 1946, None),
#  (946, 'Whit Bissell', 1909, 1996),
#  (947, 'Karen Black', 1939, 2013),
#  (948, 'Shane Black', 1961, None),
#  (949, 'Cate Blanchett', 1969, None),
#  (950, 'Brenda Blethyn', 1946, None),
#  (951, 'Joan Blondell', 1906, 1979),
#  (952, 'Hart Bochner', 1956, None),
#  (953, 'Peter Bogdanovich', 1939, 2022),
#  (954, 'Jon Bon Jovi', 1962, None),
#  (955, 'Ward Bond', 1903, 1960),
#  (956, 'Lisa Bonet', 1967, None),
#  (957, 'Jan de Bont', 1943, None),
#  (958, 'John Boorman', 1933, None),
#  (959, 'Powers Boothe', 1948, 2017),
#  (960, 'Barry Bostwick', 1945, None),
#  (961, 'Timothy Bottoms', 1951, None),
#  (962, 'Carole Bouquet', 1957, None),
#  (963, 'Stephen Boyd', 1931, 1977),
#  (964, 'Charles Boyer', 1899, 1978),
#  (965, 'Danny Boyle', 1956, None),
#  (966, 'Lorraine Bracco', 1954, None),
#  (967, 'Eric Braeden', 1941, None),
#  (968, 'Sonia Braga', 1950, None),
#  (969, 'Lillo Brancato', 1976, None),
#  (970, 'Jonathan Brandis', 1976, 2003),
#  (971, 'Nicoletta Braschi', 1960, None),
#  (972, 'Tinto Brass', 1933, None),
#  (973, 'Benjamin Bratt', 1963, None),
#  (974, 'Walter Brennan', 1894, 1974),
#  (975, 'Robert Bresson', 1901, 1999),
#  (976, 'Martin Brest', 1951, None),
#  (977, 'Beau Bridges', 1941, None),
#  (978, 'Lloyd Bridges', 1913, 1998),
#  (979, 'Wilford Brimley', 1934, 2020),
#  (980, 'Jim Broadbent', 1949, None),
#  (981, 'James Brolin', 1940, None),
#  (982, 'Josh Brolin', 1968, None),
#  (983, 'Albert Brooks', 1947, None),
#  (984, 'Avery Brooks', 1948, None),
#  (985, 'James L. Brooks', 1940, None),
#  (986, 'Bryan Brown', 1947, None),
#  (987, 'Jim Brown', 1936, None),
#  (988, 'Jerry Bruckheimer', 1943, None),
#  (989, 'Yul Brynner', 1920, 1985),
#  (990, 'Betty Buckley', 1947, None),
#  (991, 'Geneviève Bujold', 1942, None),
#  (992, 'Billie Burke', 1884, 1970),
#  (993, 'Carol Burnett', 1933, None),
#  (994, 'Raymond Burr', 1917, 1993),
#  (995, 'Ellen Burstyn', 1932, None),
#  (996, 'LeVar Burton', 1957, None),
#  (997, 'Gary Busey', 1944, None),
#  (998, 'Jake Busey', 1971, None),
#  (999, 'Red Buttons', 1919, 2006),
#  (1000, 'Tom Byron', 1961, None),
#  (1001, 'James Caan', 1940, 2022),
#  ...]

# %%
member_columns = ['_id', 'name', 'birthYear', 'deathYear']
members = [dict((key, value) for key, value in zip(member_columns, row) if value != None and value == value) for row in members]
members
# Out:
# [{'_id': 1, 'name': 'Fred Astaire', 'birthYear': 1899, 'deathYear': 1987},
#  {'_id': 2, 'name': 'Lauren Bacall', 'birthYear': 1924, 'deathYear': 2014},
#  {'_id': 3, 'name': 'Brigitte Bardot', 'birthYear': 1934},
#  {'_id': 4, 'name': 'John Belushi', 'birthYear': 1949, 'deathYear': 1982},
#  {'_id': 5, 'name': 'Ingmar Bergman', 'birthYear': 1918, 'deathYear': 2007},
#  {'_id': 6, 'name': 'Ingrid Bergman', 'birthYear': 1915, 'deathYear': 1982},
#  {'_id': 7, 'name': 'Humphrey Bogart', 'birthYear': 1899, 'deathYear': 1957},
#  {'_id': 8, 'name': 'Marlon Brando', 'birthYear': 1924, 'deathYear': 2004},
#  {'_id': 9, 'name': 'Richard Burton', 'birthYear': 1925, 'deathYear': 1984},
#  {'_id': 10, 'name': 'James Cagney', 'birthYear': 1899, 'deathYear': 1986},
#  {'_id': 11, 'name': 'Gary Cooper', 'birthYear': 1901, 'deathYear': 1961},
#  {'_id': 12, 'name': 'Bette Davis', 'birthYear': 1908, 'deathYear': 1989},
#  {'_id': 13, 'name': 'Doris Day', 'birthYear': 1922, 'deathYear': 2019},
#  {'_id': 14,
#   'name': 'Olivia de Havilland',
#   'birthYear': 1916,
#   'deathYear': 2020},
#  {'_id': 15, 'name': 'James Dean', 'birthYear': 1931, 'deathYear': 1955},
#  {'_id': 16, 'name': 'Georges Delerue', 'birthYear': 1925, 'deathYear': 1992},
#  {'_id': 17, 'name': 'Marlene Dietrich', 'birthYear': 1901, 'deathYear': 1992},
#  {'_id': 18, 'name': 'Kirk Douglas', 'birthYear': 1916, 'deathYear': 2020},
#  {'_id': 19, 'name': 'Federico Fellini', 'birthYear': 1920, 'deathYear': 1993},
#  {'_id': 20, 'name': 'Henry Fonda', 'birthYear': 1905, 'deathYear': 1982},
#  {'_id': 21, 'name': 'Joan Fontaine', 'birthYear': 1917, 'deathYear': 2013},
#  {'_id': 22, 'name': 'Clark Gable', 'birthYear': 1901, 'deathYear': 1960},
#  {'_id': 23, 'name': 'Judy Garland', 'birthYear': 1922, 'deathYear': 1969},
#  {'_id': 24, 'name': 'John Gielgud', 'birthYear': 1904, 'deathYear': 2000},
#  {'_id': 25, 'name': 'Jerry Goldsmith', 'birthYear': 1929, 'deathYear': 2004},
#  {'_id': 26, 'name': 'Cary Grant', 'birthYear': 1904, 'deathYear': 1986},
#  {'_id': 27, 'name': 'Alec Guinness', 'birthYear': 1914, 'deathYear': 2000},
#  {'_id': 28, 'name': 'Rita Hayworth', 'birthYear': 1918, 'deathYear': 1987},
#  {'_id': 29,
#   'name': 'Margaux Hemingway',
#   'birthYear': 1954,
#   'deathYear': 1996},
#  {'_id': 30, 'name': 'Audrey Hepburn', 'birthYear': 1929, 'deathYear': 1993},
#  {'_id': 31,
#   'name': 'Katharine Hepburn',
#   'birthYear': 1907,
#   'deathYear': 2003},
#  {'_id': 32, 'name': 'Charlton Heston', 'birthYear': 1923, 'deathYear': 2008},
#  {'_id': 33, 'name': 'Alfred Hitchcock', 'birthYear': 1899, 'deathYear': 1980},
#  {'_id': 34, 'name': 'William Holden', 'birthYear': 1918, 'deathYear': 1981},
#  {'_id': 35, 'name': 'James Horner', 'birthYear': 1953, 'deathYear': 2015},
#  {'_id': 36, 'name': 'Buster Keaton', 'birthYear': 1895, 'deathYear': 1966},
#  {'_id': 37, 'name': 'Gene Kelly', 'birthYear': 1912, 'deathYear': 1996},
#  {'_id': 38, 'name': 'Grace Kelly', 'birthYear': 1929, 'deathYear': 1982},
#  {'_id': 39, 'name': 'Deborah Kerr', 'birthYear': 1921, 'deathYear': 2007},
#  {'_id': 40, 'name': 'Stanley Kubrick', 'birthYear': 1928, 'deathYear': 1999},
#  {'_id': 41, 'name': 'Akira Kurosawa', 'birthYear': 1910, 'deathYear': 1998},
#  {'_id': 42, 'name': 'Alan Ladd', 'birthYear': 1913, 'deathYear': 1964},
#  {'_id': 43, 'name': 'Veronica Lake', 'birthYear': 1922, 'deathYear': 1973},
#  {'_id': 44, 'name': 'Burt Lancaster', 'birthYear': 1913, 'deathYear': 1994},
#  {'_id': 45, 'name': 'Bruce Lee', 'birthYear': 1940, 'deathYear': 1973},
#  {'_id': 46, 'name': 'Vivien Leigh', 'birthYear': 1913, 'deathYear': 1967},
#  {'_id': 47, 'name': 'Sophia Loren', 'birthYear': 1934},
#  {'_id': 48, 'name': 'Peter Lorre', 'birthYear': 1904, 'deathYear': 1964},
#  {'_id': 49, 'name': 'Henry Mancini', 'birthYear': 1924, 'deathYear': 1994},
#  {'_id': 50, 'name': 'Groucho Marx', 'birthYear': 1890, 'deathYear': 1977},
#  {'_id': 51, 'name': 'James Mason', 'birthYear': 1909, 'deathYear': 1984},
#  {'_id': 52,
#   'name': 'Marcello Mastroianni',
#   'birthYear': 1924,
#   'deathYear': 1996},
#  {'_id': 53, 'name': 'Robert Mitchum', 'birthYear': 1917, 'deathYear': 1997},
#  {'_id': 54, 'name': 'Marilyn Monroe', 'birthYear': 1926, 'deathYear': 1962},
#  {'_id': 55, 'name': 'Alfred Newman', 'birthYear': 1900, 'deathYear': 1970},
#  {'_id': 56, 'name': 'Paul Newman', 'birthYear': 1925, 'deathYear': 2008},
#  {'_id': 57, 'name': 'David Niven', 'birthYear': 1910, 'deathYear': 1983},
#  {'_id': 58, 'name': "Maureen O'Hara", 'birthYear': 1920, 'deathYear': 2015},
#  {'_id': 59, 'name': 'Laurence Olivier', 'birthYear': 1907, 'deathYear': 1989},
#  {'_id': 60, 'name': 'Gregory Peck', 'birthYear': 1916, 'deathYear': 2003},
#  {'_id': 61, 'name': 'Tyrone Power', 'birthYear': 1914, 'deathYear': 1958},
#  {'_id': 62, 'name': 'Elvis Presley', 'birthYear': 1935, 'deathYear': 1977},
#  {'_id': 63, 'name': 'Anthony Quinn', 'birthYear': 1915, 'deathYear': 2001},
#  {'_id': 64,
#   'name': 'Edward G. Robinson',
#   'birthYear': 1893,
#   'deathYear': 1973},
#  {'_id': 65, 'name': 'Nino Rota', 'birthYear': 1911, 'deathYear': 1979},
#  {'_id': 66, 'name': 'Jane Russell', 'birthYear': 1921, 'deathYear': 2011},
#  {'_id': 67, 'name': 'Miklós Rózsa', 'birthYear': 1907, 'deathYear': 1995},
#  {'_id': 68, 'name': 'Randolph Scott', 'birthYear': 1898, 'deathYear': 1987},
#  {'_id': 69, 'name': 'Frank Sinatra', 'birthYear': 1915, 'deathYear': 1998},
#  {'_id': 70, 'name': 'Max Steiner', 'birthYear': 1888, 'deathYear': 1971},
#  {'_id': 71, 'name': 'James Stewart', 'birthYear': 1908, 'deathYear': 1997},
#  {'_id': 72, 'name': 'Elizabeth Taylor', 'birthYear': 1932, 'deathYear': 2011},
#  {'_id': 73, 'name': 'Shirley Temple', 'birthYear': 1928, 'deathYear': 2014},
#  {'_id': 74, 'name': 'Gene Tierney', 'birthYear': 1920, 'deathYear': 1991},
#  {'_id': 75, 'name': 'Spencer Tracy', 'birthYear': 1900, 'deathYear': 1967},
#  {'_id': 76,
#   'name': 'François Truffaut',
#   'birthYear': 1932,
#   'deathYear': 1984},
#  {'_id': 77, 'name': 'Franz Waxman', 'birthYear': 1906, 'deathYear': 1967},
#  {'_id': 78, 'name': 'John Wayne', 'birthYear': 1907, 'deathYear': 1979},
#  {'_id': 79, 'name': 'Raquel Welch', 'birthYear': 1940},
#  {'_id': 80, 'name': 'Orson Welles', 'birthYear': 1915, 'deathYear': 1985},
#  {'_id': 81, 'name': 'Natalie Wood', 'birthYear': 1938, 'deathYear': 1981},
#  {'_id': 82, 'name': 'Victor Young', 'birthYear': 1900, 'deathYear': 1956},
#  {'_id': 83, 'name': 'Alan Miller'},
#  {'_id': 84, 'name': 'Gong Li', 'birthYear': 1965},
#  {'_id': 85, 'name': 'Henner Hofmann', 'birthYear': 1950},
#  {'_id': 86, 'name': 'Louis de Funès', 'birthYear': 1914, 'deathYear': 1983},
#  {'_id': 87, 'name': 'Elena Koreneva', 'birthYear': 1953},
#  {'_id': 88, 'name': 'Aleksey Korenev', 'birthYear': 1927, 'deathYear': 1995},
#  {'_id': 89, 'name': 'Richard Paul', 'birthYear': 1940, 'deathYear': 1998},
#  {'_id': 90, 'name': 'Armin Mueller-Stahl', 'birthYear': 1930},
#  {'_id': 91, 'name': 'Gérard Pirès', 'birthYear': 1942},
#  {'_id': 92, 'name': 'John Cleese', 'birthYear': 1939},
#  {'_id': 93, 'name': 'Brad Pitt', 'birthYear': 1963},
#  {'_id': 94, 'name': 'J. Reifel'},
#  {'_id': 95, 'name': 'Woody Allen', 'birthYear': 1935},
#  {'_id': 96, 'name': 'Gillian Anderson', 'birthYear': 1968},
#  {'_id': 97, 'name': 'Pamela Anderson', 'birthYear': 1967},
#  {'_id': 98, 'name': 'Jennifer Aniston', 'birthYear': 1969},
#  {'_id': 99, 'name': 'Patricia Arquette', 'birthYear': 1968},
#  {'_id': 100, 'name': 'Rowan Atkinson', 'birthYear': 1955},
#  {'_id': 101, 'name': 'Dan Aykroyd', 'birthYear': 1952},
#  {'_id': 102, 'name': 'Kevin Bacon', 'birthYear': 1958},
#  {'_id': 103, 'name': 'Fairuza Balk', 'birthYear': 1974},
#  {'_id': 104, 'name': 'Antonio Banderas', 'birthYear': 1960},
#  {'_id': 105, 'name': 'Adrienne Barbeau', 'birthYear': 1945},
#  {'_id': 106, 'name': 'Drew Barrymore', 'birthYear': 1975},
#  {'_id': 107, 'name': 'Kim Basinger', 'birthYear': 1953},
#  {'_id': 108, 'name': 'Luc Besson', 'birthYear': 1959},
#  {'_id': 109, 'name': 'Yasmine Bleeth', 'birthYear': 1968},
#  {'_id': 110, 'name': 'Kenneth Branagh', 'birthYear': 1960},
#  {'_id': 111, 'name': 'Matthew Broderick', 'birthYear': 1962},
#  {'_id': 112, 'name': 'Pierce Brosnan', 'birthYear': 1953},
#  {'_id': 113, 'name': 'Sandra Bullock', 'birthYear': 1964},
#  {'_id': 114, 'name': 'Steve Buscemi', 'birthYear': 1957},
#  {'_id': 115, 'name': 'Nicolas Cage', 'birthYear': 1964},
#  {'_id': 116, 'name': 'James Cameron', 'birthYear': 1954},
#  {'_id': 117, 'name': 'Neve Campbell', 'birthYear': 1973},
#  {'_id': 118, 'name': 'John Carpenter', 'birthYear': 1948},
#  {'_id': 119, 'name': 'Tia Carrere', 'birthYear': 1967},
#  {'_id': 120, 'name': 'Jim Carrey', 'birthYear': 1962},
#  {'_id': 121, 'name': 'Phoebe Cates', 'birthYear': 1963},
#  {'_id': 122, 'name': 'Charles Chaplin', 'birthYear': 1889, 'deathYear': 1977},
#  {'_id': 123, 'name': 'George Clooney', 'birthYear': 1961},
#  {'_id': 124, 'name': 'Jennifer Connelly', 'birthYear': 1970},
#  {'_id': 125, 'name': 'Sean Connery', 'birthYear': 1930, 'deathYear': 2020},
#  {'_id': 126, 'name': 'Kevin Costner', 'birthYear': 1955},
#  {'_id': 127, 'name': 'Wes Craven', 'birthYear': 1939, 'deathYear': 2015},
#  {'_id': 128, 'name': 'Russell Crowe', 'birthYear': 1964},
#  {'_id': 129, 'name': 'Tom Cruise', 'birthYear': 1962},
#  {'_id': 130, 'name': 'Jamie Lee Curtis', 'birthYear': 1958},
#  {'_id': 131, 'name': 'John Cusack', 'birthYear': 1966},
#  {'_id': 132, 'name': 'Claire Danes', 'birthYear': 1979},
#  {'_id': 133, 'name': 'Geena Davis', 'birthYear': 1956},
#  {'_id': 134, 'name': 'Robert De Niro', 'birthYear': 1943},
#  {'_id': 135, 'name': 'John Denver', 'birthYear': 1943, 'deathYear': 1997},
#  {'_id': 136, 'name': 'Johnny Depp', 'birthYear': 1963},
#  {'_id': 137, 'name': 'Bo Derek', 'birthYear': 1956},
#  {'_id': 138, 'name': 'Leonardo DiCaprio', 'birthYear': 1974},
#  {'_id': 139, 'name': 'Cameron Diaz', 'birthYear': 1972},
#  {'_id': 140, 'name': 'Michael Douglas', 'birthYear': 1944},
#  {'_id': 141, 'name': 'David Duchovny', 'birthYear': 1960},
#  {'_id': 142, 'name': 'Clint Eastwood', 'birthYear': 1930},
#  {'_id': 143, 'name': 'Erika Eleniak', 'birthYear': 1969},
#  {'_id': 144, 'name': 'Cary Elwes', 'birthYear': 1962},
#  {'_id': 145, 'name': 'Sherilyn Fenn', 'birthYear': 1965},
#  {'_id': 146, 'name': 'Ralph Fiennes', 'birthYear': 1962},
#  {'_id': 147, 'name': 'Colin Firth', 'birthYear': 1960},
#  {'_id': 148, 'name': 'Harrison Ford', 'birthYear': 1942},
#  {'_id': 149, 'name': 'Jodie Foster', 'birthYear': 1962},
#  {'_id': 150, 'name': 'Michael J. Fox', 'birthYear': 1961},
#  {'_id': 151, 'name': 'Morgan Freeman', 'birthYear': 1937},
#  {'_id': 152, 'name': 'Richard Gere', 'birthYear': 1949},
#  {'_id': 153, 'name': 'Gina Gershon', 'birthYear': 1962},
#  {'_id': 154, 'name': 'Mel Gibson', 'birthYear': 1956},
#  {'_id': 155, 'name': 'Whoopi Goldberg', 'birthYear': 1955},
#  {'_id': 156, 'name': 'Jeff Goldblum', 'birthYear': 1952},
#  {'_id': 157, 'name': 'Linda Hamilton', 'birthYear': 1956},
#  {'_id': 158, 'name': 'Tom Hanks', 'birthYear': 1956},
#  {'_id': 159, 'name': 'Teri Hatcher', 'birthYear': 1964},
#  {'_id': 160, 'name': 'Ethan Hawke', 'birthYear': 1970},
#  {'_id': 161, 'name': 'Salma Hayek', 'birthYear': 1966},
#  {'_id': 162, 'name': 'Anne Heche', 'birthYear': 1969, 'deathYear': 2022},
#  {'_id': 163, 'name': 'Dustin Hoffman', 'birthYear': 1937},
#  {'_id': 164, 'name': 'Anthony Hopkins', 'birthYear': 1937},
#  {'_id': 165, 'name': 'Ron Howard', 'birthYear': 1954},
#  {'_id': 166, 'name': 'Helen Hunt', 'birthYear': 1963},
#  {'_id': 167, 'name': 'Elizabeth Hurley', 'birthYear': 1965},
#  {'_id': 168, 'name': 'Samuel L. Jackson', 'birthYear': 1948},
#  {'_id': 169, 'name': 'Tommy Lee Jones', 'birthYear': 1946},
#  {'_id': 170, 'name': 'Milla Jovovich', 'birthYear': 1975},
#  {'_id': 171, 'name': 'Ashley Judd', 'birthYear': 1968},
#  {'_id': 172, 'name': 'Harvey Keitel', 'birthYear': 1939},
#  {'_id': 173, 'name': 'Nicole Kidman', 'birthYear': 1967},
#  {'_id': 174, 'name': 'Val Kilmer', 'birthYear': 1959},
#  {'_id': 175, 'name': 'Stephen King', 'birthYear': 1947},
#  {'_id': 176, 'name': 'Nastassja Kinski', 'birthYear': 1961},
#  {'_id': 177, 'name': 'Kevin Kline', 'birthYear': 1947},
#  {'_id': 178, 'name': 'Diane Lane', 'birthYear': 1965},
#  {'_id': 179, 'name': 'Jude Law', 'birthYear': 1972},
#  {'_id': 180, 'name': 'David Lean', 'birthYear': 1908, 'deathYear': 1991},
#  {'_id': 181, 'name': 'Heather Locklear', 'birthYear': 1961},
#  {'_id': 182, 'name': 'Jennifer Lopez', 'birthYear': 1969},
#  {'_id': 183, 'name': 'Traci Lords', 'birthYear': 1968},
#  {'_id': 184, 'name': 'George Lucas', 'birthYear': 1944},
#  {'_id': 185, 'name': 'Dolph Lundgren', 'birthYear': 1957},
#  {'_id': 186, 'name': 'David Lynch', 'birthYear': 1946},
#  {'_id': 187, 'name': 'Madonna', 'birthYear': 1958},
#  {'_id': 188, 'name': 'Steve Martin', 'birthYear': 1945},
#  {'_id': 189, 'name': 'Jenny McCarthy-Wahlberg', 'birthYear': 1972},
#  {'_id': 190, 'name': 'Matthew McConaughey', 'birthYear': 1969},
#  {'_id': 191, 'name': 'Ewan McGregor', 'birthYear': 1971},
#  {'_id': 192, 'name': 'Alyssa Milano', 'birthYear': 1972},
#  {'_id': 193, 'name': 'Demi Moore', 'birthYear': 1962},
#  {'_id': 194, 'name': 'Julianne Moore', 'birthYear': 1960},
#  {'_id': 195, 'name': 'Bill Murray', 'birthYear': 1950},
#  {'_id': 196, 'name': 'Mike Myers', 'birthYear': 1963},
#  {'_id': 197, 'name': 'Jack Nicholson', 'birthYear': 1937},
#  {'_id': 198, 'name': 'Gary Oldman', 'birthYear': 1958},
#  {'_id': 199, 'name': 'Al Pacino', 'birthYear': 1940},
#  {'_id': 200, 'name': 'Bill Paxton', 'birthYear': 1955, 'deathYear': 2017},
#  {'_id': 201, 'name': 'Michelle Pfeiffer', 'birthYear': 1958},
#  {'_id': 202, 'name': 'Ryan Phillippe', 'birthYear': 1974},
#  {'_id': 203, 'name': 'River Phoenix', 'birthYear': 1970, 'deathYear': 1993},
#  {'_id': 204, 'name': 'Natalie Portman', 'birthYear': 1981},
#  {'_id': 205, 'name': 'Parker Posey', 'birthYear': 1968},
#  {'_id': 206, 'name': 'Keanu Reeves', 'birthYear': 1964},
#  {'_id': 207, 'name': 'Christina Ricci', 'birthYear': 1980},
#  {'_id': 208, 'name': 'Molly Ringwald', 'birthYear': 1968},
#  {'_id': 209, 'name': 'Tim Robbins', 'birthYear': 1958},
#  {'_id': 210, 'name': 'Julia Roberts', 'birthYear': 1967},
#  {'_id': 211, 'name': 'Mimi Rogers', 'birthYear': 1956},
#  {'_id': 212, 'name': 'Meg Ryan', 'birthYear': 1961},
#  {'_id': 213, 'name': 'Winona Ryder', 'birthYear': 1971},
#  {'_id': 214, 'name': 'Mia Sara', 'birthYear': 1967},
#  {'_id': 215, 'name': 'Susan Sarandon', 'birthYear': 1946},
#  {'_id': 216, 'name': 'Arnold Schwarzenegger', 'birthYear': 1947},
#  {'_id': 217, 'name': 'Martin Scorsese', 'birthYear': 1942},
#  {'_id': 218, 'name': 'Kristin Scott Thomas', 'birthYear': 1960},
#  {'_id': 219, 'name': 'Steven Seagal', 'birthYear': 1952},
#  {'_id': 220, 'name': 'Joan Severance', 'birthYear': 1958},
#  {'_id': 221, 'name': 'Charlie Sheen', 'birthYear': 1965},
#  {'_id': 222, 'name': 'Brooke Shields', 'birthYear': 1965},
#  {'_id': 223, 'name': 'Elisabeth Shue', 'birthYear': 1963},
#  {'_id': 224, 'name': 'Alicia Silverstone', 'birthYear': 1976},
#  {'_id': 225, 'name': 'Christian Slater', 'birthYear': 1969},
#  {'_id': 226, 'name': 'Will Smith', 'birthYear': 1968},
#  {'_id': 227, 'name': 'Mira Sorvino', 'birthYear': 1967},
#  {'_id': 228, 'name': 'Kevin Spacey', 'birthYear': 1959},
#  {'_id': 229, 'name': 'Steven Spielberg', 'birthYear': 1946},
#  {'_id': 230, 'name': 'Sylvester Stallone', 'birthYear': 1946},
#  {'_id': 231, 'name': 'Oliver Stone', 'birthYear': 1946},
#  {'_id': 232, 'name': 'Sharon Stone', 'birthYear': 1958},
#  {'_id': 233, 'name': 'Quentin Tarantino', 'birthYear': 1963},
#  {'_id': 234, 'name': 'Charlize Theron', 'birthYear': 1975},
#  {'_id': 235, 'name': 'Uma Thurman', 'birthYear': 1970},
#  {'_id': 236, 'name': 'Jennifer Tilly', 'birthYear': 1958},
#  {'_id': 237, 'name': 'John Travolta', 'birthYear': 1954},
#  {'_id': 238, 'name': 'Shannon Tweed', 'birthYear': 1957},
#  {'_id': 239, 'name': 'Liv Tyler', 'birthYear': 1977},
#  {'_id': 240, 'name': 'Skeet Ulrich', 'birthYear': 1970},
#  {'_id': 241, 'name': 'Jean-Claude Van Damme', 'birthYear': 1960},
#  {'_id': 242, 'name': 'Mark Wahlberg', 'birthYear': 1971},
#  {'_id': 243, 'name': 'Denzel Washington', 'birthYear': 1954},
#  {'_id': 244, 'name': 'Sigourney Weaver', 'birthYear': 1949},
#  {'_id': 245, 'name': 'Robin Williams', 'birthYear': 1951, 'deathYear': 2014},
#  {'_id': 246, 'name': 'Bruce Willis', 'birthYear': 1955},
#  {'_id': 247, 'name': 'John Woo', 'birthYear': 1946},
#  {'_id': 248,
#   'name': 'Edward D. Wood Jr.',
#   'birthYear': 1924,
#   'deathYear': 1978},
#  {'_id': 249, 'name': 'James Woods', 'birthYear': 1947},
#  {'_id': 250, 'name': 'Renée Zellweger', 'birthYear': 1969},
#  {'_id': 251, 'name': 'Timothy Dowling', 'birthYear': 1973},
#  {'_id': 252, 'name': 'Robert Ellis', 'birthYear': 1892, 'deathYear': 1974},
#  {'_id': 253, 'name': 'Robert Ellis', 'birthYear': 1888, 'deathYear': 1935},
#  {'_id': 254, 'name': 'Isabelle Adjani', 'birthYear': 1955},
#  {'_id': 255, 'name': 'Ben Affleck', 'birthYear': 1972},
#  {'_id': 256, 'name': 'Jenny Agutter', 'birthYear': 1952},
#  {'_id': 257, 'name': 'Alan Alda', 'birthYear': 1936},
#  {'_id': 258, 'name': 'Stephanie Zimbalist', 'birthYear': 1956},
#  {'_id': 259, 'name': 'Ginger Lynn', 'birthYear': 1962},
#  {'_id': 260, 'name': 'Joan Allen', 'birthYear': 1956},
#  {'_id': 261, 'name': 'Karen Allen', 'birthYear': 1951},
#  {'_id': 262, 'name': 'Nancy Allen', 'birthYear': 1950},
#  {'_id': 263, 'name': 'Kirstie Alley', 'birthYear': 1951, 'deathYear': 2022},
#  {'_id': 264, 'name': 'Pedro Almodóvar', 'birthYear': 1949},
#  {'_id': 265, 'name': 'Robert Altman', 'birthYear': 1925, 'deathYear': 2006},
#  {'_id': 266, 'name': 'Ursula Andress', 'birthYear': 1936},
#  {'_id': 267, 'name': 'Julie Andrews', 'birthYear': 1935},
#  {'_id': 268, 'name': 'Ann-Margret', 'birthYear': 1941},
#  {'_id': 269, 'name': 'Jean-Jacques Annaud', 'birthYear': 1943},
#  {'_id': 270, 'name': 'Gabrielle Anwar', 'birthYear': 1970},
#  {'_id': 271, 'name': 'Anne Archer', 'birthYear': 1947},
#  {'_id': 272, 'name': 'Fanny Ardant', 'birthYear': 1949},
#  {'_id': 273, 'name': 'Alan Arkin', 'birthYear': 1934},
#  {'_id': 274, 'name': 'David Arquette', 'birthYear': 1971},
#  {'_id': 275, 'name': 'Rosanna Arquette', 'birthYear': 1959},
#  {'_id': 276, 'name': 'Sean Astin', 'birthYear': 1971},
#  {'_id': 277,
#   'name': 'Richard Attenborough',
#   'birthYear': 1923,
#   'deathYear': 2014},
#  {'_id': 278, 'name': 'Pernilla August', 'birthYear': 1958},
#  {'_id': 279, 'name': 'Hank Azaria', 'birthYear': 1964},
#  {'_id': 280, 'name': 'Catherine Bach', 'birthYear': 1954},
#  {'_id': 281, 'name': 'Scott Baio', 'birthYear': 1960},
#  {'_id': 282, 'name': 'Scott Bairstow', 'birthYear': 1970},
#  {'_id': 283, 'name': 'Brenda Bakke', 'birthYear': 1963},
#  {'_id': 284, 'name': 'Adam Baldwin', 'birthYear': 1962},
#  {'_id': 285, 'name': 'Alec Baldwin', 'birthYear': 1958},
#  {'_id': 286, 'name': 'Stephen Baldwin', 'birthYear': 1966},
#  {'_id': 287, 'name': 'William Baldwin', 'birthYear': 1963},
#  {'_id': 288, 'name': 'Christian Bale', 'birthYear': 1974},
#  {'_id': 289, 'name': 'Ellen Barkin', 'birthYear': 1954},
#  {'_id': 290, 'name': 'John Barry', 'birthYear': 1933, 'deathYear': 2011},
#  {'_id': 291, 'name': 'Angela Bassett', 'birthYear': 1958},
#  {'_id': 292, 'name': 'Michelle Bauer', 'birthYear': 1958},
#  {'_id': 293, 'name': 'Sean Bean', 'birthYear': 1959},
#  {'_id': 294, 'name': 'Amanda Bearse', 'birthYear': 1958},
#  {'_id': 295, 'name': 'Kate Beckinsale', 'birthYear': 1973},
#  {'_id': 296, 'name': 'Robert Beltran', 'birthYear': 1953},
#  {'_id': 297, 'name': 'Tom Berenger', 'birthYear': 1949},
#  {'_id': 298, 'name': 'Candice Bergen', 'birthYear': 1946},
#  {'_id': 299, 'name': 'Michael Biehn', 'birthYear': 1956},
#  {'_id': 300, 'name': 'Juliette Binoche', 'birthYear': 1964},
#  {'_id': 301, 'name': 'Thora Birch', 'birthYear': 1982},
#  {'_id': 302, 'name': 'Jacqueline Bisset', 'birthYear': 1944},
#  {'_id': 303, 'name': 'Honor Blackman', 'birthYear': 1925, 'deathYear': 2020},
#  {'_id': 304, 'name': 'Linda Blair', 'birthYear': 1959},
#  {'_id': 305, 'name': 'Mel Blanc', 'birthYear': 1908, 'deathYear': 1989},
#  {'_id': 306, 'name': 'Brian Blessed', 'birthYear': 1936},
#  {'_id': 307, 'name': 'Helena Bonham Carter', 'birthYear': 1966},
#  {'_id': 308, 'name': 'Ernest Borgnine', 'birthYear': 1917, 'deathYear': 2012},
#  {'_id': 309, 'name': 'David Bowie', 'birthYear': 1947, 'deathYear': 2016},
#  {'_id': 310, 'name': 'Bruce Boxleitner', 'birthYear': 1950},
#  {'_id': 311, 'name': 'Annie Rosar', 'birthYear': 1888, 'deathYear': 1963},
#  {'_id': 312, 'name': 'Amy Brenneman', 'birthYear': 1964},
#  {'_id': 313, 'name': 'Jeff Bridges', 'birthYear': 1949},
#  {'_id': 314, 'name': 'Charles Bronson', 'birthYear': 1921, 'deathYear': 2003},
#  {'_id': 315, 'name': 'Louise Brooks', 'birthYear': 1906, 'deathYear': 1985},
#  {'_id': 316, 'name': 'Mel Brooks', 'birthYear': 1926},
#  {'_id': 317, 'name': 'Clancy Brown', 'birthYear': 1959},
#  {'_id': 318, 'name': 'Tim Burton', 'birthYear': 1958},
#  {'_id': 319, 'name': 'Yancy Butler', 'birthYear': 1970},
#  {'_id': 320, 'name': 'Luis Buñuel', 'birthYear': 1900, 'deathYear': 1983},
#  {'_id': 321, 'name': 'Gabriel Byrne', 'birthYear': 1950},
#  {'_id': 322, 'name': 'Emmanuelle Béart', 'birthYear': 1963},
#  {'_id': 323, 'name': 'Michael Caine', 'birthYear': 1933},
#  {'_id': 324, 'name': 'Barbara Carrera', 'birthYear': 1945},
#  {'_id': 325, 'name': 'David Caruso', 'birthYear': 1956},
#  {'_id': 326, 'name': 'Kim Cattrall', 'birthYear': 1956},
#  {'_id': 327, 'name': 'Lacey Chabert', 'birthYear': 1982},
#  {'_id': 328, 'name': 'Richard Chamberlain', 'birthYear': 1934},
#  {'_id': 329, 'name': 'Jackie Chan', 'birthYear': 1954},
#  {'_id': 330, 'name': 'Stockard Channing', 'birthYear': 1944},
#  {'_id': 331, 'name': 'Chevy Chase', 'birthYear': 1943},
#  {'_id': 332, 'name': 'Don Cheadle', 'birthYear': 1964},
#  {'_id': 333, 'name': 'Cher', 'birthYear': 1946},
#  {'_id': 334, 'name': 'Chow Yun-Fat', 'birthYear': 1955},
#  {'_id': 335, 'name': 'Glenn Close', 'birthYear': 1947},
#  {'_id': 336, 'name': 'James Coburn', 'birthYear': 1928, 'deathYear': 2002},
#  {'_id': 337, 'name': 'Rachael Leigh Cook', 'birthYear': 1979},
#  {'_id': 338, 'name': 'Francis Ford Coppola', 'birthYear': 1939},
#  {'_id': 339, 'name': 'Roger Corman', 'birthYear': 1926},
#  {'_id': 340, 'name': 'Cindy Crawford', 'birthYear': 1966},
#  {'_id': 341,
#   'name': 'Michael Crichton',
#   'birthYear': 1942,
#   'deathYear': 2008},
#  {'_id': 342, 'name': 'James Cromwell', 'birthYear': 1940},
#  {'_id': 343, 'name': 'David Cronenberg', 'birthYear': 1943},
#  {'_id': 344, 'name': 'Denise Crosby'},
#  {'_id': 345, 'name': 'Billy Crystal', 'birthYear': 1948},
#  {'_id': 346, 'name': 'Macaulay Culkin', 'birthYear': 1980},
#  {'_id': 347, 'name': 'Tim Curry', 'birthYear': 1946},
#  {'_id': 348, 'name': 'Tony Curtis', 'birthYear': 1925, 'deathYear': 2010},
#  {'_id': 349, 'name': 'Joan Cusack', 'birthYear': 1962},
#  {'_id': 350, 'name': "Beverly D'Angelo", 'birthYear': 1951},
#  {'_id': 351, 'name': "Donna D'Errico", 'birthYear': 1968},
#  {'_id': 352, 'name': "Vincent D'Onofrio", 'birthYear': 1959},
#  {'_id': 353, 'name': 'Willem Dafoe', 'birthYear': 1955},
#  {'_id': 354, 'name': 'Matt Damon', 'birthYear': 1970},
#  {'_id': 355, 'name': 'Anthony Daniels', 'birthYear': 1946},
#  {'_id': 356, 'name': 'Sybil Danning'},
#  {'_id': 357, 'name': 'Lolita Davidovich', 'birthYear': 1961},
#  {'_id': 358, 'name': 'Daniel Day-Lewis', 'birthYear': 1957},
#  {'_id': 359, 'name': 'Olivier De Funès', 'birthYear': 1949},
#  {'_id': 360, 'name': 'Rebecca De Mornay', 'birthYear': 1959},
#  {'_id': 361, 'name': 'Brian De Palma', 'birthYear': 1940},
#  {'_id': 362, 'name': 'Danny DeVito', 'birthYear': 1944},
#  {'_id': 363, 'name': 'Loren Dean', 'birthYear': 1969},
#  {'_id': 364, 'name': 'Sandra Dee', 'birthYear': 1942, 'deathYear': 2005},
#  {'_id': 365, 'name': 'Julie Delpy', 'birthYear': 1969},
#  {'_id': 366, 'name': 'Catherine Deneuve', 'birthYear': 1943},
#  {'_id': 367, 'name': 'Gérard Depardieu', 'birthYear': 1948},
#  {'_id': 368, 'name': 'Laura Dern', 'birthYear': 1967},
#  {'_id': 369, 'name': 'Matt Dillon', 'birthYear': 1964},
#  {'_id': 370, 'name': 'Walt Disney', 'birthYear': 1901, 'deathYear': 1966},
#  {'_id': 371, 'name': 'Ami Dolenz', 'birthYear': 1969},
#  {'_id': 372, 'name': 'Amanda Donohoe', 'birthYear': 1962},
#  {'_id': 373, 'name': 'Michael Dorn', 'birthYear': 1952},
#  {'_id': 374, 'name': 'Brad Dourif', 'birthYear': 1950},
#  {'_id': 375, 'name': 'Robert Downey Jr.', 'birthYear': 1965},
#  {'_id': 376, 'name': 'Fran Drescher', 'birthYear': 1957},
#  {'_id': 377, 'name': 'Richard Dreyfuss', 'birthYear': 1947},
#  {'_id': 378, 'name': 'Minnie Driver', 'birthYear': 1970},
#  {'_id': 379, 'name': 'Kirsten Dunst', 'birthYear': 1982},
#  {'_id': 380, 'name': 'Robert Duvall', 'birthYear': 1931},
#  {'_id': 381, 'name': 'Anthony Edwards', 'birthYear': 1962},
#  {'_id': 382, 'name': 'Atom Egoyan', 'birthYear': 1960},
#  {'_id': 383, 'name': 'Jennifer Ehle', 'birthYear': 1969},
#  {'_id': 384, 'name': 'Danny Elfman', 'birthYear': 1953},
#  {'_id': 385, 'name': 'Sam Elliott', 'birthYear': 1944},
#  {'_id': 386, 'name': 'Roland Emmerich', 'birthYear': 1955},
#  {'_id': 387, 'name': 'Robert Englund', 'birthYear': 1947},
#  {'_id': 388, 'name': 'R. Lee Ermey', 'birthYear': 1944, 'deathYear': 2018},
#  {'_id': 389, 'name': 'Emilio Estevez', 'birthYear': 1962},
#  {'_id': 390, 'name': 'Joe Eszterhas', 'birthYear': 1944},
#  {'_id': 391, 'name': 'Rupert Everett', 'birthYear': 1959},
#  {'_id': 392, 'name': 'Morgan Fairchild', 'birthYear': 1950},
#  {'_id': 393, 'name': 'Peter Falk', 'birthYear': 1927, 'deathYear': 2011},
#  {'_id': 394, 'name': 'Chris Farley', 'birthYear': 1964, 'deathYear': 1997},
#  {'_id': 395, 'name': 'Terry Farrell', 'birthYear': 1963},
#  {'_id': 396, 'name': 'Farrah Fawcett', 'birthYear': 1947, 'deathYear': 2009},
#  {'_id': 397, 'name': 'Corey Feldman', 'birthYear': 1971},
#  {'_id': 398, 'name': 'Sally Field', 'birthYear': 1946},
#  {'_id': 399, 'name': 'David Fincher', 'birthYear': 1962},
#  {'_id': 400, 'name': 'Linda Fiorentino', 'birthYear': 1958},
#  {'_id': 401, 'name': 'Laurence Fishburne', 'birthYear': 1961},
#  {'_id': 402, 'name': 'Carrie Fisher', 'birthYear': 1956, 'deathYear': 2016},
#  {'_id': 403, 'name': 'Bridget Fonda', 'birthYear': 1964},
#  {'_id': 404, 'name': 'Jane Fonda', 'birthYear': 1937},
#  {'_id': 405, 'name': 'Michelle Forbes', 'birthYear': 1965},
#  {'_id': 406, 'name': 'John Ford', 'birthYear': 1894, 'deathYear': 1973},
#  {'_id': 407, 'name': 'Vivica A. Fox', 'birthYear': 1964},
#  {'_id': 408, 'name': 'Jonathan Frakes', 'birthYear': 1952},
#  {'_id': 409, 'name': 'Brendan Fraser', 'birthYear': 1968},
#  {'_id': 410, 'name': 'Stephen Fry', 'birthYear': 1957},
#  {'_id': 411, 'name': 'Edward Furlong', 'birthYear': 1977},
#  {'_id': 412, 'name': 'Andy Garcia', 'birthYear': 1956},
#  {'_id': 413, 'name': 'Janeane Garofalo', 'birthYear': 1964},
#  {'_id': 414, 'name': 'Teri Garr', 'birthYear': 1947},
#  {'_id': 415, 'name': 'Jami Gertz', 'birthYear': 1965},
#  {'_id': 416, 'name': 'Terry Gilliam', 'birthYear': 1940},
#  {'_id': 417, 'name': 'Crispin Glover', 'birthYear': 1964},
#  {'_id': 418, 'name': 'Danny Glover', 'birthYear': 1946},
#  {'_id': 419, 'name': 'Jean-Luc Godard', 'birthYear': 1930, 'deathYear': 2022},
#  {'_id': 420, 'name': 'Valeria Golino', 'birthYear': 1965},
#  {'_id': 421, 'name': 'Cuba Gooding Jr.', 'birthYear': 1968},
#  {'_id': 422, 'name': 'John Goodman', 'birthYear': 1952},
#  {'_id': 423, 'name': 'Serena Grandi', 'birthYear': 1958},
#  {'_id': 424, 'name': 'Hugh Grant', 'birthYear': 1960},
#  {'_id': 425, 'name': 'Peter Greenaway', 'birthYear': 1942},
#  {'_id': 426, 'name': 'Jennifer Grey', 'birthYear': 1960},
#  {'_id': 427, 'name': 'Pam Grier', 'birthYear': 1949},
#  {'_id': 428, 'name': 'D.W. Griffith', 'birthYear': 1875, 'deathYear': 1948},
#  {'_id': 429, 'name': 'Melanie Griffith', 'birthYear': 1957},
#  {'_id': 430, 'name': 'Steve Guttenberg', 'birthYear': 1958},
#  {'_id': 431, 'name': 'Taylor Hackford', 'birthYear': 1944},
#  {'_id': 432, 'name': 'Gene Hackman', 'birthYear': 1930},
#  {'_id': 433, 'name': 'Corey Haim', 'birthYear': 1971, 'deathYear': 2010},
#  {'_id': 434, 'name': 'Mark Hamill', 'birthYear': 1951},
#  {'_id': 435, 'name': 'Daryl Hannah', 'birthYear': 1960},
#  {'_id': 436, 'name': 'Curtis Hanson', 'birthYear': 1945, 'deathYear': 2016},
#  {'_id': 437, 'name': 'Woody Harrelson', 'birthYear': 1961},
#  {'_id': 438, 'name': 'Ed Harris', 'birthYear': 1950},
#  {'_id': 439, 'name': 'Neil Patrick Harris', 'birthYear': 1973},
#  {'_id': 440, 'name': 'Nina Hartley', 'birthYear': 1959},
#  {'_id': 441, 'name': 'Noah Hathaway', 'birthYear': 1971},
#  {'_id': 442, 'name': 'Rutger Hauer', 'birthYear': 1944, 'deathYear': 2019},
#  {'_id': 443, 'name': 'Goldie Hawn', 'birthYear': 1945},
#  {'_id': 444, 'name': 'Glenne Headly', 'birthYear': 1955, 'deathYear': 2017},
#  {'_id': 445, 'name': 'Dan Hedaya', 'birthYear': 1940},
#  {'_id': 446, 'name': 'Mariel Hemingway', 'birthYear': 1961},
#  {'_id': 447, 'name': 'Marilu Henner', 'birthYear': 1952},
#  {'_id': 448, 'name': 'Lance Henriksen', 'birthYear': 1940},
#  {'_id': 449, 'name': 'Natasha Henstridge', 'birthYear': 1974},
#  {'_id': 450,
#   'name': 'Philip Seymour Hoffman',
#   'birthYear': 1967,
#   'deathYear': 2014},
#  {'_id': 451, 'name': 'Gaby Hoffmann', 'birthYear': 1982},
#  {'_id': 452, 'name': 'Lauren Holly', 'birthYear': 1963},
#  {'_id': 453, 'name': 'Ian Holm', 'birthYear': 1931, 'deathYear': 2020},
#  {'_id': 454, 'name': 'Dennis Hopper', 'birthYear': 1936, 'deathYear': 2010},
#  {'_id': 455, 'name': 'John Hughes', 'birthYear': 1950, 'deathYear': 2009},
#  {'_id': 456, 'name': 'Holly Hunter', 'birthYear': 1958},
#  {'_id': 457, 'name': 'John Hurt', 'birthYear': 1940, 'deathYear': 2017},
#  {'_id': 458, 'name': 'William Hurt', 'birthYear': 1950, 'deathYear': 2022},
#  {'_id': 459, 'name': 'Timothy Hutton', 'birthYear': 1960},
#  {'_id': 460, 'name': 'Jeremy Irons', 'birthYear': 1948},
#  {'_id': 461, 'name': 'Michael Ironside', 'birthYear': 1950},
#  {'_id': 462, 'name': 'Kate Jackson', 'birthYear': 1948},
#  {'_id': 463, 'name': 'Famke Janssen', 'birthYear': 1964},
#  {'_id': 464, 'name': 'Jim Jarmusch', 'birthYear': 1953},
#  {'_id': 465, 'name': 'Ron Jeremy', 'birthYear': 1953},
#  {'_id': 466, 'name': 'Jean-Pierre Jeunet', 'birthYear': 1953},
#  {'_id': 467, 'name': 'Don Johnson', 'birthYear': 1949},
#  {'_id': 468, 'name': 'Lynn-Holly Johnson', 'birthYear': 1958},
#  {'_id': 469, 'name': 'James Earl Jones', 'birthYear': 1931},
#  {'_id': 470, 'name': 'Jeffrey Jones', 'birthYear': 1946},
#  {'_id': 471, 'name': 'Raul Julia', 'birthYear': 1940, 'deathYear': 1994},
#  {'_id': 472, 'name': 'Boris Karloff', 'birthYear': 1887, 'deathYear': 1969},
#  {'_id': 473, 'name': 'Diane Keaton', 'birthYear': 1946},
#  {'_id': 474, 'name': 'Michael Keaton', 'birthYear': 1951},
#  {'_id': 475, 'name': 'Patsy Kensit', 'birthYear': 1968},
#  {'_id': 476, 'name': 'Sally Kirkland', 'birthYear': 1941},
#  {'_id': 477, 'name': 'Mia Kirshner', 'birthYear': 1975},
#  {'_id': 478, 'name': 'Tawny Kitaen', 'birthYear': 1961, 'deathYear': 2021},
#  {'_id': 479, 'name': 'Walter Koenig', 'birthYear': 1936},
#  {'_id': 480, 'name': 'Elias Koteas', 'birthYear': 1961},
#  {'_id': 481, 'name': 'Alice Krige', 'birthYear': 1954},
#  {'_id': 482, 'name': 'Sylvia Kristel', 'birthYear': 1952, 'deathYear': 2012},
#  {'_id': 483, 'name': 'Christopher Lambert', 'birthYear': 1957},
#  {'_id': 484, 'name': 'John Landis', 'birthYear': 1950},
#  {'_id': 485, 'name': 'Fritz Lang', 'birthYear': 1890, 'deathYear': 1976},
#  {'_id': 486, 'name': 'Heather Langenkamp', 'birthYear': 1964},
#  {'_id': 487, 'name': 'Ang Lee', 'birthYear': 1954},
#  {'_id': 488, 'name': 'Brandon Lee', 'birthYear': 1965, 'deathYear': 1993},
#  {'_id': 489, 'name': 'Christopher Lee', 'birthYear': 1922, 'deathYear': 2015},
#  {'_id': 490, 'name': 'Spike Lee', 'birthYear': 1957},
#  {'_id': 491, 'name': 'John Leguizamo', 'birthYear': 1960},
#  {'_id': 492, 'name': 'Jennifer Jason Leigh', 'birthYear': 1962},
#  {'_id': 493, 'name': 'Jack Lemmon', 'birthYear': 1925, 'deathYear': 2001},
#  {'_id': 494, 'name': 'Robert Sean Leonard', 'birthYear': 1969},
#  {'_id': 495, 'name': 'Téa Leoni', 'birthYear': 1966},
#  {'_id': 496, 'name': 'Juliette Lewis', 'birthYear': 1973},
#  {'_id': 497, 'name': 'Jennifer Lien', 'birthYear': 1974},
#  {'_id': 498, 'name': 'Matthew Lillard', 'birthYear': 1970},
#  {'_id': 499, 'name': 'Bai Ling'},
#  {'_id': 500, 'name': 'Richard Linklater', 'birthYear': 1960},
#  {'_id': 501, 'name': 'Ray Liotta', 'birthYear': 1954, 'deathYear': 2022},
#  {'_id': 502, 'name': 'Christopher Lloyd', 'birthYear': 1938},
#  {'_id': 503, 'name': 'Emily Lloyd', 'birthYear': 1970},
#  {'_id': 504, 'name': 'Amy Locane', 'birthYear': 1971},
#  {'_id': 505, 'name': 'Nia Long', 'birthYear': 1970},
#  {'_id': 506, 'name': 'Julia Louis-Dreyfus', 'birthYear': 1961},
#  {'_id': 507, 'name': 'Rob Lowe', 'birthYear': 1964},
#  {'_id': 508, 'name': 'Carey Lowell', 'birthYear': 1961},
#  {'_id': 509, 'name': 'Bela Lugosi', 'birthYear': 1882, 'deathYear': 1956},
#  {'_id': 510, 'name': 'Andie MacDowell', 'birthYear': 1958},
#  {'_id': 511, 'name': 'Shirley MacLaine', 'birthYear': 1934},
#  {'_id': 512, 'name': 'Elle Macpherson', 'birthYear': 1964},
#  {'_id': 513, 'name': 'William H. Macy', 'birthYear': 1950},
#  {'_id': 514, 'name': 'Michael Madsen', 'birthYear': 1957},
#  {'_id': 515, 'name': 'Virginia Madsen', 'birthYear': 1961},
#  {'_id': 516, 'name': 'Lee Majors', 'birthYear': 1939},
#  {'_id': 517, 'name': 'Terrence Malick', 'birthYear': 1943},
#  {'_id': 518, 'name': 'John Malkovich', 'birthYear': 1953},
#  {'_id': 519, 'name': 'David Mamet', 'birthYear': 1947},
#  {'_id': 520, 'name': 'Michael Mann', 'birthYear': 1943},
#  {'_id': 521, 'name': 'Sophie Marceau', 'birthYear': 1966},
#  {'_id': 522, 'name': 'Vanessa Marcil', 'birthYear': 1968},
#  {'_id': 523, 'name': 'Julianna Margulies', 'birthYear': 1966},
#  {'_id': 524, 'name': 'Mary Stuart Masterson', 'birthYear': 1966},
#  {'_id': 525, 'name': 'Heather Matarazzo', 'birthYear': 1982},
#  {'_id': 526, 'name': 'Samantha Mathis', 'birthYear': 1970},
#  {'_id': 527, 'name': 'Walter Matthau', 'birthYear': 1920, 'deathYear': 2000},
#  {'_id': 528, 'name': 'Mathilda May', 'birthYear': 1965},
#  {'_id': 529, 'name': 'Debi Mazar', 'birthYear': 1964},
#  {'_id': 530, 'name': 'Andrew McCarthy', 'birthYear': 1962},
#  {'_id': 531, 'name': 'Frances McDormand', 'birthYear': 1957},
#  {'_id': 532, 'name': 'Malcolm McDowell', 'birthYear': 1943},
#  {'_id': 533, 'name': 'Gates McFadden', 'birthYear': 1949},
#  {'_id': 534, 'name': 'Kelly McGillis', 'birthYear': 1957},
#  {'_id': 535, 'name': 'Rose McGowan', 'birthYear': 1973},
#  {'_id': 536, 'name': 'Robert Duncan McNeill', 'birthYear': 1964},
#  {'_id': 537, 'name': 'Steve McQueen', 'birthYear': 1930, 'deathYear': 1980},
#  {'_id': 538, 'name': 'Colm Meaney', 'birthYear': 1953},
#  {'_id': 539, 'name': 'Dina Meyer', 'birthYear': 1968},
#  {'_id': 540, 'name': 'Russ Meyer', 'birthYear': 1922, 'deathYear': 2004},
#  {'_id': 541, 'name': 'Bette Midler', 'birthYear': 1945},
#  {'_id': 542, 'name': 'Penelope Ann Miller', 'birthYear': 1964},
#  {'_id': 543, 'name': 'Sal Mineo', 'birthYear': 1939, 'deathYear': 1976},
#  {'_id': 544, 'name': 'Carmen Miranda', 'birthYear': 1909, 'deathYear': 1955},
#  {'_id': 545, 'name': 'Helen Mirren', 'birthYear': 1945},
#  {'_id': 546, 'name': 'Matthew Modine', 'birthYear': 1959},
#  {'_id': 547, 'name': 'Alfred Molina', 'birthYear': 1953},
#  {'_id': 548,
#   'name': 'Elizabeth Montgomery',
#   'birthYear': 1933,
#   'deathYear': 1995},
#  {'_id': 549, 'name': 'Roger Moore', 'birthYear': 1927, 'deathYear': 2017},
#  {'_id': 550, 'name': 'Kate Mulgrew', 'birthYear': 1955},
#  {'_id': 551, 'name': 'Dermot Mulroney', 'birthYear': 1963},
#  {'_id': 552, 'name': 'Eddie Murphy', 'birthYear': 1961},
#  {'_id': 553, 'name': 'Liam Neeson', 'birthYear': 1952},
#  {'_id': 554, 'name': 'Sam Neill', 'birthYear': 1947},
#  {'_id': 555, 'name': 'Judd Nelson', 'birthYear': 1959},
#  {'_id': 556,
#   'name': 'Olivia Newton-John',
#   'birthYear': 1948,
#   'deathYear': 2022},
#  {'_id': 557, 'name': 'Brigitte Nielsen', 'birthYear': 1963},
#  {'_id': 558, 'name': 'Leslie Nielsen', 'birthYear': 1926, 'deathYear': 2010},
#  {'_id': 559, 'name': 'Leonard Nimoy', 'birthYear': 1931, 'deathYear': 2015},
#  {'_id': 560, 'name': 'Nick Nolte', 'birthYear': 1941},
#  {'_id': 561, 'name': 'Peter North', 'birthYear': 1957},
#  {'_id': 562, 'name': 'Jeremy Northam', 'birthYear': 1961},
#  {'_id': 563, 'name': "Chris O'Donnell", 'birthYear': 1970},
#  {'_id': 564, 'name': "Peter O'Toole", 'birthYear': 1932, 'deathYear': 2013},
#  {'_id': 565, 'name': 'Lena Olin', 'birthYear': 1955},
#  {'_id': 566, 'name': 'Julia Ormond', 'birthYear': 1965},
#  {'_id': 567, 'name': 'George Orwell', 'birthYear': 1903, 'deathYear': 1950},
#  {'_id': 568, 'name': 'Frank Oz', 'birthYear': 1944},
#  {'_id': 569, 'name': 'Gwyneth Paltrow', 'birthYear': 1972},
#  {'_id': 570, 'name': 'Alan Parker', 'birthYear': 1944, 'deathYear': 2020},
#  {'_id': 571, 'name': 'Mary-Louise Parker', 'birthYear': 1964},
#  {'_id': 572, 'name': 'Sarah Jessica Parker', 'birthYear': 1965},
#  {'_id': 573, 'name': 'Dolly Parton', 'birthYear': 1946},
#  {'_id': 574, 'name': 'Jason Patric', 'birthYear': 1966},
#  {'_id': 575, 'name': 'Alexandra Paul', 'birthYear': 1963},
#  {'_id': 576, 'name': 'Sean Penn', 'birthYear': 1960},
#  {'_id': 577, 'name': 'George Peppard', 'birthYear': 1928, 'deathYear': 1994},
#  {'_id': 578, 'name': 'Anthony Perkins', 'birthYear': 1932, 'deathYear': 1992},
#  {'_id': 579, 'name': 'Ron Perlman', 'birthYear': 1950},
#  {'_id': 580, 'name': 'Luke Perry', 'birthYear': 1966, 'deathYear': 2019},
#  {'_id': 581,
#   'name': 'Joseph L. Mankiewicz',
#   'birthYear': 1909,
#   'deathYear': 1993},
#  {'_id': 582, 'name': 'Joe Pesci', 'birthYear': 1943},
#  {'_id': 583,
#   'name': 'Wolfgang Petersen',
#   'birthYear': 1941,
#   'deathYear': 2022},
#  {'_id': 584, 'name': 'Amanda Peterson', 'birthYear': 1971, 'deathYear': 2015},
#  {'_id': 585, 'name': 'Robert Picardo', 'birthYear': 1953},
#  {'_id': 586, 'name': 'Jada Pinkett Smith', 'birthYear': 1971},
#  {'_id': 587,
#   'name': 'Donald Pleasence',
#   'birthYear': 1919,
#   'deathYear': 1995},
#  {'_id': 588, 'name': 'Martha Plimpton', 'birthYear': 1970},
#  {'_id': 589, 'name': 'Eve Plumb', 'birthYear': 1958},
#  {'_id': 590, 'name': 'Edgar Allan Poe', 'birthYear': 1809, 'deathYear': 1849},
#  {'_id': 591, 'name': 'Roman Polanski', 'birthYear': 1933},
#  {'_id': 592,
#   'name': 'Pete Postlethwaite',
#   'birthYear': 1946,
#   'deathYear': 2011},
#  {'_id': 593, 'name': 'Kelly Preston', 'birthYear': 1962, 'deathYear': 2020},
#  {'_id': 594, 'name': 'Jason Priestley', 'birthYear': 1969},
#  {'_id': 595, 'name': 'Victoria Principal', 'birthYear': 1950},
#  {'_id': 596, 'name': 'Jonathan Pryce', 'birthYear': 1947},
#  {'_id': 597, 'name': 'Bill Pullman', 'birthYear': 1953},
#  {'_id': 598, 'name': 'Dennis Quaid', 'birthYear': 1954},
#  {'_id': 599, 'name': 'Kathleen Quinlan', 'birthYear': 1954},
#  {'_id': 600, 'name': 'Sam Raimi', 'birthYear': 1959},
#  {'_id': 601, 'name': 'Harold Ramis', 'birthYear': 1944, 'deathYear': 2014},
#  {'_id': 602, 'name': 'Robert Redford', 'birthYear': 1936},
#  {'_id': 603, 'name': 'Vanessa Redgrave', 'birthYear': 1937},
#  {'_id': 604, 'name': 'John C. Reilly', 'birthYear': 1965},
#  {'_id': 605, 'name': 'Brad Renfro', 'birthYear': 1982, 'deathYear': 2008},
#  {'_id': 606, 'name': 'Jean Reno', 'birthYear': 1948},
#  {'_id': 607, 'name': 'Paul Reubens', 'birthYear': 1952},
#  {'_id': 608, 'name': 'Burt Reynolds', 'birthYear': 1936, 'deathYear': 2018},
#  {'_id': 609, 'name': 'Ving Rhames', 'birthYear': 1959},
#  {'_id': 610, 'name': 'Giovanni Ribisi', 'birthYear': 1974},
#  {'_id': 611, 'name': 'Ariana Richards', 'birthYear': 1979},
#  {'_id': 612, 'name': 'Denise Richards', 'birthYear': 1971},
#  {'_id': 613, 'name': 'Joely Richardson', 'birthYear': 1965},
#  {'_id': 614, 'name': 'Alan Rickman', 'birthYear': 1946, 'deathYear': 2016},
#  {'_id': 615, 'name': 'John Ritter', 'birthYear': 1948, 'deathYear': 2003},
#  {'_id': 616, 'name': 'Eric Roberts', 'birthYear': 1956},
#  {'_id': 617, 'name': 'Tanya Roberts', 'birthYear': 1949, 'deathYear': 2021},
#  {'_id': 618, 'name': 'Isabella Rossellini', 'birthYear': 1952},
#  {'_id': 619, 'name': 'Tim Roth', 'birthYear': 1961},
#  {'_id': 620, 'name': 'Mickey Rourke', 'birthYear': 1952},
#  {'_id': 621, 'name': 'Kurt Russell', 'birthYear': 1951},
#  {'_id': 622, 'name': 'Theresa Russell', 'birthYear': 1957},
#  {'_id': 623, 'name': 'Rene Russo', 'birthYear': 1954},
#  {'_id': 624, 'name': 'Laura San Giacomo', 'birthYear': 1961},
#  {'_id': 625, 'name': 'Fred Savage', 'birthYear': 1976},
#  {'_id': 626, 'name': 'John Sayles', 'birthYear': 1950},
#  {'_id': 627, 'name': 'Greta Scacchi', 'birthYear': 1960},
#  {'_id': 628, 'name': 'Johnathon Schaech', 'birthYear': 1969},
#  {'_id': 629, 'name': 'Claudia Schiffer', 'birthYear': 1970},
#  {'_id': 630, 'name': 'Liev Schreiber', 'birthYear': 1967},
#  {'_id': 631, 'name': 'Ridley Scott', 'birthYear': 1937},
#  {'_id': 632, 'name': 'Jerry Seinfeld', 'birthYear': 1954},
#  {'_id': 633, 'name': 'Tom Selleck', 'birthYear': 1945},
#  {'_id': 634, 'name': 'Peter Sellers', 'birthYear': 1925, 'deathYear': 1980},
#  {'_id': 635, 'name': 'Yahoo Serious', 'birthYear': 1953},
#  {'_id': 636,
#   'name': 'William Shakespeare',
#   'birthYear': 1564,
#   'deathYear': 1616},
#  {'_id': 637, 'name': 'Tupac Shakur', 'birthYear': 1971, 'deathYear': 1996},
#  {'_id': 638, 'name': 'William Shatner', 'birthYear': 1931},
#  {'_id': 639, 'name': 'Ally Sheedy', 'birthYear': 1962},
#  {'_id': 640, 'name': 'Martin Sheen', 'birthYear': 1940},
#  {'_id': 641, 'name': 'Gary Sinise', 'birthYear': 1955},
#  {'_id': 642, 'name': 'Marina Sirtis', 'birthYear': 1955},
#  {'_id': 643, 'name': 'Tom Skerritt', 'birthYear': 1933},
#  {'_id': 644, 'name': 'Helen Slater', 'birthYear': 1963},
#  {'_id': 645,
#   'name': 'Anna Nicole Smith',
#   'birthYear': 1967,
#   'deathYear': 2007},
#  {'_id': 646, 'name': 'Jaclyn Smith', 'birthYear': 1945},
#  {'_id': 647, 'name': 'Alan Smithee'},
#  {'_id': 648, 'name': 'Wesley Snipes', 'birthYear': 1962},
#  {'_id': 649, 'name': 'Paul Sorvino', 'birthYear': 1939, 'deathYear': 2022},
#  {'_id': 650, 'name': 'Talisa Soto', 'birthYear': 1967},
#  {'_id': 651, 'name': 'Sissy Spacek', 'birthYear': 1949},
#  {'_id': 652, 'name': 'James Spader', 'birthYear': 1960},
#  {'_id': 653, 'name': 'Brent Spiner', 'birthYear': 1949},
#  {'_id': 654, 'name': 'Terence Stamp', 'birthYear': 1938},
#  {'_id': 655, 'name': 'Eric Stoltz', 'birthYear': 1961},
#  {'_id': 656, 'name': 'Madeleine Stowe', 'birthYear': 1958},
#  {'_id': 657, 'name': 'David Strathairn', 'birthYear': 1949},
#  {'_id': 658, 'name': 'Meryl Streep', 'birthYear': 1949},
#  {'_id': 659, 'name': 'Barbra Streisand', 'birthYear': 1942},
#  {'_id': 660, 'name': 'Tami Stronach', 'birthYear': 1972},
#  {'_id': 661, 'name': 'Donald Sutherland', 'birthYear': 1935},
#  {'_id': 662, 'name': 'Kiefer Sutherland', 'birthYear': 1966},
#  {'_id': 663, 'name': 'Dominique Swain', 'birthYear': 1980},
#  {'_id': 664, 'name': 'Patrick Swayze', 'birthYear': 1952, 'deathYear': 2009},
#  {'_id': 665, 'name': 'D.B. Sweeney'},
#  {'_id': 666, 'name': 'Lili Taylor', 'birthYear': 1967},
#  {'_id': 667, 'name': 'David Thewlis', 'birthYear': 1963},
#  {'_id': 668, 'name': 'Emma Thompson', 'birthYear': 1959},
#  {'_id': 669, 'name': 'Fred Thompson', 'birthYear': 1942, 'deathYear': 2015},
#  {'_id': 670, 'name': 'Lea Thompson', 'birthYear': 1961},
#  {'_id': 671, 'name': 'Billy Bob Thornton', 'birthYear': 1955},
#  {'_id': 672, 'name': 'Meg Tilly', 'birthYear': 1960},
#  {'_id': 673, 'name': 'Marisa Tomei', 'birthYear': 1964},
#  {'_id': 674, 'name': 'Tamlyn Tomita', 'birthYear': 1966},
#  {'_id': 675, 'name': 'Jeanne Tripplehorn', 'birthYear': 1963},
#  {'_id': 676, 'name': 'Chris Tucker', 'birthYear': 1971},
#  {'_id': 677, 'name': 'Robin Tunney', 'birthYear': 1972},
#  {'_id': 678, 'name': 'Kathleen Turner', 'birthYear': 1954},
#  {'_id': 679, 'name': 'Deborah Kara Unger', 'birthYear': 1966},
#  {'_id': 680, 'name': 'Casper Van Dien', 'birthYear': 1968},
#  {'_id': 681, 'name': 'Vince Vaughn', 'birthYear': 1970},
#  {'_id': 682, 'name': 'Paul Verhoeven', 'birthYear': 1938},
#  {'_id': 683, 'name': 'Gore Vidal', 'birthYear': 1925, 'deathYear': 2012},
#  {'_id': 684, 'name': 'Nana Visitor', 'birthYear': 1957},
#  {'_id': 685, 'name': 'Jon Voight', 'birthYear': 1938},
#  {'_id': 686, 'name': 'Christopher Walken', 'birthYear': 1943},
#  {'_id': 687, 'name': 'J.T. Walsh', 'birthYear': 1943, 'deathYear': 1998},
#  {'_id': 688, 'name': 'Sela Ward', 'birthYear': 1956},
#  {'_id': 689, 'name': 'Julie Warner', 'birthYear': 1965},
#  {'_id': 690, 'name': 'Lesley Ann Warren', 'birthYear': 1946},
#  {'_id': 691, 'name': 'John Waters', 'birthYear': 1946},
#  {'_id': 692, 'name': 'Teri Weigel', 'birthYear': 1962},
#  {'_id': 693, 'name': 'Peter Weller', 'birthYear': 1947},
#  {'_id': 694, 'name': 'Wim Wenders', 'birthYear': 1945},
#  {'_id': 695, 'name': 'Joanne Whalley', 'birthYear': 1961},
#  {'_id': 696, 'name': 'Wil Wheaton', 'birthYear': 1972},
#  {'_id': 697, 'name': 'Billy Wilder', 'birthYear': 1906, 'deathYear': 2002},
#  {'_id': 698, 'name': 'Gene Wilder', 'birthYear': 1933, 'deathYear': 2016},
#  {'_id': 699, 'name': 'Michael Wincott', 'birthYear': 1958},
#  {'_id': 700, 'name': 'Debra Winger', 'birthYear': 1955},
#  {'_id': 701, 'name': 'Kate Winslet', 'birthYear': 1975},
#  {'_id': 702, 'name': 'Reese Witherspoon', 'birthYear': 1976},
#  {'_id': 703, 'name': 'BD Wong', 'birthYear': 1960},
#  {'_id': 704, 'name': 'Elijah Wood', 'birthYear': 1981},
#  {'_id': 705, 'name': 'Robin Wright', 'birthYear': 1966},
#  {'_id': 706, 'name': 'Michelle Yeoh', 'birthYear': 1962},
#  {'_id': 707, 'name': 'Sean Young', 'birthYear': 1959},
#  {'_id': 708, 'name': 'Billy Zane', 'birthYear': 1966},
#  {'_id': 709, 'name': 'Robert Zemeckis', 'birthYear': 1952},
#  {'_id': 710, 'name': 'David Raksin', 'birthYear': 1912, 'deathYear': 2004},
#  {'_id': 711, 'name': 'Rick Baker', 'birthYear': 1950},
#  {'_id': 712, 'name': 'Steve Cohen'},
#  {'_id': 713, 'name': 'Joel Oliansky', 'birthYear': 1935, 'deathYear': 2002},
#  {'_id': 714, 'name': 'Willie Aames', 'birthYear': 1960},
#  {'_id': 715, 'name': 'Caroline Aaron', 'birthYear': 1952},
#  {'_id': 716, 'name': 'Paula Abdul', 'birthYear': 1962},
#  {'_id': 717, 'name': 'Kareem Abdul-Jabbar', 'birthYear': 1947},
#  {'_id': 718, 'name': 'Ian Abercrombie', 'birthYear': 1934, 'deathYear': 2012},
#  {'_id': 719, 'name': 'F. Murray Abraham', 'birthYear': 1939},
#  {'_id': 720, 'name': 'Jim Abrahams', 'birthYear': 1944},
#  {'_id': 721, 'name': 'Victoria Abril', 'birthYear': 1959},
#  {'_id': 722, 'name': 'Joss Ackland', 'birthYear': 1928},
#  {'_id': 723, 'name': 'Deborah Adair', 'birthYear': 1952},
#  {'_id': 724, 'name': 'Brooke Adams', 'birthYear': 1949},
#  {'_id': 725, 'name': 'Joey Lauren Adams', 'birthYear': 1968},
#  {'_id': 726, 'name': 'Maud Adams', 'birthYear': 1945},
#  {'_id': 727, 'name': 'Percy Adlon', 'birthYear': 1935},
#  {'_id': 728, 'name': 'Mario Adorf', 'birthYear': 1930},
#  {'_id': 729, 'name': 'Casey Affleck', 'birthYear': 1975},
#  {'_id': 730, 'name': 'John Agar', 'birthYear': 1921, 'deathYear': 2002},
#  {'_id': 731, 'name': 'Brian Aherne', 'birthYear': 1902, 'deathYear': 1986},
#  {'_id': 732, 'name': 'Danny Aiello', 'birthYear': 1933, 'deathYear': 2019},
#  {'_id': 733, 'name': 'Anouk Aimée', 'birthYear': 1932},
#  {'_id': 734, 'name': 'Eddie Albert', 'birthYear': 1906, 'deathYear': 2005},
#  {'_id': 735, 'name': 'Brian Aldiss', 'birthYear': 1925, 'deathYear': 2017},
#  {'_id': 736, 'name': 'Robert Aldrich', 'birthYear': 1918, 'deathYear': 1983},
#  {'_id': 737, 'name': 'Jane Alexander', 'birthYear': 1939},
#  {'_id': 738, 'name': 'Muhammad Ali', 'birthYear': 1942, 'deathYear': 2016},
#  {'_id': 739, 'name': 'Debbie Allen', 'birthYear': 1950},
#  {'_id': 740, 'name': 'Irwin Allen', 'birthYear': 1916, 'deathYear': 1991},
#  {'_id': 741, 'name': 'Tim Allen', 'birthYear': 1953},
#  {'_id': 742, 'name': 'June Allyson', 'birthYear': 1917, 'deathYear': 2006},
#  {'_id': 743,
#   'name': 'Néstor Almendros',
#   'birthYear': 1930,
#   'deathYear': 1992},
#  {'_id': 744, 'name': 'Maria Conchita Alonso', 'birthYear': 1957},
#  {'_id': 745, 'name': 'Carol Alt', 'birthYear': 1960},
#  {'_id': 746, 'name': 'Trini Alvarado', 'birthYear': 1967},
#  {'_id': 747, 'name': 'Don Ameche', 'birthYear': 1908, 'deathYear': 1993},
#  {'_id': 748, 'name': 'Leon Ames', 'birthYear': 1902, 'deathYear': 1993},
#  {'_id': 749, 'name': 'Mädchen Amick', 'birthYear': 1970},
#  {'_id': 750, 'name': 'Jon Amiel', 'birthYear': 1948},
#  {'_id': 751, 'name': 'Suzy Amis', 'birthYear': 1962},
#  {'_id': 752, 'name': 'Judith Anderson', 'birthYear': 1897, 'deathYear': 1992},
# ...
#  {'_id': 763, 'name': 'Dana Andrews', 'birthYear': 1909, 'deathYear': 1992},
#  {'_id': 764,
#   'name': 'André René Roussimoff',
#   'birthYear': 1946,
#   'deathYear': 1993},
#  {'_id': 765, 'name': 'Pier Angeli', 'birthYear': 1932, 'deathYear': 1971},
#  {'_id': 766,
#   'name': 'Theodoros Angelopoulos',
#   'birthYear': 1935,
#   'deathYear': 2012},
#  {'_id': 767, 'name': 'Jean-Hugues Anglade', 'birthYear': 1955},
#  {'_id': 768, 'name': 'Francesca Annis', 'birthYear': 1945},
#  {'_id': 769, 'name': 'Susan Anspach', 'birthYear': 1942, 'deathYear': 2018},
#  {'_id': 770, 'name': 'David Anspaugh', 'birthYear': 1946},
#  {'_id': 771, 'name': 'Lysette Anthony', 'birthYear': 1963},
#  {'_id': 772, 'name': 'Susan Anton', 'birthYear': 1950},
#  {'_id': 773, 'name': 'Laura Antonelli', 'birthYear': 1941, 'deathYear': 2015},
#  {'_id': 774,
#   'name': 'Michelangelo Antonioni',
#   'birthYear': 1912,
#   'deathYear': 2007},
#  {'_id': 775, 'name': 'Christina Applegate', 'birthYear': 1971},
#  {'_id': 776, 'name': 'Michael Apted', 'birthYear': 1941, 'deathYear': 2021},
#  {'_id': 777, 'name': 'Gregg Araki', 'birthYear': 1959},
#  {'_id': 778, 'name': 'Alfonso Arau', 'birthYear': 1932},
#  {'_id': 779,
#   'name': "Roscoe 'Fatty' Arbuckle",
#   'birthYear': 1887,
#   'deathYear': 1933},
#  {'_id': 780, 'name': 'Denys Arcand', 'birthYear': 1941},
#  {'_id': 781, 'name': 'Eve Arden', 'birthYear': 1908, 'deathYear': 1990},
#  {'_id': 782, 'name': 'Asia Argento', 'birthYear': 1975},
#  {'_id': 783, 'name': 'Dario Argento', 'birthYear': 1940},
#  {'_id': 784,
#   'name': 'Pedro Armendáriz',
#   'birthYear': 1912,
#   'deathYear': 1963},
#  {'_id': 785, 'name': 'Alison Armitage', 'birthYear': 1965},
#  {'_id': 786, 'name': 'George Armitage', 'birthYear': 1942},
#  {'_id': 787, 'name': 'Bess Armstrong', 'birthYear': 1953},
#  {'_id': 788, 'name': 'Gillian Armstrong', 'birthYear': 1950},
#  {'_id': 789, 'name': 'Desi Arnaz', 'birthYear': 1917, 'deathYear': 1986},
#  {'_id': 790, 'name': 'James Arness', 'birthYear': 1923, 'deathYear': 2011},
#  {'_id': 791, 'name': 'Jack Arnold', 'birthYear': 1912, 'deathYear': 1992},
#  {'_id': 792, 'name': 'Tom Arnold', 'birthYear': 1959},
#  {'_id': 793, 'name': 'Alexis Arquette', 'birthYear': 1969, 'deathYear': 2016},
#  {'_id': 794, 'name': 'Lewis Arquette', 'birthYear': 1935, 'deathYear': 2001},
#  {'_id': 795, 'name': 'Jean Arthur', 'birthYear': 1900, 'deathYear': 1991},
#  {'_id': 796, 'name': 'Dana Ashbrook', 'birthYear': 1967},
#  {'_id': 797, 'name': 'Hal Ashby', 'birthYear': 1929, 'deathYear': 1988},
#  {'_id': 798, 'name': 'Linden Ashby', 'birthYear': 1960},
#  {'_id': 799, 'name': 'Edward Asner', 'birthYear': 1929, 'deathYear': 2021},
#  {'_id': 800, 'name': 'Armand Assante', 'birthYear': 1949},
#  {'_id': 801, 'name': 'Olivier Assayas', 'birthYear': 1955},
#  {'_id': 802, 'name': 'Mary Astor', 'birthYear': 1906, 'deathYear': 1987},
#  {'_id': 803, 'name': 'Christopher Atkins', 'birthYear': 1961},
#  {'_id': 804, 'name': 'Stéphane Audran', 'birthYear': 1932, 'deathYear': 2018},
#  {'_id': 805, 'name': 'Claudine Auger', 'birthYear': 1941, 'deathYear': 2019},
#  {'_id': 806, 'name': 'Bille August', 'birthYear': 1948},
#  {'_id': 807, 'name': 'Jane Austen', 'birthYear': 1775, 'deathYear': 1817},
#  {'_id': 808, 'name': 'Paul Auster', 'birthYear': 1947},
#  {'_id': 809, 'name': 'Daniel Auteuil', 'birthYear': 1950},
#  {'_id': 810, 'name': 'Gene Autry', 'birthYear': 1907, 'deathYear': 1998},
#  {'_id': 811, 'name': 'Frankie Avalon', 'birthYear': 1940},
#  {'_id': 812, 'name': 'Roger Avary', 'birthYear': 1965},
#  {'_id': 813, 'name': 'Tex Avery', 'birthYear': 1908, 'deathYear': 1980},
#  {'_id': 814,
#   'name': 'John G. Avildsen',
#   'birthYear': 1935,
#   'deathYear': 2017},
#  {'_id': 815, 'name': 'Mili Avital', 'birthYear': 1972},
#  {'_id': 816, 'name': 'Jon Avnet', 'birthYear': 1949},
#  {'_id': 817, 'name': 'Lew Ayres', 'birthYear': 1908, 'deathYear': 1996},
#  {'_id': 818, 'name': 'Shabana Azmi', 'birthYear': 1950},
#  {'_id': 819, 'name': 'Barbara Bach', 'birthYear': 1946},
#  {'_id': 820, 'name': 'Burt Bacharach', 'birthYear': 1928},
#  {'_id': 821, 'name': 'Amitabh Bachchan', 'birthYear': 1942},
#  {'_id': 822, 'name': 'Jim Backus', 'birthYear': 1913, 'deathYear': 1989},
#  {'_id': 823,
#   'name': 'Angelo Badalamenti',
#   'birthYear': 1937,
#   'deathYear': 2022},
#  {'_id': 824, 'name': 'John Badham', 'birthYear': 1939},
#  {'_id': 825, 'name': 'Mary Badham', 'birthYear': 1952},
#  {'_id': 826, 'name': 'Jane Badler', 'birthYear': 1953},
#  {'_id': 827, 'name': 'Maxine Bahns', 'birthYear': 1971},
#  {'_id': 828, 'name': 'Barbara Bain', 'birthYear': 1931},
#  {'_id': 829, 'name': 'Stuart Baird', 'birthYear': 1947},
#  {'_id': 830, 'name': 'Oksana Baiul', 'birthYear': 1977},
#  {'_id': 832, 'name': 'Diane Baker', 'birthYear': 1938},
#  {'_id': 833, 'name': 'Joe Don Baker', 'birthYear': 1936},
#  {'_id': 834, 'name': 'Kathy Baker', 'birthYear': 1950},
#  {'_id': 835, 'name': 'Ralph Bakshi', 'birthYear': 1938},
#  {'_id': 836, 'name': 'Scott Bakula', 'birthYear': 1954},
#  {'_id': 837, 'name': 'Bob Balaban', 'birthYear': 1945},
#  {'_id': 838, 'name': 'Daniel Baldwin', 'birthYear': 1960},
#  {'_id': 839, 'name': 'Ina Balin', 'birthYear': 1937, 'deathYear': 1990},
#  {'_id': 840, 'name': 'Lucille Ball', 'birthYear': 1911, 'deathYear': 1989},
#  {'_id': 841,
#   'name': 'Michael Ballhaus',
#   'birthYear': 1935,
#   'deathYear': 2017},
#  {'_id': 842, 'name': 'Martin Balsam', 'birthYear': 1919, 'deathYear': 1996},
#  {'_id': 843, 'name': 'Anne Bancroft', 'birthYear': 1931, 'deathYear': 2005},
#  {'_id': 844, 'name': 'Tamasaburô Bandô', 'birthYear': 1950},
#  {'_id': 845,
#   'name': 'Tallulah Bankhead',
#   'birthYear': 1902,
#   'deathYear': 1968},
#  {'_id': 846, 'name': 'Ian Bannen', 'birthYear': 1928, 'deathYear': 1999},
#  {'_id': 847, 'name': 'Theda Bara', 'birthYear': 1885, 'deathYear': 1955},
#  {'_id': 848, 'name': 'Olivia Barash'},
#  {'_id': 849, 'name': 'Javier Bardem', 'birthYear': 1969},
#  {'_id': 850, 'name': 'Clive Barker', 'birthYear': 1952},
#  {'_id': 851, 'name': 'Lex Barker', 'birthYear': 1919, 'deathYear': 1973},
#  {'_id': 852, 'name': 'Jean-Marc Barr', 'birthYear': 1960},
#  {'_id': 853, 'name': 'Bruno Barreto', 'birthYear': 1955},
#  {'_id': 854, 'name': 'Majel Barrett', 'birthYear': 1932, 'deathYear': 2008},
#  {'_id': 855, 'name': 'Raymond J. Barry', 'birthYear': 1939},
#  {'_id': 856, 'name': 'Ethel Barrymore', 'birthYear': 1879, 'deathYear': 1959},
#  {'_id': 857,
#   'name': 'John Drew Barrymore',
#   'birthYear': 1932,
#   'deathYear': 2004},
#  {'_id': 858, 'name': 'John Barrymore', 'birthYear': 1882, 'deathYear': 1942},
#  {'_id': 859,
#   'name': 'Lionel Barrymore',
#   'birthYear': 1878,
#   'deathYear': 1954},
#  {'_id': 860, 'name': 'Paul Bartel', 'birthYear': 1938, 'deathYear': 2000},
#  {'_id': 861,
#   'name': 'Freddie Bartholomew',
#   'birthYear': 1924,
#   'deathYear': 1992},
#  {'_id': 862, 'name': 'Robin Bartlett', 'birthYear': 1951},
#  {'_id': 863, 'name': 'Billy Barty', 'birthYear': 1924, 'deathYear': 2000},
#  {'_id': 864, 'name': 'Mikhail Baryshnikov', 'birthYear': 1948},
#  {'_id': 865,
#   'name': 'Richard Basehart',
#   'birthYear': 1914,
#   'deathYear': 1984},
#  {'_id': 866, 'name': 'Saul Bass', 'birthYear': 1920, 'deathYear': 1996},
#  {'_id': 867, 'name': 'Jason Bateman', 'birthYear': 1969},
#  {'_id': 868, 'name': 'Justine Bateman', 'birthYear': 1966},
#  {'_id': 869, 'name': 'Alan Bates', 'birthYear': 1934, 'deathYear': 2003},
#  {'_id': 870, 'name': 'Kathy Bates', 'birthYear': 1948},
#  {'_id': 871, 'name': 'Randall Batinkoff', 'birthYear': 1968},
#  {'_id': 872, 'name': 'Patrick Bauchau', 'birthYear': 1938},
#  {'_id': 873, 'name': 'Belinda Bauer', 'birthYear': 1950},
#  {'_id': 874, 'name': 'Steven Bauer', 'birthYear': 1956},
#  {'_id': 875, 'name': 'L. Frank Baum', 'birthYear': 1856, 'deathYear': 1919},
#  {'_id': 876, 'name': 'Noah Baumbach', 'birthYear': 1969},
#  {'_id': 877, 'name': 'Lamberto Bava', 'birthYear': 1944},
#  {'_id': 878, 'name': 'Mario Bava', 'birthYear': 1914, 'deathYear': 1980},
#  {'_id': 879, 'name': 'Anne Baxter', 'birthYear': 1923, 'deathYear': 1985},
#  {'_id': 880, 'name': 'Meredith Baxter', 'birthYear': 1947},
#  {'_id': 881, 'name': 'Michael Bay', 'birthYear': 1965},
#  {'_id': 882, 'name': 'Nathalie Baye', 'birthYear': 1948},
#  {'_id': 883, 'name': 'Stephanie Beacham', 'birthYear': 1947},
#  {'_id': 884, 'name': 'Jennifer Beals', 'birthYear': 1963},
#  {'_id': 885, 'name': 'Ned Beatty', 'birthYear': 1937, 'deathYear': 2021},
#  {'_id': 886, 'name': 'Warren Beatty', 'birthYear': 1937},
#  {'_id': 887, 'name': 'Harold Becker', 'birthYear': 1928},
#  {'_id': 888, 'name': 'Meret Becker', 'birthYear': 1969},
#  {'_id': 889, 'name': 'Bonnie Bedelia', 'birthYear': 1948},
#  {'_id': 890, 'name': 'Noah Beery Jr.', 'birthYear': 1913, 'deathYear': 1994},
#  {'_id': 891, 'name': 'Wallace Beery', 'birthYear': 1885, 'deathYear': 1949},
#  {'_id': 892, 'name': 'Jason Beghe', 'birthYear': 1960},
#  {'_id': 893, 'name': 'Ed Begley Jr.', 'birthYear': 1949},
#  {'_id': 894,
#   'name': 'Jean-Jacques Beineix',
#   'birthYear': 1946,
#   'deathYear': 2022},
#  {'_id': 895,
#   'name': 'Barbara Bel Geddes',
#   'birthYear': 1922,
#   'deathYear': 2005},
#  {'_id': 896, 'name': 'Harry Belafonte', 'birthYear': 1927},
#  {'_id': 897, 'name': 'Ralph Bellamy', 'birthYear': 1904, 'deathYear': 1991},
#  {'_id': 898, 'name': 'Kathleen Beller', 'birthYear': 1956},
#  {'_id': 899, 'name': 'Monica Bellucci', 'birthYear': 1964},
#  {'_id': 900, 'name': 'Pamela Bellwood', 'birthYear': 1944},
#  {'_id': 901,
#   'name': 'Jean-Paul Belmondo',
#   'birthYear': 1933,
#   'deathYear': 2021},
#  {'_id': 902, 'name': 'Jim Belushi', 'birthYear': 1954},
#  {'_id': 903, 'name': 'Brian Benben', 'birthYear': 1956},
#  {'_id': 904, 'name': 'William Bendix', 'birthYear': 1906, 'deathYear': 1964},
#  {'_id': 905, 'name': 'Roberto Benigni', 'birthYear': 1952},
#  {'_id': 906, 'name': 'Annette Bening', 'birthYear': 1958},
#  {'_id': 907, 'name': 'Richard Benjamin', 'birthYear': 1938},
#  {'_id': 908, 'name': 'David Bennent', 'birthYear': 1966},
#  {'_id': 909,
#   'name': 'Constance Bennett',
#   'birthYear': 1904,
#   'deathYear': 1965},
#  {'_id': 910, 'name': 'Joan Bennett', 'birthYear': 1910, 'deathYear': 1990},
#  {'_id': 911, 'name': 'Nigel Bennett', 'birthYear': 1949},
#  {'_id': 912, 'name': 'Jack Benny', 'birthYear': 1894, 'deathYear': 1974},
#  {'_id': 913, 'name': 'Robby Benson', 'birthYear': 1956},
#  {'_id': 914, 'name': 'Robert Benton', 'birthYear': 1932},
#  {'_id': 915, 'name': 'Bruce Beresford', 'birthYear': 1940},
#  {'_id': 916, 'name': 'Peter Berg', 'birthYear': 1964},
#  {'_id': 917, 'name': 'Polly Bergen', 'birthYear': 1930, 'deathYear': 2014},
#  {'_id': 918, 'name': 'Helmut Berger', 'birthYear': 1944},
#  {'_id': 919, 'name': 'Senta Berger', 'birthYear': 1941},
#  {'_id': 920, 'name': 'Patrick Bergin', 'birthYear': 1951},
#  {'_id': 921, 'name': 'Andrew Bergman', 'birthYear': 1945},
#  {'_id': 922, 'name': 'Sandahl Bergman', 'birthYear': 1951},
#  {'_id': 923, 'name': 'Busby Berkeley', 'birthYear': 1895, 'deathYear': 1976},
#  {'_id': 924, 'name': 'Elizabeth Berkley', 'birthYear': 1972},
#  {'_id': 925, 'name': 'Steven Berkoff', 'birthYear': 1937},
#  {'_id': 926, 'name': 'Milton Berle', 'birthYear': 1908, 'deathYear': 2002},
#  {'_id': 927, 'name': 'Irving Berlin', 'birthYear': 1888, 'deathYear': 1989},
#  {'_id': 928, 'name': 'Sandra Bernhard', 'birthYear': 1955},
#  {'_id': 929, 'name': 'Corbin Bernsen', 'birthYear': 1954},
#  {'_id': 930, 'name': 'Elmer Bernstein', 'birthYear': 1922, 'deathYear': 2004},
#  {'_id': 931, 'name': 'Elizabeth Berridge', 'birthYear': 1962},
#  {'_id': 932, 'name': 'Halle Berry', 'birthYear': 1966},
#  {'_id': 933, 'name': 'Valerie Bertinelli', 'birthYear': 1960},
#  {'_id': 934,
#   'name': 'Bernardo Bertolucci',
#   'birthYear': 1941,
#   'deathYear': 2018},
#  {'_id': 935, 'name': 'Bibi Besch', 'birthYear': 1942, 'deathYear': 1996},
#  {'_id': 936, 'name': 'Martine Beswick', 'birthYear': 1941},
#  {'_id': 937, 'name': 'Richard Beymer', 'birthYear': 1939},
#  {'_id': 938, 'name': 'Daniela Bianchi', 'birthYear': 1942},
#  {'_id': 939, 'name': 'Adrian Biddle', 'birthYear': 1952, 'deathYear': 2005},
#  {'_id': 940, 'name': 'Bigas Luna', 'birthYear': 1946, 'deathYear': 2013},
#  {'_id': 941, 'name': 'Kathryn Bigelow', 'birthYear': 1951},
#  {'_id': 942, 'name': 'Theodore Bikel', 'birthYear': 1924, 'deathYear': 2015},
#  {'_id': 943, 'name': 'Traci Bingham', 'birthYear': 1968},
#  {'_id': 944, 'name': 'Antonia Bird', 'birthYear': 1951, 'deathYear': 2013},
#  {'_id': 945, 'name': 'Jane Birkin', 'birthYear': 1946},
#  {'_id': 946, 'name': 'Whit Bissell', 'birthYear': 1909, 'deathYear': 1996},
#  {'_id': 947, 'name': 'Karen Black', 'birthYear': 1939, 'deathYear': 2013},
#  {'_id': 948, 'name': 'Shane Black', 'birthYear': 1961},
#  {'_id': 949, 'name': 'Cate Blanchett', 'birthYear': 1969},
#  {'_id': 950, 'name': 'Brenda Blethyn', 'birthYear': 1946},
#  {'_id': 951, 'name': 'Joan Blondell', 'birthYear': 1906, 'deathYear': 1979},
#  {'_id': 952, 'name': 'Hart Bochner', 'birthYear': 1956},
#  {'_id': 953,
#   'name': 'Peter Bogdanovich',
#   'birthYear': 1939,
#   'deathYear': 2022},
#  {'_id': 954, 'name': 'Jon Bon Jovi', 'birthYear': 1962},
#  {'_id': 955, 'name': 'Ward Bond', 'birthYear': 1903, 'deathYear': 1960},
#  {'_id': 956, 'name': 'Lisa Bonet', 'birthYear': 1967},
#  {'_id': 957, 'name': 'Jan de Bont', 'birthYear': 1943},
#  {'_id': 958, 'name': 'John Boorman', 'birthYear': 1933},
#  {'_id': 959, 'name': 'Powers Boothe', 'birthYear': 1948, 'deathYear': 2017},
#  {'_id': 960, 'name': 'Barry Bostwick', 'birthYear': 1945},
#  {'_id': 961, 'name': 'Timothy Bottoms', 'birthYear': 1951},
#  {'_id': 962, 'name': 'Carole Bouquet', 'birthYear': 1957},
#  {'_id': 963, 'name': 'Stephen Boyd', 'birthYear': 1931, 'deathYear': 1977},
#  {'_id': 964, 'name': 'Charles Boyer', 'birthYear': 1899, 'deathYear': 1978},
#  {'_id': 965, 'name': 'Danny Boyle', 'birthYear': 1956},
#  {'_id': 966, 'name': 'Lorraine Bracco', 'birthYear': 1954},
#  {'_id': 967, 'name': 'Eric Braeden', 'birthYear': 1941},
#  {'_id': 968, 'name': 'Sonia Braga', 'birthYear': 1950},
#  {'_id': 969, 'name': 'Lillo Brancato', 'birthYear': 1976},
#  {'_id': 970,
#   'name': 'Jonathan Brandis',
#   'birthYear': 1976,
#   'deathYear': 2003},
#  {'_id': 971, 'name': 'Nicoletta Braschi', 'birthYear': 1960},
#  {'_id': 972, 'name': 'Tinto Brass', 'birthYear': 1933},
#  {'_id': 973, 'name': 'Benjamin Bratt', 'birthYear': 1963},
#  {'_id': 974, 'name': 'Walter Brennan', 'birthYear': 1894, 'deathYear': 1974},
#  {'_id': 975, 'name': 'Robert Bresson', 'birthYear': 1901, 'deathYear': 1999},
#  {'_id': 976, 'name': 'Martin Brest', 'birthYear': 1951},
#  {'_id': 977, 'name': 'Beau Bridges', 'birthYear': 1941},
#  {'_id': 978, 'name': 'Lloyd Bridges', 'birthYear': 1913, 'deathYear': 1998},
#  {'_id': 979, 'name': 'Wilford Brimley', 'birthYear': 1934, 'deathYear': 2020},
#  {'_id': 980, 'name': 'Jim Broadbent', 'birthYear': 1949},
#  {'_id': 981, 'name': 'James Brolin', 'birthYear': 1940},
#  {'_id': 982, 'name': 'Josh Brolin', 'birthYear': 1968},
#  {'_id': 983, 'name': 'Albert Brooks', 'birthYear': 1947},
#  {'_id': 984, 'name': 'Avery Brooks', 'birthYear': 1948},
#  {'_id': 985, 'name': 'James L. Brooks', 'birthYear': 1940},
#  {'_id': 986, 'name': 'Bryan Brown', 'birthYear': 1947},
#  {'_id': 987, 'name': 'Jim Brown', 'birthYear': 1936},
#  {'_id': 988, 'name': 'Jerry Bruckheimer', 'birthYear': 1943},
#  {'_id': 989, 'name': 'Yul Brynner', 'birthYear': 1920, 'deathYear': 1985},
#  {'_id': 990, 'name': 'Betty Buckley', 'birthYear': 1947},
#  {'_id': 991, 'name': 'Geneviève Bujold', 'birthYear': 1942},
#  {'_id': 992, 'name': 'Billie Burke', 'birthYear': 1884, 'deathYear': 1970},
#  {'_id': 993, 'name': 'Carol Burnett', 'birthYear': 1933},
#  {'_id': 994, 'name': 'Raymond Burr', 'birthYear': 1917, 'deathYear': 1993},
#  {'_id': 995, 'name': 'Ellen Burstyn', 'birthYear': 1932},
#  {'_id': 996, 'name': 'LeVar Burton', 'birthYear': 1957},
#  {'_id': 997, 'name': 'Gary Busey', 'birthYear': 1944},
#  {'_id': 998, 'name': 'Jake Busey', 'birthYear': 1971},
#  {'_id': 999, 'name': 'Red Buttons', 'birthYear': 1919, 'deathYear': 2006},
#  {'_id': 1000, 'name': 'Tom Byron', 'birthYear': 1961},
#  {'_id': 1001, 'name': 'James Caan', 'birthYear': 1940, 'deathYear': 2022},
#  ...]

# %% [markdown]
# ### Fetching movie table, a result joins of multiple tables from IMDB SQL DB and converting to JSON dictionary

# %%
query = '''SELECT id AS _id, type, t.title AS title, originalTitle, startYear, endYear, runtime, avgRating, numVotes, genres, actors, directors, writers, producers
	FROM title AS t
	LEFT JOIN (SELECT title, ARRAY_AGG(g.genre) AS genres 
				FROM title_genre AS tg 
				INNER JOIN genre AS g 
				ON g.id = tg.genre 
				GROUP BY title) AS g
	ON t.id = g.title
	LEFT JOIN (SELECT title, ARRAY_AGG(writer) AS writers 
				FROM title_writer 
				GROUP BY title) AS w
	ON t.id = w.title
	LEFT JOIN (SELECT title, ARRAY_AGG(director) AS directors 
			   FROM title_director 
			   GROUP BY title) AS d
	ON t.id = d.title
	LEFT JOIN (SELECT title, ARRAY_AGG(producer) AS producers 
			   FROM title_producer 
			   GROUP BY title) AS p
	ON t.id = p.title
	LEFT JOIN (SELECT title, JSON_AGG(JSON_BUILD_OBJECT(
				   'actor', actor, 
				   'roles', characters)) AS actors 
			   FROM ( 
				   SELECT title, actor, ARRAY_AGG(c.character) AS characters 
				   FROM actor_title_character AS atc 
				   INNER JOIN character AS c 
				   ON atc.character = c.id 
				   GROUP BY title, actor) AS ta
			   GROUP BY title) AS a
	ON t.id = a.title'''
movies = fetch_sql(query)
movies[:10]
# Out:
# [(1,
#   'short',
#   'Carmencita',
#   'Carmencita',
#   1894,
#   None,
#   1,
#   Decimal('5.7'),
#   1949,
#   ['Documentary', 'Short'],
#   [{'actor': 1588970, 'roles': ['Self']}],
#   [5690],
#   None,
#   None),
#  (2,
#   'short',
#   'Le clown et ses chiens',
#   'Le clown et ses chiens',
#   1892,
#   None,
#   5,
#   Decimal('5.8'),
#   264,
#   ['Short', 'Animation'],
#   None,
#   [721526],
#   None,
#   None),
#  (3,
#   'short',
#   'Pauvre Pierrot',
#   'Pauvre Pierrot',
#   1892,
#   None,
#   4,
#   Decimal('6.5'),
#   1779,
#   ['Animation', 'Comedy', 'Romance'],
#   None,
#   [721526],
#   None,
#   [1770680]),
#  (4,
#   'short',
#   'Un bon bock',
#   'Un bon bock',
#   1892,
#   None,
#   12,
#   Decimal('5.6'),
#   179,
#   ['Short', 'Animation'],
#   None,
#   [721526],
#   None,
#   None),
#  (5,
#   'short',
#   'Blacksmith Scene',
#   'Blacksmith Scene',
#   1893,
#   None,
#   1,
#   Decimal('6.2'),
#   2583,
#   ['Short', 'Comedy'],
#   [{'actor': 443482, 'roles': ['Blacksmith']},
#    {'actor': 653042, 'roles': ['Assistant']}],
#   [5690],
#   None,
#   [249379]),
#  (6,
#   'short',
#   'Chinese Opium Den',
#   'Chinese Opium Den',
#   1894,
#   None,
#   1,
#   Decimal('5.1'),
#   177,
#   ['Short'],
#   None,
#   [5690],
#   None,
#   None),
#  (7,
#   'short',
#   'Corbett and Courtney Before the Kinetograph',
#   'Corbett and Courtney Before the Kinetograph',
#   1894,
#   None,
#   1,
#   Decimal('5.4'),
#   811,
#   ['Short', 'Sport'],
#   None,
#   [5690, 374658],
#   None,
#   [249379]),
#  (8,
#   'short',
#   'Edison Kinetoscopic Record of a Sneeze',
#   'Edison Kinetoscopic Record of a Sneeze',
#   1894,
#   None,
#   1,
#   Decimal('5.4'),
#   2090,
#   ['Documentary', 'Short'],
#   [{'actor': 653028, 'roles': ['Sneezing Man']}],
#   [5690],
#   None,
#   None),
#  (9,
#   'movie',
#   'Miss Jerry',
#   'Miss Jerry',
#   1894,
#   None,
#   45,
#   Decimal('5.3'),
#   204,
#   ['Romance'],
#   [{'actor': 63086, 'roles': ['Miss Geraldine Holbrook (Miss Jerry)']},
#    {'actor': 183823, 'roles': ['Mr. Hamilton']},
#    {'actor': 1309758,
#     'roles': ['Chauncey Depew - the Director of the New York Central Railroad']}],
#   [85156],
#   [85156],
#   None),
#  (10,
#   'short',
#   'Leaving the Factory',
#   "La sortie de l'usine Lumière à Lyon",
#   1895,
#   None,
#   1,
#   Decimal('6.9'),
#   7047,
#   ['Documentary', 'Short'],
#   None,
#   [525910],
#   None,
#   None)]

# %%
movie_columns = ['_id', 'type', 'title', 'originalTitle', 'startYear', 'endYear', 'runtime', 'avgRating', 'numVotes', 'genres', 'actors', 'directors', 'writers', 'producers']
movie_list = []
# movies = [dict((key, value) for key, value in zip(movie_columns, row) if value != None and value == value) for row in movies]
for row in movies:
    row_dict = {}
    row_zip = zip(movie_columns, row)
    for key, value in row_zip:
        if value != None and value == value:
            if isinstance(value, Decimal):
                row_dict[key] = float(str(value))
            else:
                row_dict[key] = value
    movie_list.append(row_dict)
movies = movie_list
movies
# Out:
# [{'_id': 1,
#   'type': 'short',
#   'title': 'Carmencita',
#   'originalTitle': 'Carmencita',
#   'startYear': 1894,
#   'runtime': 1,
#   'avgRating': 5.7,
#   'numVotes': 1949,
#   'genres': ['Documentary', 'Short'],
#   'actors': [{'actor': 1588970, 'roles': ['Self']}],
#   'directors': [5690]},
#  {'_id': 2,
#   'type': 'short',
#   'title': 'Le clown et ses chiens',
#   'originalTitle': 'Le clown et ses chiens',
#   'startYear': 1892,
#   'runtime': 5,
#   'avgRating': 5.8,
#   'numVotes': 264,
#   'genres': ['Short', 'Animation'],
#   'directors': [721526]},
#  {'_id': 3,
#   'type': 'short',
#   'title': 'Pauvre Pierrot',
#   'originalTitle': 'Pauvre Pierrot',
#   'startYear': 1892,
#   'runtime': 4,
#   'avgRating': 6.5,
#   'numVotes': 1779,
#   'genres': ['Animation', 'Comedy', 'Romance'],
#   'directors': [721526],
#   'producers': [1770680]},
#  {'_id': 4,
#   'type': 'short',
#   'title': 'Un bon bock',
#   'originalTitle': 'Un bon bock',
#   'startYear': 1892,
#   'runtime': 12,
#   'avgRating': 5.6,
#   'numVotes': 179,
#   'genres': ['Short', 'Animation'],
#   'directors': [721526]},
#  {'_id': 5,
#   'type': 'short',
#   'title': 'Blacksmith Scene',
#   'originalTitle': 'Blacksmith Scene',
#   'startYear': 1893,
#   'runtime': 1,
#   'avgRating': 6.2,
#   'numVotes': 2583,
#   'genres': ['Short', 'Comedy'],
#   'actors': [{'actor': 443482, 'roles': ['Blacksmith']},
#    {'actor': 653042, 'roles': ['Assistant']}],
#   'directors': [5690],
#   'producers': [249379]},
#  {'_id': 6,
#   'type': 'short',
#   'title': 'Chinese Opium Den',
#   'originalTitle': 'Chinese Opium Den',
#   'startYear': 1894,
#   'runtime': 1,
#   'avgRating': 5.1,
#   'numVotes': 177,
#   'genres': ['Short'],
#   'directors': [5690]},
#  {'_id': 7,
#   'type': 'short',
#   'title': 'Corbett and Courtney Before the Kinetograph',
#   'originalTitle': 'Corbett and Courtney Before the Kinetograph',
#   'startYear': 1894,
#   'runtime': 1,
#   'avgRating': 5.4,
#   'numVotes': 811,
#   'genres': ['Short', 'Sport'],
#   'directors': [5690, 374658],
#   'producers': [249379]},
#  {'_id': 8,
#   'type': 'short',
#   'title': 'Edison Kinetoscopic Record of a Sneeze',
#   'originalTitle': 'Edison Kinetoscopic Record of a Sneeze',
#   'startYear': 1894,
#   'runtime': 1,
#   'avgRating': 5.4,
#   'numVotes': 2090,
#   'genres': ['Documentary', 'Short'],
#   'actors': [{'actor': 653028, 'roles': ['Sneezing Man']}],
#   'directors': [5690]},
#  {'_id': 9,
#   'type': 'movie',
#   'title': 'Miss Jerry',
#   'originalTitle': 'Miss Jerry',
#   'startYear': 1894,
#   'runtime': 45,
#   'avgRating': 5.3,
#   'numVotes': 204,
#   'genres': ['Romance'],
#   'actors': [{'actor': 63086,
#     'roles': ['Miss Geraldine Holbrook (Miss Jerry)']},
#    {'actor': 183823, 'roles': ['Mr. Hamilton']},
#    {'actor': 1309758,
#     'roles': ['Chauncey Depew - the Director of the New York Central Railroad']}],
#   'directors': [85156],
#   'writers': [85156]},
#  {'_id': 10,
#   'type': 'short',
#   'title': 'Leaving the Factory',
#   'originalTitle': "La sortie de l'usine Lumière à Lyon",
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 6.9,
#   'numVotes': 7047,
#   'genres': ['Documentary', 'Short'],
#   'directors': [525910]},
#  {'_id': 11,
#   'type': 'short',
#   'title': 'Akrobatisches Potpourri',
#   'originalTitle': 'Akrobatisches Potpourri',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 5.3,
#   'numVotes': 363,
#   'genres': ['Documentary', 'Short'],
#   'actors': [{'actor': 3692297, 'roles': ['Acrobats']}],
#   'directors': [804434]},
#  {'_id': 12,
#   'type': 'short',
#   'title': 'The Arrival of a Train',
#   'originalTitle': "L'arrivée d'un train à La Ciotat",
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 7.4,
#   'numVotes': 12090,
#   'genres': ['Documentary', 'Short'],
#   'actors': [{'actor': 525900, 'roles': ['Self']},
#    {'actor': 2880396, 'roles': ['Self']},
#    {'actor': 9653419, 'roles': ['Self']},
#    {'actor': 9735579, 'roles': ['Self']},
#    {'actor': 9735580, 'roles': ['Self']},
#    {'actor': 9735581, 'roles': ['Self']}],
#   'directors': [525908, 525910]},
#  {'_id': 13,
#   'type': 'short',
#   'title': 'The Photographical Congress Arrives in Lyon',
#   'originalTitle': 'Le débarquement du congrès de photographie à Lyon',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 5.7,
#   'numVotes': 1866,
#   'genres': ['Documentary', 'Short'],
#   'actors': [{'actor': 525908, 'roles': ['Self']},
#    {'actor': 1715062, 'roles': ['Self']}],
#   'directors': [525910]},
#  {'_id': 14,
#   'type': 'short',
#   'title': 'The Waterer Watered',
#   'originalTitle': "L'arroseur arrosé",
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 7.1,
#   'numVotes': 5436,
#   'genres': ['Short', 'Comedy'],
#   'actors': [{'actor': 166380, 'roles': ['The Gardener']},
#    {'actor': 244989, 'roles': ['The Boy']}],
#   'directors': [525910]},
#  {'_id': 15,
#   'type': 'short',
#   'title': "Autour d'une cabine",
#   'originalTitle': "Autour d'une cabine",
#   'startYear': 1894,
#   'runtime': 2,
#   'avgRating': 6.2,
#   'numVotes': 1064,
#   'genres': ['Short', 'Animation'],
#   'directors': [721526]},
#  {'_id': 16,
#   'type': 'short',
#   'title': 'Boat Leaving the Port',
#   'originalTitle': 'Barque sortant du port',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 5.9,
#   'numVotes': 1480,
#   'genres': ['Documentary', 'Short'],
#   'actors': [{'actor': 525900, 'roles': ['Self (on the pier)']},
#    {'actor': 9735581, 'roles': ['Self (on the pier)']}],
#   'directors': [525910]},
#  {'_id': 17,
#   'type': 'short',
#   'title': 'Italienischer Bauerntanz',
#   'originalTitle': 'Italienischer Bauerntanz',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 4.6,
#   'numVotes': 323,
#   'genres': ['Documentary', 'Short'],
#   'actors': [{'actor': 3691272, 'roles': ['The boy']},
#    {'actor': 3692829, 'roles': ['The girl']}],
#   'directors': [804434, 1587194]},
#  {'_id': 18,
#   'type': 'short',
#   'title': 'Das boxende Känguruh',
#   'originalTitle': 'Das boxende Känguruh',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 5.3,
#   'numVotes': 587,
#   'genres': ['Short'],
#   'actors': [{'actor': 3692071, 'roles': ['The Boxer']}],
#   'directors': [804434]},
#  {'_id': 19,
#   'type': 'short',
#   'title': 'The Clown Barber',
#   'originalTitle': 'The Clown Barber',
#   'startYear': 1898,
#   'runtime': 0,
#   'avgRating': 5.1,
#   'numVotes': 31,
#   'genres': ['Short', 'Comedy'],
#   'directors': [932055]},
#  {'_id': 20,
#   'type': 'short',
#   'title': 'The Derby 1895',
#   'originalTitle': 'The Derby 1895',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 4.8,
#   'numVotes': 355,
#   'genres': ['Documentary', 'Short', 'Sport'],
#   'directors': [10291],
#   'producers': [666972]},
#  {'_id': 22,
#   'type': 'short',
#   'title': 'Blacksmith Scene',
#   'originalTitle': 'Les forgerons',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 5.1,
#   'numVotes': 1084,
#   'genres': ['Documentary', 'Short'],
#   'directors': [525910]},
#  {'_id': 23,
#   'type': 'short',
#   'title': 'The Sea',
#   'originalTitle': 'Baignade en mer',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 5.7,
#   'numVotes': 1421,
#   'genres': ['Documentary', 'Short'],
#   'directors': [525910]},
#  {'_id': 24,
#   'type': 'short',
#   'title': 'Opening of the Kiel Canal',
#   'originalTitle': 'Opening of the Kiel Canal',
#   'startYear': 1895,
#   'runtime': 0,
#   'avgRating': 4.2,
#   'numVotes': 110,
#   'genres': ['Short', 'News'],
#   'actors': [{'actor': 256651, 'roles': ['Self - Empress of Gemany']},
#    {'actor': 435118, 'roles': ['Self - Emperor of Germany']}],
#   'directors': [10291],
#   'producers': [666972]},
#  {'_id': 25,
#   'type': 'short',
#   'title': 'The Oxford and Cambridge University Boat Race',
#   'originalTitle': 'The Oxford and Cambridge University Boat Race',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.8,
#   'numVotes': 46,
#   'genres': ['Short', 'Sport', 'News'],
#   'directors': [10291],
#   'producers': [666972]},
#  {'_id': 26,
#   'type': 'short',
#   'title': 'The Messers. Lumière at Cards',
#   'originalTitle': "Partie d'écarté",
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 5.6,
#   'numVotes': 1524,
#   'genres': ['Documentary', 'Short'],
#   'actors': [{'actor': 525907,
#     'roles': ['Man playing cards', 'seated on the left']},
#    {'actor': 1151424, 'roles': ['Man playing cards', 'seated on the right']},
#    {'actor': 2350007, 'roles': ['Valet']},
#    {'actor': 2354154, 'roles': ['Man playing cards', 'seated in the middle']}],
#   'directors': [525910]},
#  {'_id': 27,
#   'type': 'short',
#   'title': "Cordeliers' Square in Lyon",
#   'originalTitle': 'Place des Cordeliers à Lyon',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 5.6,
#   'numVotes': 1143,
#   'genres': ['Documentary', 'Short'],
#   'directors': [525910]},
#  {'_id': 28,
#   'type': 'short',
#   'title': 'Fishing for Goldfish',
#   'originalTitle': 'La pêche aux poissons rouges',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 5.1,
#   'numVotes': 1066,
#   'genres': ['Documentary', 'Short'],
#   'actors': [{'actor': 525908, 'roles': ['Self']},
#    {'actor': 2350838, 'roles': ['Self']}],
#   'directors': [525910]},
#  {'_id': 29,
#   'type': 'short',
#   'title': "Baby's Meal",
#   'originalTitle': 'Repas de bébé',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 5.9,
#   'numVotes': 3324,
#   'genres': ['Documentary', 'Short'],
#   'actors': [{'actor': 525900, 'roles': ['Self']},
#    {'actor': 525908, 'roles': ['Self']},
#    {'actor': 2350838, 'roles': ['Self']}],
#   'directors': [525910]},
#  {'_id': 30,
#   'type': 'short',
#   'title': 'Rough Sea at Dover',
#   'originalTitle': 'Rough Sea at Dover',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 5.2,
#   'numVotes': 840,
#   'genres': ['Documentary', 'Short'],
#   'directors': [10291, 666972]},
#  {'_id': 31,
#   'type': 'short',
#   'title': 'Jumping the Blanket',
#   'originalTitle': 'Le saut à la couverture',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 5.5,
#   'numVotes': 998,
#   'genres': ['Documentary', 'Short'],
#   'directors': [525910]},
#  {'_id': 32,
#   'type': 'short',
#   'title': 'Die Serpentintänzerin',
#   'originalTitle': 'Die Serpentintänzerin',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 5.0,
#   'numVotes': 414,
#   'genres': ['Short'],
#   'actors': [{'actor': 3692479, 'roles': ['The dancer']}],
#   'directors': [804434]},
#  {'_id': 33,
#   'type': 'short',
#   'title': 'Horse Trick Riders',
#   'originalTitle': 'La voltige',
#   'startYear': 1895,
#   'runtime': 1,
#   'avgRating': 5.5,
#   'numVotes': 1024,
#   'genres': ['Documentary', 'Short', 'Comedy'],
#   'directors': [525910]},
#  {'_id': 34,
#   'type': 'short',
#   'title': "Arrivée d'un train gare de Vincennes",
#   'originalTitle': "Arrivée d'un train gare de Vincennes",
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 5.0,
#   'numVotes': 203,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 35,
#   'type': 'short',
#   'title': 'Watering the Flowers',
#   'originalTitle': "L'arroseur",
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 5.6,
#   'numVotes': 82,
#   'genres': ['Short', 'Comedy'],
#   'directors': [617588]},
#  {'_id': 36,
#   'type': 'short',
#   'title': 'Awakening of Rip',
#   'originalTitle': 'Awakening of Rip',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.4,
#   'numVotes': 602,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 420198, 'roles': ['Rip Van Winkle']}],
#   'directors': [5690],
#   'writers': [410331]},
#  {'_id': 37,
#   'type': 'short',
#   'title': 'Sea Bathing',
#   'originalTitle': 'Baignade en mer',
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 4.3,
#   'numVotes': 68,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 38,
#   'type': 'short',
#   'title': 'The Ball Game',
#   'originalTitle': 'The Ball Game',
#   'startYear': 1898,
#   'runtime': 0,
#   'avgRating': 4.2,
#   'numVotes': 199,
#   'genres': ['Documentary', 'Short', 'Sport'],
#   'actors': [{'actor': 340719, 'roles': ['Self']},
#    {'actor': 2958402, 'roles': ['Self']},
#    {'actor': 2960633, 'roles': ['Self - First baseman']}],
#   'directors': [374658]},
#  {'_id': 39,
#   'type': 'short',
#   'title': 'Barnet Horse Fair',
#   'originalTitle': 'Barnet Horse Fair',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.3,
#   'numVotes': 32,
#   'genres': ['Short'],
#   'producers': [666972]},
#  {'_id': 40,
#   'type': 'short',
#   'title': 'Barque sortant du port de Trouville',
#   'originalTitle': 'Barque sortant du port de Trouville',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.0,
#   'numVotes': 66,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 41,
#   'type': 'short',
#   'title': 'Bataille de neige',
#   'originalTitle': 'Bataille de neige',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 6.7,
#   'numVotes': 1835,
#   'genres': ['Documentary', 'Short', 'Comedy'],
#   'directors': [525910],
#   'producers': [525908]},
#  {'_id': 42,
#   'type': 'short',
#   'title': 'Bateau-mouche sur la Seine',
#   'originalTitle': 'Bateau-mouche sur la Seine',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.9,
#   'numVotes': 39,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 43,
#   'type': 'short',
#   'title': 'Batteuse à vapeur',
#   'originalTitle': 'Batteuse à vapeur',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.2,
#   'numVotes': 34,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 44,
#   'type': 'short',
#   'title': 'Le bivouac',
#   'originalTitle': 'Le bivouac',
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 3.9,
#   'numVotes': 47,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 45,
#   'type': 'short',
#   'title': 'Les blanchisseuses',
#   'originalTitle': 'Les blanchisseuses',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.8,
#   'numVotes': 35,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 46,
#   'type': 'short',
#   'title': 'Bois de Boulogne',
#   'originalTitle': 'Bois de Boulogne',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.9,
#   'numVotes': 36,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 47,
#   'type': 'short',
#   'title': 'Boulevard des Italiens',
#   'originalTitle': 'Boulevard des Italiens',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.3,
#   'numVotes': 36,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 48,
#   'type': 'short',
#   'title': 'The Boxing Kangaroo',
#   'originalTitle': 'The Boxing Kangaroo',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.8,
#   'numVotes': 197,
#   'genres': ['Short'],
#   'directors': [10291]},
#  {'_id': 49,
#   'type': 'short',
#   'title': 'Boxing Match; or, Glove Contest',
#   'originalTitle': 'Boxing Match; or, Glove Contest',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 5.0,
#   'numVotes': 51,
#   'genres': ['Short', 'Sport'],
#   'directors': [10291]},
#  {'_id': 50,
#   'type': 'short',
#   'title': 'Bébé et fillettes',
#   'originalTitle': 'Bébé et fillettes',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.9,
#   'numVotes': 36,
#   'genres': ['Documentary', 'Short'],
#   'actors': [{'actor': 3029234, 'roles': ['Self']}],
#   'directors': [617588]},
#  {'_id': 51,
#   'type': 'short',
#   'title': 'The Bohemian Encampment',
#   'originalTitle': 'Campement de bohémiens',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.4,
#   'numVotes': 37,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 52,
#   'type': 'short',
#   'title': 'Carga de rurales',
#   'originalTitle': 'Carga de rurales',
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 4.2,
#   'numVotes': 102,
#   'genres': ['Documentary', 'Short'],
#   'directors': [895515]},
#  {'_id': 53,
#   'type': 'short',
#   'title': 'A Chegada do Comboio Inaugural à Estação Central do Porto',
#   'originalTitle': 'A Chegada do Comboio Inaugural à Estação Central do Porto',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 3.3,
#   'numVotes': 19,
#   'genres': ['Documentary', 'Short'],
#   'directors': [684607]},
#  {'_id': 54,
#   'type': 'short',
#   'title': 'A Merry-Go-Round',
#   'originalTitle': 'Les chevaux de bois',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.7,
#   'numVotes': 36,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 55,
#   'type': 'short',
#   'title': 'Le chiffonnier',
#   'originalTitle': 'Le chiffonnier',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.4,
#   'numVotes': 32,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 56,
#   'type': 'short',
#   'title': 'Uma Corrida de Touros no Campo Pequeno',
#   'originalTitle': 'Uma Corrida de Touros no Campo Pequeno',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 2.8,
#   'numVotes': 24,
#   'genres': ['Short'],
#   'directors': [795060]},
#  {'_id': 57,
#   'type': 'short',
#   'title': 'Cortège de tzar allant à Versailles',
#   'originalTitle': 'Cortège de tzar allant à Versailles',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.2,
#   'numVotes': 36,
#   'genres': ['Documentary', 'Short'],
#   'actors': [{'actor': 874739, 'roles': ['Self (Tsar of Russia)']},
#    {'actor': 874746, 'roles': ['Self (Tsarina of Russia)']}],
#   'directors': [617588]},
#  {'_id': 58,
#   'type': 'short',
#   'title': 'Cortège de tzar au Bois de Boulogne',
#   'originalTitle': 'Cortège de tzar au Bois de Boulogne',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.0,
#   'numVotes': 35,
#   'genres': ['Documentary', 'Short'],
#   'actors': [{'actor': 874739, 'roles': ['Self (Tsar of Russia)']}],
#   'directors': [617588]},
#  {'_id': 59,
#   'type': 'short',
#   'title': 'Coronation of a Village Maiden',
#   'originalTitle': 'Couronnement de la rosière',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.2,
#   'numVotes': 29,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 60,
#   'type': 'short',
#   'title': 'Dancing Darkies',
#   'originalTitle': 'Dancing Darkies',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 7.4,
#   'numVotes': 89,
#   'genres': ['Documentary', 'Short'],
#   'directors': [5690]},
#  {'_id': 61,
#   'type': 'short',
#   'title': 'Dancing Girls',
#   'originalTitle': 'Dancing Girls',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.9,
#   'numVotes': 26,
#   'genres': ['Short'],
#   'directors': [10291],
#   'producers': [666972]},
#  {'_id': 62,
#   'type': 'short',
#   'title': 'Danse serpentine',
#   'originalTitle': 'Danse serpentine',
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 6.3,
#   'numVotes': 198,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 63,
#   'type': 'short',
#   'title': 'Dessinateur express',
#   'originalTitle': 'Dessinateur express',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.2,
#   'numVotes': 30,
#   'genres': ['Short'],
#   'actors': [{'actor': 617588, 'roles': ['Georges Méliès']}],
#   'directors': [617588]},
#  {'_id': 64,
#   'type': 'short',
#   'title': 'Dessinateur: Chamberlain',
#   'originalTitle': 'Dessinateur: Chamberlain',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 2.8,
#   'numVotes': 31,
#   'genres': ['Short'],
#   'actors': [{'actor': 617588, 'roles': ['Lightening Sketch Artist']}],
#   'directors': [617588]},
#  {'_id': 65,
#   'type': 'short',
#   'title': 'Dessinateur: Reine Victoria',
#   'originalTitle': 'Dessinateur: Reine Victoria',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.1,
#   'numVotes': 31,
#   'genres': ['Short'],
#   'actors': [{'actor': 617588, 'roles': ['Lightening Sketch Artist']}],
#   'directors': [617588]},
#  {'_id': 66,
#   'type': 'short',
#   'title': 'Dessinateur: Von Bismark',
#   'originalTitle': 'Dessinateur: Von Bismark',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.0,
#   'numVotes': 31,
#   'genres': ['Short'],
#   'actors': [{'actor': 617588, 'roles': ['Lightening Sketch Artist']}],
#   'directors': [617588]},
#  {'_id': 67,
#   'type': 'short',
#   'title': 'Conjurer Making Ten Hats in Sixty Seconds',
#   'originalTitle': 'Dix chapeaux en 60 secondes',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 5.5,
#   'numVotes': 64,
#   'genres': ['Short', 'Fantasy'],
#   'directors': [617588]},
#  {'_id': 68,
#   'type': 'short',
#   'title': 'Unloading the Boat',
#   'originalTitle': 'Déchargement de bateaux',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.5,
#   'numVotes': 33,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 69,
#   'type': 'short',
#   'title': 'Post No Bills',
#   'originalTitle': "Défense d'afficher",
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 4.9,
#   'numVotes': 450,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 70,
#   'type': 'short',
#   'title': 'Demolition of a Wall',
#   'originalTitle': "Démolition d'un mur",
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 6.4,
#   'numVotes': 2621,
#   'genres': ['Documentary', 'Short'],
#   'directors': [525910]},
#  {'_id': 71,
#   'type': 'short',
#   'title': 'Automobiles Starting a Race',
#   'originalTitle': 'Départ des automobiles',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.1,
#   'numVotes': 31,
#   'genres': ['Short', 'Sport'],
#   'directors': [617588]},
#  {'_id': 72,
#   'type': 'short',
#   'title': 'Officers of French Army Leaving Service',
#   'originalTitle': 'Départ des officiers',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.3,
#   'numVotes': 29,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 73,
#   'type': 'short',
#   'title': 'Effets de mer sur les rochers',
#   'originalTitle': 'Effets de mer sur les rochers',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.2,
#   'numVotes': 32,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 74,
#   'type': 'short',
#   'title': 'Enfants jouant sur la plage',
#   'originalTitle': 'Enfants jouant sur la plage',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.3,
#   'numVotes': 33,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 75,
#   'type': 'short',
#   'title': 'The Conjuring of a Woman at the House of Robert Houdin',
#   'originalTitle': "Escamotage d'une dame au théâtre Robert Houdin",
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 6.3,
#   'numVotes': 1906,
#   'genres': ['Short', 'Horror'],
#   'actors': [{'actor': 194945, 'roles': ['Woman']},
#    {'actor': 617588, 'roles': ['Magician']}],
#   'directors': [617588]},
#  {'_id': 76,
#   'type': 'short',
#   'title': 'Exit of Rip and the Dwarf',
#   'originalTitle': 'Exit of Rip and the Dwarf',
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 4.5,
#   'numVotes': 532,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 420198, 'roles': ['Rip Van Winkle']}],
#   'directors': [5690],
#   'writers': [410331]},
#  {'_id': 77,
#   'type': 'short',
#   'title': 'Le fakir, mystère indien',
#   'originalTitle': 'Le fakir, mystère indien',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.3,
#   'numVotes': 37,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 78,
#   'type': 'short',
#   'title': 'Feira de Gado na Corujeira',
#   'originalTitle': 'Feira de Gado na Corujeira',
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 3.7,
#   'numVotes': 83,
#   'genres': ['Documentary', 'Short'],
#   'directors': [234288]},
#  {'_id': 79,
#   'type': 'short',
#   'title': 'La gare Saint-Lazare',
#   'originalTitle': 'La gare Saint-Lazare',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.1,
#   'numVotes': 37,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 80,
#   'type': 'short',
#   'title': 'Grandes manoeuvres',
#   'originalTitle': 'Grandes manoeuvres',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.7,
#   'numVotes': 32,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 81,
#   'type': 'short',
#   'title': 'Towing a Boat on the River',
#   'originalTitle': 'Les haleurs de bateaux',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.8,
#   'numVotes': 33,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 82,
#   'type': 'short',
#   'title': 'A Hard Wash',
#   'originalTitle': 'A Hard Wash',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.6,
#   'numVotes': 50,
#   'genres': ['Short', 'Comedy'],
#   'directors': [5690]},
#  {'_id': 83,
#   'type': 'short',
#   'title': 'Les indiscrets',
#   'originalTitle': 'Les indiscrets',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.4,
#   'numVotes': 33,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 84,
#   'type': 'short',
#   'title': 'Les ivrognes',
#   'originalTitle': 'Les ivrognes',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.1,
#   'numVotes': 31,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 85,
#   'type': 'short',
#   'title': 'Gardener Burning Weeds',
#   'originalTitle': 'Jardinier brûlant des herbes',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.4,
#   'numVotes': 34,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 86,
#   'type': 'short',
#   'title': 'Beach and Pier at Trouville, 1st part',
#   'originalTitle': 'Jetée et plage de Trouville (1er partie)',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.8,
#   'numVotes': 34,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 87,
#   'type': 'short',
#   'title': 'Beach and Pier at Trouville, 2nd part',
#   'originalTitle': 'Jetée et plage de Trouville (2e partie)',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.5,
#   'numVotes': 38,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 88,
#   'type': 'short',
#   'title': 'Market Day',
#   'originalTitle': 'Jour de marché à Trouville',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.9,
#   'numVotes': 33,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 89,
#   'type': 'short',
#   'title': 'Leaving Jerusalem by Railway',
#   'originalTitle': 'Départ de Jérusalem en chemin de fer',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 6.2,
#   'numVotes': 991,
#   'genres': ['Documentary', 'Short'],
#   'directors': [525908, 698645],
#   'producers': [525910]},
#  {'_id': 90,
#   'type': 'short',
#   'title': 'Libération des territoriaux',
#   'originalTitle': 'Libération des territoriaux',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.6,
#   'numVotes': 32,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 91,
#   'type': 'short',
#   'title': 'The House of the Devil',
#   'originalTitle': 'Le manoir du diable',
#   'startYear': 1896,
#   'runtime': 3,
#   'avgRating': 6.7,
#   'numVotes': 3603,
#   'genres': ['Short', 'Horror'],
#   'actors': [{'actor': 194945, 'roles': ['Young woman']},
#    {'actor': 617588, 'roles': ['Mephistopheles']},
#    {'actor': 6170115, 'roles': ['Mephistopheles']}],
#   'directors': [617588],
#   'writers': [617588]},
#  {'_id': 92,
#   'type': 'short',
#   'title': 'Marée montante sur Brise-Larmes',
#   'originalTitle': 'Marée montante sur Brise-Larmes',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.2,
#   'numVotes': 30,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 93,
#   'type': 'short',
#   'title': 'Melbourne',
#   'originalTitle': 'Melbourne',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.7,
#   'numVotes': 94,
#   'genres': ['Documentary', 'Short'],
#   'directors': [525908, 525910]},
#  {'_id': 94,
#   'type': 'short',
#   'title': 'Miss de Vere',
#   'originalTitle': 'Miss de Vere',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.1,
#   'numVotes': 33,
#   'genres': ['Short'],
#   'actors': [{'actor': 9513675, 'roles': ['Self']}],
#   'directors': [617588]},
#  {'_id': 95,
#   'type': 'short',
#   'title': 'The Mysterious Paper',
#   'originalTitle': 'Le papier protée',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.6,
#   'numVotes': 35,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 96,
#   'type': 'short',
#   'title': 'Place Saint-Augustin',
#   'originalTitle': 'Place Saint-Augustin',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.0,
#   'numVotes': 30,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 97,
#   'type': 'short',
#   'title': "Place de l'Opéra, First View",
#   'originalTitle': "Place de l'Opéra, 1er aspect",
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.6,
#   'numVotes': 34,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 98,
#   'type': 'short',
#   'title': "Place de l'Opéra, Second View",
#   'originalTitle': "Place de l'Opéra, 2e aspect",
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.9,
#   'numVotes': 37,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 99,
#   'type': 'short',
#   'title': 'Place de la Bastille',
#   'originalTitle': 'Place de la Bastille',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.3,
#   'numVotes': 33,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 100,
#   'type': 'short',
#   'title': 'Place de la Concorde',
#   'originalTitle': 'Place de la Concorde',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.7,
#   'numVotes': 54,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 101,
#   'type': 'short',
#   'title': 'Place du théâtre français',
#   'originalTitle': 'Place du théâtre français',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.2,
#   'numVotes': 29,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 102,
#   'type': 'short',
#   'title': 'The Beach at Villiers in a Gale',
#   'originalTitle': 'Plage de Villiers par gros temps',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.3,
#   'numVotes': 27,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 103,
#   'type': 'short',
#   'title': 'Smarter than the Teacher',
#   'originalTitle': 'Plus fort que le maître',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 5.1,
#   'numVotes': 28,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 104,
#   'type': 'short',
#   'title': 'Pompiers à Lyon',
#   'originalTitle': 'Pompiers à Lyon',
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 5.6,
#   'numVotes': 466,
#   'genres': ['Documentary', 'Short'],
#   'producers': [525910]},
#  {'_id': 105,
#   'type': 'short',
#   'title': 'The Docks at Marseilles',
#   'originalTitle': 'Les quais à Marseille',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.6,
#   'numVotes': 30,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 106,
#   'type': 'short',
#   'title': 'Retour au cantonnement',
#   'originalTitle': 'Retour au cantonnement',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.0,
#   'numVotes': 24,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 107,
#   'type': 'short',
#   'title': 'Naval Review at Cherburg',
#   'originalTitle': 'Revue navale à Cherbourg',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.8,
#   'numVotes': 29,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 108,
#   'type': 'short',
#   'title': 'Rip Leaving Sleepy Hollow',
#   'originalTitle': 'Rip Leaving Sleepy Hollow',
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 4.4,
#   'numVotes': 541,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 420198, 'roles': ['Rip Van Winkle']}],
#   'directors': [5690],
#   'writers': [410331]},
#  {'_id': 109,
#   'type': 'short',
#   'title': 'Rip Meeting the Dwarf',
#   'originalTitle': 'Rip Meeting the Dwarf',
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 4.5,
#   'numVotes': 525,
#   'genres': ['Short', 'Fantasy'],
#   'actors': [{'actor': 420198, 'roles': ['Rip Van Winkle']}],
#   'directors': [5690],
#   'writers': [410331]},
#  {'_id': 110,
#   'type': 'short',
#   'title': 'Rip Passing Over the Mountain',
#   'originalTitle': 'Rip Passing Over the Mountain',
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 4.4,
#   'numVotes': 528,
#   'genres': ['Short', 'Fantasy'],
#   'actors': [{'actor': 420198, 'roles': ['Rip Van Winkle']}],
#   'directors': [5690],
#   'writers': [410331]},
#  {'_id': 111,
#   'type': 'short',
#   'title': "Rip's Toast",
#   'originalTitle': "Rip's Toast",
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 4.4,
#   'numVotes': 543,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 420198, 'roles': ['Rip Van Winkle']}],
#   'directors': [5690],
#   'writers': [410331]},
#  {'_id': 112,
#   'type': 'short',
#   'title': "Rip's Toast to Hudson",
#   'originalTitle': "Rip's Toast to Hudson",
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 4.5,
#   'numVotes': 522,
#   'genres': ['Short', 'Fantasy'],
#   'actors': [{'actor': 420198, 'roles': ['Rip Van Winkle']}],
#   'directors': [5690],
#   'writers': [410331]},
#  {'_id': 113,
#   'type': 'short',
#   'title': "Rip's Twenty Years' Sleep",
#   'originalTitle': "Rip's Twenty Years' Sleep",
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.3,
#   'numVotes': 549,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 420198, 'roles': ['Rip Van Winkle']}],
#   'directors': [5690],
#   'writers': [410331]},
#  {'_id': 114,
#   'type': 'short',
#   'title': 'French Regiment Going to the Parade',
#   'originalTitle': 'Le régiment',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.8,
#   'numVotes': 31,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 115,
#   'type': 'short',
#   'title': "Réunion d'officiers",
#   'originalTitle': "Réunion d'officiers",
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.6,
#   'numVotes': 35,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 116,
#   'type': 'short',
#   'title': 'Sac au dos',
#   'originalTitle': 'Sac au dos',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.8,
#   'numVotes': 28,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 117,
#   'type': 'short',
#   'title': 'Saída do Pessoal Operário da Fábrica Confiança',
#   'originalTitle': 'Saída do Pessoal Operário da Fábrica Confiança',
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 5.1,
#   'numVotes': 164,
#   'genres': ['Documentary', 'Short'],
#   'directors': [234288]},
#  {'_id': 118,
#   'type': 'short',
#   'title': "Salut malencontreux d'un déserteur",
#   'originalTitle': "Salut malencontreux d'un déserteur",
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.8,
#   'numVotes': 29,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 119,
#   'type': 'short',
#   'title': 'Rescue on the River, Pt. 2',
#   'originalTitle': 'Sauvetage en rivière, 1er',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 5.2,
#   'numVotes': 56,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 120,
#   'type': 'short',
#   'title': 'Rescue on the River, Pt. 1',
#   'originalTitle': 'Sauvetage en rivière, 2e',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 5.2,
#   'numVotes': 52,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 121,
#   'type': 'short',
#   'title': "The Soldier's Courtship",
#   'originalTitle': "The Soldier's Courtship",
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 4.1,
#   'numVotes': 87,
#   'genres': ['Short', 'Comedy'],
#   'actors': [{'actor': 780534, 'roles': ['The Girl']},
#    {'actor': 832461, 'roles': ['The Soldier']},
#    {'actor': 5718242, 'roles': ['The Woman']}],
#   'directors': [609678],
#   'producers': [666972]},
#  {'_id': 122,
#   'type': 'short',
#   'title': "Closing Hours at Vibert's Perfume Factory",
#   'originalTitle': 'Sortie des ateliers Vibert',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.8,
#   'numVotes': 32,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 123,
#   'type': 'short',
#   'title': 'Conjuring',
#   'originalTitle': 'Séance de prestidigitation',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 5.7,
#   'numVotes': 141,
#   'genres': ['Short'],
#   'actors': [{'actor': 617588, 'roles': ['Self (stage magician)']}],
#   'directors': [617588]},
#  {'_id': 124,
#   'type': 'short',
#   'title': 'Tempête sur la jetée du treport',
#   'originalTitle': 'Tempête sur la jetée du treport',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.9,
#   'numVotes': 31,
#   'genres': ['Documentary', 'Short'],
#   'directors': [617588]},
#  {'_id': 125,
#   'type': 'short',
#   'title': 'The Terrible Railway Accident',
#   'originalTitle': 'The Terrible Railway Accident',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.0,
#   'numVotes': 16,
#   'genres': ['Short'],
#   'producers': [666972]},
#  {'_id': 126,
#   'type': 'short',
#   'title': 'Tom Old Boot',
#   'originalTitle': 'Tom Old Boot',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 5.5,
#   'numVotes': 32,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 127,
#   'type': 'short',
#   'title': "Les tribulations d'un concierge",
#   'originalTitle': "Les tribulations d'un concierge",
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.1,
#   'numVotes': 27,
#   'genres': ['Short', 'Comedy'],
#   'directors': [617588]},
#  {'_id': 128,
#   'type': 'short',
#   'title': 'Academy for Young Ladies',
#   'originalTitle': 'Un lycée de jeunes filles',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 5.5,
#   'numVotes': 39,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 129,
#   'type': 'short',
#   'title': 'Un petit diable',
#   'originalTitle': 'Un petit diable',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 6.4,
#   'numVotes': 52,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 130,
#   'type': 'short',
#   'title': 'Une altercation au café',
#   'originalTitle': 'Une altercation au café',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.8,
#   'numVotes': 29,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 131,
#   'type': 'short',
#   'title': 'A Terrible Night',
#   'originalTitle': 'Une nuit terrible',
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 5.7,
#   'numVotes': 1390,
#   'genres': ['Short', 'Comedy', 'Horror'],
#   'actors': [{'actor': 617588, 'roles': ["L'homme qui essaie de dormir"]}],
#   'directors': [617588]},
#  {'_id': 132,
#   'type': 'short',
#   'title': 'Card Party',
#   'originalTitle': 'Une partie de cartes',
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 5.1,
#   'numVotes': 1054,
#   'genres': ['Short', 'Biography'],
#   'actors': [{'actor': 577734, 'roles': ['Un joueur de cartes']},
#    {'actor': 617588, 'roles': ['Un joueur de cartes']},
#    {'actor': 3029234, 'roles': ['La petite fille']},
#    {'actor': 9342429, 'roles': ['La Serveuse']}],
#   'directors': [617588],
#   'writers': [617588]},
#  {'_id': 133,
#   'type': 'short',
#   'title': 'La voiture du potier',
#   'originalTitle': 'La voiture du potier',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 6.0,
#   'numVotes': 36,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 134,
#   'type': 'short',
#   'title': 'The Wandering Negro Minstrels',
#   'originalTitle': 'The Wandering Negro Minstrels',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 4.4,
#   'numVotes': 21,
#   'genres': ['Short', 'Music']},
#  {'_id': 135,
#   'type': 'short',
#   'title': 'A Watermelon Feast',
#   'originalTitle': 'A Watermelon Feast',
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 6.4,
#   'numVotes': 84,
#   'genres': ['Documentary', 'Short'],
#   'directors': [5690]},
#  {'_id': 137,
#   'type': 'short',
#   'title': 'Au réfectoire',
#   'originalTitle': 'Au réfectoire',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 4.5,
#   'numVotes': 30,
#   'genres': ['Short', 'Comedy'],
#   'directors': [349785]},
#  {'_id': 138,
#   'type': 'short',
#   'title': 'The Bewitched Inn',
#   'originalTitle': "L'auberge ensorcelée",
#   'startYear': 1897,
#   'runtime': 2,
#   'avgRating': 6.4,
#   'numVotes': 1125,
#   'genres': ['Short', 'Comedy', 'Horror'],
#   'actors': [{'actor': 617588, 'roles': ['Inn Guest']}],
#   'directors': [617588],
#   'writers': [617588]},
#  {'_id': 139,
#   'type': 'short',
#   'title': "L'aveugle",
#   'originalTitle': "L'aveugle",
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 5.3,
#   'numVotes': 24,
#   'genres': ['Short', 'Drama'],
#   'directors': [349785]},
#  {'_id': 140,
#   'type': 'short',
#   'title': 'Baignade dans le torrent',
#   'originalTitle': 'Baignade dans le torrent',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 4.9,
#   'numVotes': 296,
#   'genres': ['Short'],
#   'directors': [349785]},
#  {'_id': 141,
#   'type': 'short',
#   'title': 'Ballet libella',
#   'originalTitle': 'Ballet libella',
#   'startYear': 1897,
#   'runtime': 2,
#   'avgRating': 5.1,
#   'numVotes': 102,
#   'genres': ['Documentary', 'Short'],
#   'directors': [349785]},
#  {'_id': 142,
#   'type': 'short',
#   'title': 'Buffalo Bill and Escort',
#   'originalTitle': 'Buffalo Bill and Escort',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 4.1,
#   'numVotes': 29,
#   'genres': ['Short', 'News'],
#   'directors': [924920]},
#  {'_id': 143,
#   'type': 'short',
#   'title': 'Les cambrioleurs',
#   'originalTitle': 'Les cambrioleurs',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 4.9,
#   'numVotes': 261,
#   'genres': ['Short', 'Comedy'],
#   'directors': [349785]},
#  {'_id': 144,
#   'type': 'short',
#   'title': 'Chez le magnétiseur',
#   'originalTitle': 'Chez le magnétiseur',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 5.1,
#   'numVotes': 313,
#   'genres': ['Short', 'Comedy'],
#   'directors': [349785]},
#  {'_id': 145,
#   'type': 'short',
#   'title': 'En classe',
#   'originalTitle': 'En classe',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 3.2,
#   'numVotes': 13,
#   'genres': ['Short', 'Comedy'],
#   'directors': [349785]},
#  {'_id': 146,
#   'type': 'short',
#   'title': 'Le cocher de fiacre endormi',
#   'originalTitle': 'Le cocher de fiacre endormi',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 5.0,
#   'numVotes': 26,
#   'genres': ['Short', 'Comedy'],
#   'directors': [349785]},
#  {'_id': 147,
#   'type': 'movie',
#   'title': 'The Corbett-Fitzsimmons Fight',
#   'originalTitle': 'The Corbett-Fitzsimmons Fight',
#   'startYear': 1897,
#   'runtime': 100,
#   'avgRating': 5.2,
#   'numVotes': 466,
#   'genres': ['Documentary', 'Sport', 'News'],
#   'actors': [{'actor': 179163, 'roles': ['Self']},
#    {'actor': 280615, 'roles': ['Self']},
#    {'actor': 2256592, 'roles': ['Self - Master of Ceremonies']},
#    {'actor': 4081458, 'roles': ['Self - Referee']},
#    {'actor': 4082222, 'roles': ["Self - Sullivan's Manager"]}],
#   'directors': [714557],
#   'producers': [103755]},
#  {'_id': 148,
#   'type': 'short',
#   'title': "Le Coucher d'Yvette",
#   'originalTitle': "Le Coucher d'Yvette",
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 2.7,
#   'numVotes': 15,
#   'genres': ['Short'],
#   'directors': [349785]},
#  {'_id': 149,
#   'type': 'short',
#   'title': 'Behind the Scenes',
#   'originalTitle': 'Dans les coulisses',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 4.1,
#   'numVotes': 22,
#   'genres': ['Short', 'Comedy'],
#   'directors': [617588]},
#  {'_id': 150,
#   'type': 'short',
#   'title': 'Danse fleur de lotus',
#   'originalTitle': 'Danse fleur de lotus',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 5.3,
#   'numVotes': 166,
#   'genres': ['Documentary', 'Short'],
#   'directors': [349785]},
#  {'_id': 151,
#   'type': 'short',
#   'title': 'Faust et Marguerite',
#   'originalTitle': 'Faust et Marguerite',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 4.8,
#   'numVotes': 63,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 152,
#   'type': 'short',
#   'title': 'The Hallucinated Alchemist',
#   'originalTitle': "L'hallucination de l'alchimiste",
#   'startYear': 1897,
#   'runtime': 2,
#   'avgRating': 6.2,
#   'numVotes': 253,
#   'genres': ['Short', 'Fantasy', 'Horror'],
#   'directors': [617588]},
#  {'_id': 153,
#   'type': 'short',
#   'title': 'The Haunted Castle',
#   'originalTitle': 'The Haunted Castle',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 5.7,
#   'numVotes': 450,
#   'genres': ['Short', 'Horror'],
#   'directors': [808310]},
#  {'_id': 154,
#   'type': 'short',
#   'title': 'Henley Regatta',
#   'originalTitle': 'Henley Regatta',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 3.7,
#   'numVotes': 13,
#   'genres': ['Short', 'Sport', 'News'],
#   'directors': [10291]},
#  {'_id': 155,
#   'type': 'short',
#   'title': 'The Hypnotist at Work',
#   'originalTitle': 'Le magnétiseur',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 5.2,
#   'numVotes': 28,
#   'genres': ['Short'],
#   'directors': [617588]},
#  {'_id': 156,
#   'type': 'short',
#   'title': 'A Badly Managed Hotel',
#   'originalTitle': "L'hôtel empoisonné",
#   'startYear': 1896,
#   'runtime': 0,
#   'avgRating': 3.4,
#   'numVotes': 24,
#   'genres': ['Short', 'Comedy'],
#   'directors': [617588]},
#  {'_id': 157,
#   'type': 'short',
#   'title': 'Idylle',
#   'originalTitle': 'Idylle',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 3.7,
#   'numVotes': 15,
#   'genres': ['Short'],
#   'directors': [349785]},
#  {'_id': 158,
#   'type': 'short',
#   'title': 'Idylle interrompue',
#   'originalTitle': 'Idylle interrompue',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 2.8,
#   'numVotes': 15,
#   'genres': ['Short', 'Comedy'],
#   'directors': [349785]},
#  {'_id': 159,
#   'type': 'short',
#   'title': "The Devil's Laboratory",
#   'originalTitle': 'Le cabinet de Méphistophélès',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 5.2,
#   'numVotes': 127,
#   'genres': ['Short', 'Horror'],
#   'directors': [617588]},
#  {'_id': 160,
#   'type': 'short',
#   'title': 'The Last Days of Pompeii',
#   'originalTitle': 'The Last Days of Pompeii',
#   'startYear': 1900,
#   'runtime': 0,
#   'avgRating': 5.3,
#   'numVotes': 26,
#   'genres': ['Short', 'Drama'],
#   'directors': [95816],
#   'producers': [666972]},
#  {'_id': 161,
#   'type': 'short',
#   'title': 'Leçon de danse',
#   'originalTitle': 'Leçon de danse',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 3.3,
#   'numVotes': 14,
#   'genres': ['Short', 'Comedy'],
#   'directors': [349785]},
#  {'_id': 162,
#   'type': 'short',
#   'title': 'Niagara Falls',
#   'originalTitle': 'Les chutes',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 5.4,
#   'numVotes': 472,
#   'genres': ['Documentary', 'Short'],
#   'directors': [698645],
#   'producers': [525908, 525910]},
#  {'_id': 163,
#   'type': 'short',
#   'title': 'Le planton du colonel',
#   'originalTitle': 'Le planton du colonel',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 5.0,
#   'numVotes': 13,
#   'genres': ['Short', 'Comedy'],
#   'directors': [349785]},
#  {'_id': 164,
#   'type': 'short',
#   'title': 'Le pêcheur dans le torrent',
#   'originalTitle': 'Le pêcheur dans le torrent',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 5.0,
#   'numVotes': 296,
#   'genres': ['Short', 'Comedy'],
#   'directors': [349785]},
#  {'_id': 165,
#   'type': 'short',
#   'title': 'Riña en un café',
#   'originalTitle': 'Riña en un café',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 4.6,
#   'numVotes': 129,
#   'genres': ['Short'],
#   'directors': [5717],
#   'writers': [5717]},
#  {'_id': 166,
#   'type': 'short',
#   'title': 'Salida de los trabajadores de la fábrica España Industrial',
#   'originalTitle': 'Salida de los trabajadores de la fábrica España Industrial',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 3.2,
#   'numVotes': 19,
#   'genres': ['Documentary', 'Short'],
#   'directors': [5717]},
#  {'_id': 167,
#   'type': 'short',
#   'title': 'Salida de misa de doce del Pilar de Zaragoza',
#   'originalTitle': 'Salida de misa de doce del Pilar de Zaragoza',
#   'startYear': 1897,
#   'runtime': 0,
#   'avgRating': 4.0,
#   'numVotes': 142,
#   'genres': ['Documentary', 'Short'],
#   'directors': [422809]},
#  {'_id': 168,
#   'type': 'short',
#   'title': 'Salida del público de la iglesia parroquial de Santa María de Sans',
#   'originalTitle': 'Salida del público de la iglesia parroquial de Santa María de Sans',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 2.8,
#   'numVotes': 16,
#   'genres': ['Documentary', 'Short'],
#   'directors': [5717]},
#  {'_id': 169,
#   'type': 'short',
#   'title': 'Slagsmål i gamla Stockholm',
#   'originalTitle': 'Slagsmål i gamla Stockholm',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 3.7,
#   'numVotes': 45,
#   'genres': ['Short'],
#   'directors': [698645],
#   'producers': [677318]},
#  {'_id': 170,
#   'type': 'short',
#   'title': "The Twins' Tea Party",
#   'originalTitle': "The Twins' Tea Party",
#   'startYear': 1896,
#   'runtime': 1,
#   'avgRating': 5.2,
#   'numVotes': 257,
#   'genres': ['Short', 'Comedy'],
#   'directors': [666972]},
#  {'_id': 171,
#   'type': 'short',
#   'title': 'Une nuit agitée',
#   'originalTitle': 'Une nuit agitée',
#   'startYear': 1897,
#   'runtime': 0,
#   'genres': ['Short', 'Comedy'],
#   'directors': [349785]},
#  {'_id': 172,
#   'type': 'short',
#   'title': 'The X-Ray Fiend',
#   'originalTitle': 'The X-Ray Fiend',
#   'startYear': 1897,
#   'runtime': 1,
#   'avgRating': 6.1,
#   'numVotes': 936,
#   'genres': ['Short', 'Comedy', 'Horror'],
#   'actors': [{'actor': 338379, 'roles': ['Professor']}],
#   'directors': [808310]},
#  {'_id': 173,
#   'type': 'short',
#   'title': 'Battle of Santiago Bay',
#   'originalTitle': 'Battle of Santiago Bay',
#   'startYear': 1898,
#   'runtime': 0,
#   'avgRating': 4.5,
#   'numVotes': 44,
#   'genres': ['Short', 'War'],
#   'directors': [85865]},
#  {'_id': 174,
#   'type': 'short',
#   'title': 'Výstavní párkar a lepic plakátù',
#   'originalTitle': 'Výstavní párkar a lepic plakátù',
#   'startYear': 1898,
#   'runtime': 1,
#   'avgRating': 4.6,
#   'numVotes': 129,
#   'genres': ['Short', 'Comedy'],
# ...
#   'startYear': 1909,
#   'runtime': 6,
#   'avgRating': 6.3,
#   'numVotes': 171,
#   'genres': ['Short', 'Romance', 'Drama'],
#   'actors': [{'actor': 24344, 'roles': ['Molenaar']},
#    {'actor': 77702, 'roles': ['Verliefde mededinger']},
#    {'actor': 767008, 'roles': ['Johanna']}],
#   'directors': [532622]},
#  {'_id': 972,
#   'type': 'short',
#   'title': "The Mountaineer's Honor",
#   'originalTitle': "The Mountaineer's Honor",
#   'startYear': 1909,
#   'runtime': 11,
#   'avgRating': 5.8,
#   'numVotes': 88,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 115524, 'roles': ["The Mountain Girl's Mother"]},
#    {'actor': 424530, 'roles': ['A Traveler From The Valley']},
#    {'actor': 456804, 'roles': ["The Mountain Girl's Brother"]},
#    {'actor': 601698, 'roles': ["The Mountain Girl's Suitor"]},
#    {'actor': 629589, 'roles': ["The Mountain Girl's Father"]},
#    {'actor': 642722, 'roles': ['The Sheriff']},
#    {'actor': 681933, 'roles': ['Harum-Scarum - a Mountain Girl']}],
#   'directors': [428],
#   'writers': [428, 940488]},
#  {'_id': 974,
#   'type': 'short',
#   'title': 'Mr. Jones Has a Card Party',
#   'originalTitle': 'Mr. Jones Has a Card Party',
#   'startYear': 1909,
#   'runtime': 10,
#   'avgRating': 5.1,
#   'numVotes': 55,
#   'genres': ['Short', 'Comedy'],
#   'actors': [{'actor': 38106, 'roles': ['The Maid']},
#    {'actor': 173994, 'roles': ['Mr. Jones']},
#    {'actor': 277411, 'roles': ['Guest']},
#    {'actor': 366008, 'roles': ['The Messenger']},
#    {'actor': 376829, 'roles': ['Guest']},
#    {'actor': 492757, 'roles': ['Mrs. Jones']}],
#   'directors': [428],
#   'writers': [428, 940488]},
#  {'_id': 975,
#   'type': 'short',
#   'title': "Mr. Jones' Burglar",
#   'originalTitle': "Mr. Jones' Burglar",
#   'startYear': 1909,
#   'runtime': 4,
#   'avgRating': 5.1,
#   'numVotes': 21,
#   'genres': ['Short', 'Comedy'],
#   'actors': [{'actor': 125164, 'roles': ['At Club']},
#    {'actor': 173994, 'roles': ['Mr. Jones']},
#    {'actor': 424530, 'roles': ['At Club']},
#    {'actor': 492757, 'roles': ['Mrs. Jones']},
#    {'actor': 601698, 'roles': ['At Club']},
#    {'actor': 642722, 'roles': ['At Club']},
#    {'actor': 784407, 'roles': ['The Burglar']}],
#   'directors': [428],
#   'writers': [428]},
#  {'_id': 976,
#   'type': 'short',
#   'title': "Mrs. Jones' Lover; or, 'I Want My Hat'",
#   'originalTitle': "Mrs. Jones' Lover; or, 'I Want My Hat'",
#   'startYear': 1909,
#   'runtime': 5,
#   'avgRating': 3.9,
#   'numVotes': 20,
#   'genres': ['Short', 'Comedy'],
#   'actors': [{'actor': 173994, 'roles': ['Mr. Jones']},
#    {'actor': 492757, 'roles': ['Mrs. Jones']},
#    {'actor': 642722, 'roles': ['The Repairman']}],
#   'directors': [428],
#   'writers': [428]},
#  {'_id': 977,
#   'type': 'short',
#   'title': 'Mutterliebe',
#   'originalTitle': 'Mutterliebe',
#   'startYear': 1909,
#   'runtime': 0,
#   'genres': ['Short'],
#   'producers': [1902148]},
#  {'_id': 978,
#   'type': 'short',
#   'title': 'Napoleon og hans lille Trompetist',
#   'originalTitle': 'Napoleon og hans lille Trompetist',
#   'startYear': 1909,
#   'runtime': 0,
#   'genres': ['Short'],
#   'directors': [488932]},
#  {'_id': 979,
#   'type': 'short',
#   'title': 'Napoleon, the Man of Destiny',
#   'originalTitle': 'Napoleon, the Man of Destiny',
#   'startYear': 1908,
#   'runtime': 13,
#   'avgRating': 4.9,
#   'numVotes': 30,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 401967, 'roles': ['Napoleon']}],
#   'directors': [85865],
#   'writers': [612348]},
#  {'_id': 980,
#   'type': 'short',
#   'title': 'A Narrow Escape from Lynching',
#   'originalTitle': 'A Narrow Escape from Lynching',
#   'startYear': 1909,
#   'runtime': 0,
#   'genres': ['Short', 'Drama'],
#   'directors': [294276],
#   'producers': [378408]},
#  {'_id': 981,
#   'type': 'short',
#   'title': 'The Necklace',
#   'originalTitle': 'The Necklace',
#   'startYear': 1909,
#   'runtime': 11,
#   'avgRating': 5.5,
#   'numVotes': 53,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 364516, 'roles': ['Owner of Necklace (unconfirmed)']},
#    {'actor': 455237, 'roles': ['Harriet Leroque Kendrick']},
#    {'actor': 642722, 'roles': ['Servant', 'Loan Clerk']},
#    {'actor': 681933, 'roles': ['The Maid', 'In Pawnshop']},
#    {'actor': 697944, 'roles': ['John Kendrick']}],
#   'directors': [428],
#   'writers': [560943, 940488]},
#  {'_id': 982,
#   'type': 'short',
#   'title': 'The New Servant',
#   'originalTitle': 'The New Servant',
#   'startYear': 1909,
#   'runtime': 0,
#   'genres': ['Short', 'Comedy'],
#   'directors': [294276],
#   'producers': [378408]},
#  {'_id': 983,
#   'type': 'short',
#   'title': 'A New Trick',
#   'originalTitle': 'A New Trick',
#   'startYear': 1909,
#   'runtime': 2,
#   'genres': ['Short'],
#   'actors': [{'actor': 424530, 'roles': ['Helper']},
#    {'actor': 502701, 'roles': ['The Woman']},
#    {'actor': 697944, 'roles': ['Helper']},
#    {'actor': 784407, 'roles': ['The Thief']}],
#   'directors': [428],
#   'writers': [428]},
#  {'_id': 984,
#   'type': 'movie',
#   'title': 'Niños en la alameda',
#   'originalTitle': 'Niños en la alameda',
#   'startYear': 1909,
#   'runtime': 0,
#   'directors': [23107]},
#  {'_id': 985,
#   'type': 'short',
#   'title': 'The Note in the Shoe',
#   'originalTitle': 'The Note in the Shoe',
#   'startYear': 1909,
#   'runtime': 8,
#   'avgRating': 4.4,
#   'numVotes': 16,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 173994, 'roles': ['In Office']},
#    {'actor': 366008, 'roles': ['In Store']},
#    {'actor': 376829, 'roles': ['The Mother']},
#    {'actor': 409390, 'roles': ['Customer Who Finds Note']},
#    {'actor': 424530, 'roles': ['In Office']},
#    {'actor': 492757, 'roles': ['Ella Berling']},
#    {'actor': 502701, 'roles': ['Factory Employee']},
#    {'actor': 642722, 'roles': ['The Messenger', 'Factory Employee']},
#    {'actor': 797094, 'roles': ['The Butler']}],
#   'directors': [428],
#   'writers': [428]},
#  {'_id': 986,
#   'type': 'short',
#   'title': 'Nursing a Viper',
#   'originalTitle': 'Nursing a Viper',
#   'startYear': 1909,
#   'runtime': 10,
#   'avgRating': 5.0,
#   'numVotes': 111,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 262757, 'roles': ['In Mob']},
#    {'actor': 288616, 'roles': ['The Viper']},
#    {'actor': 366511, 'roles': ['Victimized Woman']},
#    {'actor': 424530, 'roles': ['The Husband']},
#    {'actor': 456804, 'roles': ['In Mob']},
#    {'actor': 502701, 'roles': ['The Wife']}],
#   'directors': [428],
#   'writers': [428, 940488]},
#  {'_id': 987,
#   'type': 'short',
#   'title': 'How Brother Cook was Taught a Lesson',
#   'originalTitle': 'Naar Djævle er paa Spil',
#   'startYear': 1910,
#   'runtime': 15,
#   'avgRating': 7.8,
#   'numVotes': 9,
#   'genres': ['Short', 'Comedy'],
#   'directors': [711337]},
#  {'_id': 988,
#   'type': 'short',
#   'title': 'The Short-Sighted Governess',
#   'originalTitle': 'Den nærsynede guvernante',
#   'startYear': 1909,
#   'runtime': 2,
#   'avgRating': 4.8,
#   'numVotes': 23,
#   'genres': ['Short', 'Comedy'],
#   'actors': [{'actor': 814379, 'roles': ['Governess']}],
#   'directors': [333175]},
#  {'_id': 989,
#   'type': 'short',
#   'title': 'Oh, Uncle!',
#   'originalTitle': 'Oh, Uncle!',
#   'startYear': 1909,
#   'runtime': 3,
#   'avgRating': 4.8,
#   'numVotes': 45,
#   'genres': ['Short', 'Comedy'],
#   'actors': [{'actor': 456804, 'roles': ['Zeke Wright']},
#    {'actor': 681933, 'roles': ['Bessie']},
#    {'actor': 704334, 'roles': ["Tom Wright - Zeke's Nephew"]}],
#   'directors': [428],
#   'writers': [428]},
#  {'_id': 990,
#   'type': 'short',
#   'title': 'Oliver Twist',
#   'originalTitle': 'Oliver Twist',
#   'startYear': 1909,
#   'runtime': 14,
#   'avgRating': 6.0,
#   'numVotes': 78,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 401967, 'roles': ['Fagin']},
#    {'actor': 652898, 'roles': ['Nancy Sykes']},
#    {'actor': 832458, 'roles': ['Oliver']}],
#   'directors': [85865],
#   'writers': [2042, 612348]},
#  {'_id': 991,
#   'type': 'short',
#   'title': "On the Little Big Horn or Custer's Last Stand",
#   'originalTitle': "On the Little Big Horn or Custer's Last Stand",
#   'startYear': 1909,
#   'runtime': 0,
#   'genres': ['Drama', 'Action', 'History'],
#   'directors': [91767],
#   'producers': [783152]},
#  {'_id': 992,
#   'type': 'short',
#   'title': 'De onde Veje',
#   'originalTitle': 'De onde Veje',
#   'startYear': 1909,
#   'runtime': 0,
#   'avgRating': 4.4,
#   'numVotes': 15,
#   'genres': ['Short'],
#   'actors': [{'actor': 119164, 'roles': ['Ruth']}]},
#  {'_id': 993,
#   'type': 'short',
#   'title': 'One Busy Hour',
#   'originalTitle': 'One Busy Hour',
#   'startYear': 1909,
#   'runtime': 3,
#   'genres': ['Short', 'Comedy'],
#   'actors': [{'actor': 43018, 'roles': ['In Store']},
#    {'actor': 173994, 'roles': ['Jim Smith']},
#    {'actor': 366008, 'roles': ['Customer']},
#    {'actor': 376829, 'roles': ['Customer']},
#    {'actor': 409390, 'roles': ['Customer']},
#    {'actor': 697944, 'roles': ['Hiram Greengage']}],
#   'directors': [428],
#   'writers': [428]},
#  {'_id': 994,
#   'type': 'short',
#   'title': 'One Good Turn Deserves Another',
#   'originalTitle': 'One Good Turn Deserves Another',
#   'startYear': 1909,
#   'runtime': 0,
#   'genres': ['Short', 'Drama'],
#   'directors': [294276],
#   'producers': [378408]},
#  {'_id': 995,
#   'type': 'short',
#   'title': 'One Touch of Nature',
#   'originalTitle': 'One Touch of Nature',
#   'startYear': 1909,
#   'runtime': 10,
#   'avgRating': 6.6,
#   'numVotes': 18,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 38106, 'roles': ['Nurse']},
#    {'actor': 409390, 'roles': ["Sicilian Woman's Accomplice"]},
#    {'actor': 424530, 'roles': ['John Murray']},
#    {'actor': 492757, 'roles': ['Mrs. John Murray']},
#    {'actor': 502701, 'roles': ['Sicilian Woman']},
#    {'actor': 813603, 'roles': ['Doctor']}],
#   'directors': [428],
#   'writers': [853193]},
#  {'_id': 996,
#   'type': 'short',
#   'title': 'Only a Tramp',
#   'originalTitle': 'Only a Tramp',
#   'startYear': 1909,
#   'runtime': 0,
#   'genres': ['Short', 'Drama'],
#   'directors': [294276],
#   'producers': [378408]},
#  {'_id': 997,
#   'type': 'short',
#   'title': 'The Open Gate',
#   'originalTitle': 'The Open Gate',
#   'startYear': 1909,
#   'runtime': 11,
#   'avgRating': 6.2,
#   'numVotes': 16,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 115524, 'roles': ['Hetty']},
#    {'actor': 354803, 'roles': ["Hetty's Niece - Mary - as a Child"]},
#    {'actor': 601698, 'roles': ["George's Nephew - Jack"]},
#    {'actor': 629589, 'roles': ['George']},
#    {'actor': 732651, 'roles': ["Hetty's Niece - Mary - as an Adult"]},
#    {'actor': 784407, 'roles': ["Hetty's Brother-in-Law"]}],
#   'directors': [428],
#   'writers': [428, 940488]},
#  {'_id': 998,
#   'type': 'short',
#   'title': 'Othello',
#   'originalTitle': 'Otello',
#   'startYear': 1909,
#   'runtime': 12,
#   'avgRating': 5.2,
#   'numVotes': 18,
#   'genres': ['Short', 'Romance', 'Drama'],
#   'actors': [{'actor': 232370, 'roles': ['Iago']},
#    {'actor': 304862, 'roles': ['Othello']},
#    {'actor': 503227, 'roles': ['Desdemona']},
#    {'actor': 626131, 'roles': ['Cassio']},
#    {'actor': 679086, 'roles': ['Duke of Venice']}],
#   'directors': [266080],
#   'writers': [636]},
#  {'_id': 999,
#   'type': 'short',
#   'title': "Paul Wang's Destiny",
#   'originalTitle': 'Paul Wangs skæbne',
#   'startYear': 1909,
#   'runtime': 0,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 684773, 'roles': ['Paul Wang']}],
#   'directors': [488932],
#   'writers': [488932]},
#  {'_id': 1000,
#   'type': 'short',
#   'title': 'The Peachbasket Hat',
#   'originalTitle': 'The Peachbasket Hat',
#   'startYear': 1909,
#   'runtime': 7,
#   'avgRating': 5.4,
#   'numVotes': 51,
#   'genres': ['Short', 'Comedy'],
#   'actors': [{'actor': 38106, 'roles': ['Visitor']},
#    {'actor': 43018, 'roles': ['On Street']},
#    {'actor': 173994, 'roles': ['Mr. Jones']},
#    {'actor': 376829, 'roles': ['The Maid']},
#    {'actor': 424530, 'roles': ['Policeman', 'In Store']},
#    {'actor': 492757, 'roles': ['Mrs. Jones']}],
#   'directors': [428],
#   'writers': [428]},
#  {'_id': 1001,
#   'type': 'short',
#   'title': 'Pippa Passes; or, the Song of Conscience',
#   'originalTitle': 'Pippa Passes; or, The Song of Conscience',
#   'startYear': 1909,
#   'runtime': 11,
#   'avgRating': 5.2,
#   'numVotes': 134,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 38106, 'roles': ['Greek Model']},
#    {'actor': 456804, 'roles': ['Jules']},
#    {'actor': 629589, 'roles': ["Pippa's Husband"]},
#    {'actor': 732651, 'roles': ['Pippa']}],
#   'directors': [428],
#   'writers': [428, 115203, 940488]},
#  {'_id': 1002,
#   'type': 'short',
#   'title': "The Politician's Love Story",
#   'originalTitle': "The Politician's Love Story",
#   'startYear': 1909,
#   'runtime': 6,
#   'avgRating': 4.8,
#   'numVotes': 95,
#   'genres': ['Short', 'Comedy', 'Romance'],
#   'actors': [{'actor': 38106, 'roles': ['Woman - Third Couple']},
#    {'actor': 311375, 'roles': ['Newspaper Employee']},
#    {'actor': 376829, 'roles': ['Woman - Fourth Couple']},
#    {'actor': 424530, 'roles': ['Newspaper Employee', 'Man - Third Couple']},
#    {'actor': 502701, 'roles': ['Peters - the Cartoonist']},
#    {'actor': 697944, 'roles': ["Crogan's Friend"]},
#    {'actor': 784407, 'roles': ['Boss Tim Crogan']}],
#   'directors': [428],
#   'writers': [428]},
#  {'_id': 1003,
#   'type': 'short',
#   'title': 'Por un ratón',
#   'originalTitle': 'Por un ratón',
#   'startYear': 1909,
#   'runtime': 8,
#   'genres': ['Short', 'Comedy'],
#   'directors': [5717],
#   'writers': [5717]},
#  {'_id': 1004,
#   'type': 'short',
#   'title': 'Portrait of Mireille',
#   'originalTitle': 'Le portrait de Mireille',
#   'startYear': 1909,
#   'runtime': 8,
#   'genres': ['Short'],
#   'directors': [674600],
#   'writers': [275421, 304098]},
#  {'_id': 1005,
#   'type': 'short',
#   'title': 'Pranks',
#   'originalTitle': 'Pranks',
#   'startYear': 1909,
#   'runtime': 4,
#   'avgRating': 4.0,
#   'numVotes': 17,
#   'genres': ['Short', 'Comedy'],
#   'actors': [{'actor': 38106, 'roles': ['On Porch']},
#    {'actor': 366008, 'roles': ['One of the Boys']},
#    {'actor': 424530, 'roles': ['Tom']},
#    {'actor': 502701, 'roles': ['Ethel']},
#    {'actor': 642722, 'roles': ['Mr. Tramp']},
#    {'actor': 681927, 'roles': ['One of the Boys']},
#    {'actor': 704334, 'roles': ['Sunbather']},
#    {'actor': 910400, 'roles': ['Sunbather']}],
#   'directors': [428]},
#  {'_id': 1006,
#   'type': 'short',
#   'title': "Primera carrera internacional de automóviles 'Peña-Rhin'",
#   'originalTitle': "Primera carrera internacional de automóviles 'Peña-Rhin'",
#   'startYear': 1909,
#   'runtime': 10,
#   'genres': ['Short'],
#   'directors': [5717]},
#  {'_id': 1007,
#   'type': 'movie',
#   'title': 'La primera y segunda casetas',
#   'originalTitle': 'La primera y segunda casetas',
#   'startYear': 1909,
#   'runtime': 0,
#   'directors': [185426]},
#  {'_id': 1008,
#   'type': 'short',
#   'title': 'The Prince and the Pauper',
#   'originalTitle': 'The Prince and the Pauper',
#   'startYear': 1909,
#   'runtime': 0,
#   'avgRating': 5.2,
#   'numVotes': 29,
#   'genres': ['Short'],
#   'actors': [{'actor': 819384, 'roles': ['The Prince', 'Tom Canty']}],
#   'directors': [205986],
#   'writers': [205986, 878494]},
#  {'_id': 1009,
#   'type': 'short',
#   'title': 'Princess Nicotine; or, the Smoke Fairy',
#   'originalTitle': 'Princess Nicotine; or, The Smoke Fairy',
#   'startYear': 1909,
#   'runtime': 5,
#   'avgRating': 6.5,
#   'numVotes': 962,
#   'genres': ['Short', 'Comedy', 'Fantasy'],
#   'actors': [{'actor': 401368, 'roles': ['The Elder Fairy']},
#    {'actor': 659947, 'roles': ['The Smoker']}],
#   'directors': [85865]},
#  {'_id': 1010,
#   'type': 'movie',
#   'title': 'Protección de un convoy de víveres en el puente de camellos',
#   'originalTitle': 'Protección de un convoy de víveres en el puente de camellos',
#   'startYear': 1909,
#   'runtime': 0,
#   'avgRating': 4.2,
#   'numVotes': 15,
#   'directors': [185426]},
#  {'_id': 1011,
#   'type': 'short',
#   'title': 'The Prussian Spy',
#   'originalTitle': 'The Prussian Spy',
#   'startYear': 1909,
#   'runtime': 5,
#   'avgRating': 4.4,
#   'numVotes': 17,
#   'genres': ['Short', 'Drama'],
#   'actors': [{'actor': 424530, 'roles': ['Soldier']},
#    {'actor': 492757, 'roles': ['The Maid']},
#    {'actor': 502701, 'roles': ['Lady Florence']},
#    {'actor': 587097, 'roles': ['Soldier']},
#    {'actor': 601698, 'roles': ['The Spy']},
#    {'actor': 784407, 'roles': ['Soldier']},
#    {'actor': 813603, 'roles': ['Count Lopes']}],
#   'directors': [428],
#   'writers': [428]},
#  ...]

# %% [markdown]
# ## Loading data to IMDB MongoDB

# %% [markdown]
# ### Connecting to IMDB MongoDB

# %%
connection_string = "mongodb://" + mongo_config['host'] + ":" + mongo_config['port']
mongo_client = pymongo.MongoClient(connection_string)

# %%
imdb = mongo_client[mongo_config['database']]
imdb
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'imdb')

# %%
movie_collection = imdb['Movies']
movie_collection.insert_many(movies)

# %%
member_collection = imdb['Members']
member_collection.insert_many(members)
